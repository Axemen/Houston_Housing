# %%
# Dependencies
import requests
import json
import matplotlib.pyplot as plt
import pandas as pd
import xmltodict
from pprint import pprint

# %%
url="http://www.zillow.com/webservice/GetRegionChildren.htm?"
zwsid="X1-ZWz1gz687fgzyj_9r65p"
state="texas"
city="houston"

query_url = f"{url}zws-id={zwsid}&state={state}&output=json&city={city}&childtype=zipcode"
query_url
# Out:
# 'http://www.zillow.com/webservice/GetRegionChildren.htm?zws-id=X1-ZWz1gz687fgzyj_9r65p&state=texas&output=json&city=houston&childtype=zipcode'

# %%
# type(response.text)

# %%
response = requests.get(query_url)
#json.dumps(response.badgerfish.data(xml))
#pprint(response.text)
json.loads(pprint(xmltodict.parse(response.text)))
# Out:
# OrderedDict([('RegionChildren:regionchildren',
#               OrderedDict([('@xsi:schemaLocation',
#                             'http://www.zillow.com/static/xsd/RegionChildren.xsd '
#                             'https://www.zillowstatic.com/vstatic/091b98a/static/xsd/RegionChildren.xsd'),
#                            ('@xmlns:xsi',
#                             'http://www.w3.org/2001/XMLSchema-instance'),
#                            ('@xmlns:RegionChildren',
#                             'http://www.zillow.com/static/xsd/RegionChildren.xsd'),
#                            ('request',
#                             OrderedDict([('state', 'texas'),
#                                          ('city', 'houston'),
#                                          ('childtype', 'zipcode')])),
#                            ('message',
#                             OrderedDict([('text',
#                                           'Request successfully processed'),
# ...
