# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('temp_output.csv')
df.groupby(['County']).count()
# Out:
#                zip  address     lat     lng  taxAssessment  lot sq/ft  \
# County
# Austin        6345     6345    6345    6345           4226       3907
# Brazoria     25115    25115   25115   25115          18593      18096
# Chambers      4387     4387    4387    4387           3074       3049
# Fort_Bend    30885    30885   30885   30885          25571      20363
# Galveston    24436    24436   24436   24436           1964       1955
# Harris      248592   248592  248592  248592          62230      58311
# Liberty       7027     7027    7027    7027              0          0
# Montgomery   40081    40081   40081   40081              0          0
# Waller        3620     3620    3620    3620              0          0
#
#             finished sq/ft  price low  price high  zestimate
# County
# Austin                3362       3024        3024       3024
# Brazoria             17700      17384       17384      17384
# Chambers              2520       2408        2408       2408
# ...

# %%
temp = df.dropna(how='any')

# %%
temp.groupby(['County']).count()
# Out:
#              zip  address    lat    lng  taxAssessment  lot sq/ft  \
# County
# Austin      3024     3024   3024   3024           3024       3024
# Brazoria   17384    17384  17384  17384          17384      17384
# Chambers    2408     2408   2408   2408           2408       2408
# Fort_Bend  19241    19241  19241  19241          19241      19241
# Galveston   1839     1839   1839   1839           1839       1839
# Harris     56599    56599  56599  56599          56599      56599
#
#            finished sq/ft  price low  price high  zestimate
# County
# Austin               3024       3024        3024       3024
# Brazoria            17384      17384       17384      17384
# Chambers             2408       2408        2408       2408
# Fort_Bend           19241      19241       19241      19241
# Galveston            1839       1839        1839       1839
# Harris              56599      56599       56599      56599
