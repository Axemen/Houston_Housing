# %%
# Dependencies
import requests
import pandas as pd
import datetime

# %% [markdown]
# ### Data Retrieval

# %%
# Query url for HPD recent crime reports (rpt) from COHGIS Open Data Portal
url = "https://opendata.arcgis.com/datasets/8d515a90e80840b3bc7a3ada352b0d15_0.geojson"

# Get HPD crime reports data and save as "hpd_crime_rpt"
hpd_crime_rpt = requests.get(url).json()

# View "hpd_crime_rpt"
hpd_crime_rpt
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'OBJECTID': 2001,
#     'Join_Count': 1,
#     'TARGET_FID': 2001,
#     'Join_Count_1': 1,
#     'Incident_No': 33634519,
#     'Time_Begun': '2019-03-16T20:45:00.000Z',
#     'UCR_No': 7001,
#     'HPD_Beat': '10H70',
#     'HPD_District': '10',
#     'Offense': 'Auto Theft',
#     'Address_Range': '2300-2399 CAMDEN',
#     'Premise_Type': 'Road, Street, or Sidewalk',
#     'X_Coord': 3117097.76176,
#     'Y_Coord': 13823911.50133,
#     'Zip_Code': '77021',
#     'Time_Frame': 2,
#     'SNB_No': 83,
#     'SNB_Name': 'MACGREGOR',
#     'Council_District': 'D',
#     'HPD_Division': 'South Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.38101631427402, 29.711213511623697]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2002,
#     'Join_Count': 1,
#     'TARGET_FID': 2002,
#     'Join_Count_1': 1,
#     'Incident_No': 27829919,
#     'Time_Begun': '2019-03-04T13:25:00.000Z',
#     'UCR_No': 7031,
#     'HPD_Beat': '12D70',
#     'HPD_District': '12',
#     'Offense': 'Auto Theft',
#     'Address_Range': '500-599 BAYBROOK MALL',
#     'Premise_Type': 'Mall Parking Lot',
#     'X_Coord': 3193759.65036,
#     'Y_Coord': 13765293.59997,
#     'Zip_Code': '77546',
#     'Time_Frame': 3,
#     'SNB_No': 81,
#     'SNB_Name': 'CLEAR LAKE',
#     'Council_District': 'E',
#     'HPD_Division': 'Clear Lake Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.14572497102509, 29.543355609466264]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2003,
#     'Join_Count': 1,
#     'TARGET_FID': 2003,
#     'Join_Count_1': 1,
#     'Incident_No': 35089319,
#     'Time_Begun': '2019-03-20T14:45:00.000Z',
#     'UCR_No': 6031,
#     'HPD_Beat': '17E40',
#     'HPD_District': '17',
#     'Offense': 'Theft',
#     'Address_Range': '12300-12399 FONDREN',
#     'Premise_Type': 'Drug Store or Medical Sup',
#     'X_Coord': 3077439.58731,
#     'Y_Coord': 13798322.09348,
#     'Zip_Code': '77071',
#     'Time_Frame': 1,
#     'SNB_No': 36,
#     'SNB_Name': 'BRAYS OAKS',
#     'Council_District': 'K',
#     'HPD_Division': 'South Gessner Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.50830180503843, 29.64418842200775]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2004,
#     'Join_Count': 1,
#     'TARGET_FID': 2004,
#     'Join_Count_1': 1,
#     'Incident_No': 30831719,
#     'Time_Begun': '2019-03-11T09:50:00.000Z',
#     'UCR_No': 6073,
#     'HPD_Beat': '19G50',
#     'HPD_District': '19',
#     'Offense': 'Theft',
#     'Address_Range': '9800-9899 BISSONNET',
#     'Premise_Type': 'Convenience Store',
#     'X_Coord': 3063657.64859,
#     'Y_Coord': 13809234.24571,
#     'Zip_Code': '77036',
#     'Time_Frame': 3,
#     'SNB_No': 29,
#     'SNB_Name': 'WESTWOOD',
#     'Council_District': 'J',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.55065844810626, 29.67530907255889]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2005,
#     'Join_Count': 1,
#     'TARGET_FID': 2005,
#     'Join_Count_1': 1,
#     'Incident_No': 32738419,
#     'Time_Begun': '2019-02-24T10:25:00.000Z',
#     'UCR_No': 7031,
#     'HPD_Beat': '12D10',
#     'HPD_District': '12',
#     'Offense': 'Auto Theft',
#     'Address_Range': '8600-8699 PANAIR',
#     'Premise_Type': 'Vehicle/Auto Sales/Lease/',
#     'X_Coord': 3155001.94753,
#     'Y_Coord': 13803557.77005,
#     'Zip_Code': '77075',
#     'Time_Frame': 3,
#     'SNB_No': 78,
#     'SNB_Name': 'GREATER HOBBY AREA',
#     'Council_District': 'I',
#     'HPD_Division': 'Clear Lake Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.2637162396705, 29.651989724830646]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2006,
#     'Join_Count': 1,
#     'TARGET_FID': 2006,
#     'Join_Count_1': 1,
#     'Incident_No': 25172619,
#     'Time_Begun': '2019-02-26T16:45:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '7C30',
#     'HPD_District': '7',
#     'Offense': 'Theft',
#     'Address_Range': '2300-2399 PRIEST',
#     'Premise_Type': 'Residence or House',
#     'X_Coord': 3125599.6598,
#     'Y_Coord': 13875968.47351,
#     'Zip_Code': '77093',
#     'Time_Frame': 3,
#     'SNB_No': 46,
#     'SNB_Name': 'EASTEX - JENSEN AREA',
#     'Council_District': 'B',
#     'HPD_Division': 'Northeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.34912732811571, 29.85357395617067]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2007,
#     'Join_Count': 1,
#     'TARGET_FID': 2007,
#     'Join_Count_1': 1,
#     'Incident_No': 34655919,
#     'Time_Begun': '2019-03-19T14:00:00.000Z',
#     'UCR_No': 7031,
#     'HPD_Beat': '5F30',
#     'HPD_District': '5',
#     'Offense': 'Auto Theft',
#     'Address_Range': '14000-14099 NORTHWEST ',
#     'Premise_Type': 'Other Parking Lot',
#     'X_Coord': 3069502.68251,
#     'Y_Coord': 13876579.3945,
#     'Zip_Code': '77040',
#     'Time_Frame': 2,
#     'SNB_No': 4,
#     'SNB_Name': 'FAIRBANKS / NORTHWEST CROSSING',
#     'Council_District': 'A',
#     'HPD_Division': 'Northwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.5259605074485, 29.859951456421147]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2008,
#     'Join_Count': 1,
#     'TARGET_FID': 2008,
#     'Join_Count_1': 1,
#     'Incident_No': 24240419,
#     'Time_Begun': '2019-02-24T13:00:00.000Z',
#     'UCR_No': 6191,
#     'HPD_Beat': '3B50',
#     'HPD_District': '3',
#     'Offense': 'Theft',
#     'Address_Range': '4400-4499 NORTH ',
#     'Premise_Type': 'Restaurant or Cafeteria',
#     'X_Coord': 3115704.38401,
#     'Y_Coord': 13866978.36831,
#     'Zip_Code': '77022',
#     'Time_Frame': 3,
#     'SNB_No': 45,
#     'SNB_Name': 'NORTHSIDE/NORTHLINE',
#     'Council_District': 'H',
#     'HPD_Division': 'North Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.38120631581401, 29.82970922069187]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2009,
#     'Join_Count': 1,
#     'TARGET_FID': 2009,
#     'Join_Count_1': 1,
#     'Incident_No': 24337819,
#     'Time_Begun': '2019-02-24T01:00:00.000Z',
#     'UCR_No': 6191,
#     'HPD_Beat': '18F40',
#     'HPD_District': '18',
#     'Offense': 'Theft',
#     'Address_Range': '3100-3199 DUNVALE',
#     'Premise_Type': 'Other, Unknown, or Not Li',
#     'X_Coord': 3074659.25352,
#     'Y_Coord': 13829822.87316,
#     'Zip_Code': '77063',
#     'Time_Frame': 3,
#     'SNB_No': 20,
#     'SNB_Name': 'MID WEST',
#     'Council_District': 'F',
#     'HPD_Division': 'Midwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.51409550313689, 29.73100701205344]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2010,
#     'Join_Count': 1,
#     'TARGET_FID': 2010,
#     'Join_Count_1': 1,
#     'Incident_No': 23758119,
#     'Time_Begun': '2019-02-23T10:10:00.000Z',
#     'UCR_No': 6143,
#     'HPD_Beat': '24C50',
#     'HPD_District': '24',
#     'Offense': 'Theft',
#     'Address_Range': '300-399 NORTHPARK',
#     'Premise_Type': 'Restaurant or Cafeteria',
#     'X_Coord': 3156473.35541,
#     'Y_Coord': 13955356.97423,
#     'Zip_Code': '77339',
#     'Time_Frame': 3,
#     'SNB_No': 43,
#     'SNB_Name': 'KINGWOOD AREA',
#     'Council_District': 'E',
#     'HPD_Division': 'Kingwood Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.24373818242269, 30.069081653439174]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2011,
#     'Join_Count': 1,
#     'TARGET_FID': 2011,
#     'Join_Count_1': 1,
#     'Incident_No': 23761319,
#     'Time_Begun': '2019-02-23T09:00:00.000Z',
#     'UCR_No': 5021,
#     'HPD_Beat': '3B50',
#     'HPD_District': '3',
#     'Offense': 'Burglary',
#     'Address_Range': '600-699 DORCHESTER',
#     'Premise_Type': 'Residence or House',
#     'X_Coord': 3120762.38912,
#     'Y_Coord': 13864684.37952,
#     'Zip_Code': '77022',
#     'Time_Frame': 3,
#     'SNB_No': 45,
#     'SNB_Name': 'NORTHSIDE/NORTHLINE',
#     'Council_District': 'H',
#     'HPD_Division': 'North Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.36548613925275, 29.822972629212884]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2012,
#     'Join_Count': 1,
#     'TARGET_FID': 2012,
#     'Join_Count_1': 1,
#     'Incident_No': 24519219,
#     'Time_Begun': '2019-02-24T19:45:00.000Z',
#     'UCR_No': 7001,
#     'HPD_Beat': '19G10',
#     'HPD_District': '19',
#     'Offense': 'Auto Theft',
#     'Address_Range': '9400-9499 CONCOURSE',
#     'Premise_Type': 'Apartment Parking Lot',
#     'X_Coord': 3061922.05592,
#     'Y_Coord': 13810702.12028,
#     'Zip_Code': '77036',
#     'Time_Frame': 3,
#     'SNB_No': 29,
#     'SNB_Name': 'WESTWOOD',
#     'Council_District': 'J',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.55598566491332, 29.6794847213164]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2013,
#     'Join_Count': 1,
#     'TARGET_FID': 2013,
#     'Join_Count_1': 1,
#     'Incident_No': 26396819,
#     'Time_Begun': '2019-03-01T14:06:00.000Z',
#     'UCR_No': 6193,
#     'HPD_Beat': '15E30',
#     'HPD_District': '15',
#     'Offense': 'Theft',
#     'Address_Range': '4600-4699 BEECHNUT',
#     'Premise_Type': 'Service or Gas Station',
#     'X_Coord': 3093063.25001,
#     'Y_Coord': 13815151.03191,
#     'Zip_Code': '77096',
#     'Time_Frame': 3,
#     'SNB_No': 31,
#     'SNB_Name': 'MEYERLAND AREA',
#     'Council_District': 'C',
#     'HPD_Division': 'Southwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.45753304968763, 29.689156422795154]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2014,
#     'Join_Count': 1,
#     'TARGET_FID': 2014,
#     'Join_Count_1': 1,
#     'Incident_No': 29952219,
#     'Time_Begun': '2019-03-07T21:00:00.000Z',
#     'UCR_No': 5031,
#     'HPD_Beat': '10H50',
#     'HPD_District': '10',
#     'Offense': 'Burglary',
#     'Address_Range': '3400-3499 ROSALIE',
#     'Premise_Type': 'Residence or House',
#     'X_Coord': 3126574.79005,
#     'Y_Coord': 13830891.18075,
#     'Zip_Code': '77004',
#     'Time_Frame': 3,
#     'SNB_No': 67,
#     'SNB_Name': 'GREATER THIRD WARD',
#     'Council_District': 'D',
#     'HPD_Division': 'South Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.35048944292669, 29.729588876274647]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2015,
#     'Join_Count': 0,
#     'TARGET_FID': 2015,
#     'Join_Count_1': 0,
#     'Incident_No': 25259319,
#     'Time_Begun': '2019-02-26T16:00:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '20G80',
#     'HPD_District': '20',
#     'Offense': 'Theft',
#     'Address_Range': '13300-13399 WESTHEIMER',
#     'Premise_Type': 'Strip Business Center Par',
#     'X_Coord': 3039461.09463,
#     'Y_Coord': 13830552.30887,
#     'Zip_Code': '77077',
#     'Time_Frame': 3,
#     'SNB_No': None,
#     'SNB_Name': None,
#     'Council_District': None,
#     'HPD_Division': None},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.62488886861537, 29.735851015155358]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2016,
#     'Join_Count': 1,
#     'TARGET_FID': 2016,
#     'Join_Count_1': 1,
#     'Incident_No': 25993019,
#     'Time_Begun': '2019-02-28T12:00:00.000Z',
#     'UCR_No': 7031,
#     'HPD_Beat': '18F20',
#     'HPD_District': '18',
#     'Offense': 'Auto Theft',
#     'Address_Range': '1600-1699 POST OAK',
#     'Premise_Type': 'Restaurant or Cafeteria P',
#     'X_Coord': 3091355.90669,
#     'Y_Coord': 13837839.67809,
#     'Zip_Code': '77056',
#     'Time_Frame': 3,
#     'SNB_No': 21,
#     'SNB_Name': 'GREATER UPTOWN',
#     'Council_District': 'G',
#     'HPD_Division': 'Midwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.46074579485924, 29.751664593087163]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2017,
#     'Join_Count': 1,
#     'TARGET_FID': 2017,
#     'Join_Count_1': 1,
#     'Incident_No': 25618019,
#     'Time_Begun': '2019-02-27T18:10:00.000Z',
#     'UCR_No': 7001,
#     'HPD_Beat': '19G10',
#     'HPD_District': '19',
#     'Offense': 'Auto Theft',
#     'Address_Range': '9400-9499 SOUTHWEST ',
#     'Premise_Type': 'Vehicle/Auto Sales/Lease/',
#     'X_Coord': 3067420.4536,
#     'Y_Coord': 13810863.55936,
#     'Zip_Code': '77036',
#     'Time_Frame': 3,
#     'SNB_No': 29,
#     'SNB_Name': 'WESTWOOD',
#     'Council_District': 'J',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.5386620464786, 29.679482153101123]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2018,
#     'Join_Count': 1,
#     'TARGET_FID': 2018,
#     'Join_Count_1': 1,
#     'Incident_No': 24280219,
#     'Time_Begun': '2019-02-24T17:30:00.000Z',
#     'UCR_No': 6074,
#     'HPD_Beat': '5F30',
#     'HPD_District': '5',
#     'Offense': 'Theft',
#     'Address_Range': '13400-13499 NORTHWEST ',
#     'Premise_Type': 'Department or Discount St',
#     'X_Coord': 3075033.14167,
#     'Y_Coord': 13873544.16783,
#     'Zip_Code': '77040',
#     'Time_Frame': 3,
#     'SNB_No': 4,
#     'SNB_Name': 'FAIRBANKS / NORTHWEST CROSSING',
#     'Council_District': 'A',
#     'HPD_Division': 'Northwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.50880613109257, 29.851155679394996]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2019,
#     'Join_Count': 1,
#     'TARGET_FID': 2019,
#     'Join_Count_1': 1,
#     'Incident_No': 30426419,
#     'Time_Begun': '2019-03-09T23:00:00.000Z',
#     'UCR_No': 5071,
#     'HPD_Beat': '1A30',
#     'HPD_District': '1',
#     'Offense': 'Burglary',
#     'Address_Range': '3200-3299 YOAKUM',
#     'Premise_Type': 'Restaurant or Cafeteria P',
#     'X_Coord': 3113037.03359,
#     'Y_Coord': 13835836.02878,
#     'Zip_Code': '77006',
#     'Time_Frame': 3,
#     'SNB_No': 24,
#     'SNB_Name': 'NEARTOWN - MONTROSE',
#     'Council_District': 'C',
#     'HPD_Division': 'Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.3926441618638, 29.74433564898222]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2020,
#     'Join_Count': 1,
#     'TARGET_FID': 2020,
#     'Join_Count_1': 1,
#     'Incident_No': 27799219,
#     'Time_Begun': '2019-03-02T22:00:00.000Z',
#     'UCR_No': 7003,
#     'HPD_Beat': '8C10',
#     'HPD_District': '8',
#     'Offense': 'Auto Theft',
#     'Address_Range': '4900-4999 E CROSSTIMBERS',
#     'Premise_Type': 'Road, Street, or Sidewalk',
#     'X_Coord': 3135186.48599,
#     'Y_Coord': 13868065.46233,
#     'Zip_Code': '77016',
#     'Time_Frame': 3,
#     'SNB_No': 48,
#     'SNB_Name': 'TRINITY / HOUSTON GARDENS',
#     'Council_District': 'B',
#     'HPD_Division': 'Northeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.3196832999453, 29.831025643203144]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2021,
#     'Join_Count': 1,
#     'TARGET_FID': 2021,
#     'Join_Count_1': 1,
#     'Incident_No': 31562519,
#     'Time_Begun': '2019-03-12T21:12:00.000Z',
#     'UCR_No': 4043,
#     'HPD_Beat': '2A30',
#     'HPD_District': '2',
#     'Offense': 'Aggravated Assault',
#     'Address_Range': '600-699 YALE ',
#     'Premise_Type': 'Road, Street, or Sidewalk',
#     'X_Coord': 3110669.50759,
#     'Y_Coord': 13849286.39431,
#     'Zip_Code': '77007',
#     'Time_Frame': 3,
#     'SNB_No': 15,
#     'SNB_Name': 'GREATER HEIGHTS',
#     'Council_District': 'C',
#     'HPD_Division': 'Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.39879646501393, 29.78150728628426]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2022,
#     'Join_Count': 1,
#     'TARGET_FID': 2022,
#     'Join_Count_1': 1,
#     'Incident_No': 24271019,
#     'Time_Begun': '2019-02-24T17:00:00.000Z',
#     'UCR_No': 5021,
#     'HPD_Beat': '11H30',
#     'HPD_District': '11',
#     'Offense': 'Burglary',
#     'Address_Range': '8100-8199 KINGSLEY',
#     'Premise_Type': 'Residence or House',
#     'X_Coord': 3150297.3367,
#     'Y_Coord': 13816280.19269,
#     'Zip_Code': '77017',
#     'Time_Frame': 3,
#     'SNB_No': 74,
#     'SNB_Name': 'PARK PLACE',
#     'Council_District': 'I',
#     'HPD_Division': 'Eastside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.2772461838086, 29.687372059779303]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2023,
#     'Join_Count': 1,
#     'TARGET_FID': 2023,
#     'Join_Count_1': 1,
#     'Incident_No': 23796119,
#     'Time_Begun': '2019-02-23T14:20:00.000Z',
#     'UCR_No': 6071,
#     'HPD_Beat': '18F20',
#     'HPD_District': '18',
#     'Offense': 'Theft',
#     'Address_Range': '5100-5199 WESTHEIMER',
#     'Premise_Type': 'Specialty Store (Non-Spec',
#     'X_Coord': 3089636.37826,
#     'Y_Coord': 13833729.15284,
#     'Zip_Code': '77056',
#     'Time_Frame': 3,
#     'SNB_No': 21,
#     'SNB_Name': 'GREATER UPTOWN',
#     'Council_District': 'G',
#     'HPD_Division': 'Midwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.46655381376219, 29.74050870495604]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2024,
#     'Join_Count': 1,
#     'TARGET_FID': 2024,
#     'Join_Count_1': 1,
#     'Incident_No': 23796419,
#     'Time_Begun': '2019-02-23T16:40:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '10H30',
#     'HPD_District': '10',
#     'Offense': 'Theft',
#     'Address_Range': '2100-2199 DALLAS',
#     'Premise_Type': 'Bar or Night Club Parking',
#     'X_Coord': 3124655.49485,
#     'Y_Coord': 13837990.72765,
#     'Zip_Code': '77003',
#     'Time_Frame': 3,
#     'SNB_No': 61,
#     'SNB_Name': 'DOWNTOWN',
#     'Council_District': 'I',
#     'HPD_Division': 'South Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.35583700855518, 29.749267864779934]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2025,
#     'Join_Count': 1,
#     'TARGET_FID': 2025,
#     'Join_Count_1': 1,
#     'Incident_No': 25049019,
#     'Time_Begun': '2019-02-25T23:00:00.000Z',
#     'UCR_No': 6191,
#     'HPD_Beat': '22B10',
#     'HPD_District': '22',
#     'Offense': 'Theft',
#     'Address_Range': '18200-18299 TOMBALL PKWY OB',
#     'Premise_Type': 'Hospital',
#     'X_Coord': 3060828.41423,
#     'Y_Coord': 13913959.811,
#     'Zip_Code': '77070',
#     'Time_Frame': 3,
#     'SNB_No': 1,
#     'SNB_Name': 'WILLOWBROOK',
#     'Council_District': 'A',
#     'HPD_Division': 'North Belt Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.54983634667055, 29.96340413513797]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2026,
#     'Join_Count': 1,
#     'TARGET_FID': 2026,
#     'Join_Count_1': 1,
#     'Incident_No': 25177019,
#     'Time_Begun': '2019-02-26T18:55:00.000Z',
#     'UCR_No': 4041,
#     'HPD_Beat': '8C10',
#     'HPD_District': '8',
#     'Offense': 'Aggravated Assault',
#     'Address_Range': '4900-4999 LAURA KOPPE',
#     'Premise_Type': 'Convenience Store',
#     'X_Coord': 3135320.04484,
#     'Y_Coord': 13871530.43301,
#     'Zip_Code': '77016',
#     'Time_Frame': 3,
#     'SNB_No': 48,
#     'SNB_Name': 'TRINITY / HOUSTON GARDENS',
#     'Council_District': 'B',
#     'HPD_Division': 'Northeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.318918343605, 29.84053785358893]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2027,
#     'Join_Count': 1,
#     'TARGET_FID': 2027,
#     'Join_Count_1': 1,
#     'Incident_No': 32141119,
#     'Time_Begun': '2019-03-14T04:01:00.000Z',
#     'UCR_No': 6151,
#     'HPD_Beat': '5F30',
#     'HPD_District': '5',
#     'Offense': 'Theft',
#     'Address_Range': '7000-7099 HOLLISTER',
#     'Premise_Type': 'Apartment Parking Lot',
#     'X_Coord': 3075768.03903,
#     'Y_Coord': 13877795.85564,
#     'Zip_Code': '77040',
#     'Time_Frame': 2,
#     'SNB_No': 4,
#     'SNB_Name': 'FAIRBANKS / NORTHWEST CROSSING',
#     'Council_District': 'A',
#     'HPD_Division': 'Northwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.50608821282977, 29.862781964716824]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2028,
#     'Join_Count': 1,
#     'TARGET_FID': 2028,
#     'Join_Count_1': 1,
#     'Incident_No': 33629819,
#     'Time_Begun': '2019-03-17T08:40:00.000Z',
#     'UCR_No': 6073,
#     'HPD_Beat': '3B50',
#     'HPD_District': '3',
#     'Offense': 'Theft',
#     'Address_Range': '4400-4499 NORTH ',
#     'Premise_Type': 'Department or Discount St',
#     'X_Coord': 3115832.95607,
#     'Y_Coord': 13866716.49565,
#     'Zip_Code': '77022',
#     'Time_Frame': 2,
#     'SNB_No': 45,
#     'SNB_Name': 'NORTHSIDE/NORTHLINE',
#     'Council_District': 'H',
#     'HPD_Division': 'North Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.38082655494368, 29.828978489304113]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2029,
#     'Join_Count': 1,
#     'TARGET_FID': 2029,
#     'Join_Count_1': 1,
#     'Incident_No': 30441019,
#     'Time_Begun': '2019-03-10T10:00:00.000Z',
#     'UCR_No': 6191,
#     'HPD_Beat': '15E40',
#     'HPD_District': '15',
#     'Offense': 'Theft',
#     'Address_Range': '8400-8499 FANNIN',
#     'Premise_Type': 'Stadium, Sports Arena, Ra',
#     'X_Coord': 3110368.0172,
#     'Y_Coord': 13813523.25688,
#     'Zip_Code': '77054',
#     'Time_Frame': 3,
#     'SNB_No': 34,
#     'SNB_Name': 'ASTRODOME AREA',
#     'Council_District': 'K',
#     'HPD_Division': 'Southwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.40321324129363, 29.683229712407194]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2030,
#     'Join_Count': 1,
#     'TARGET_FID': 2030,
#     'Join_Count_1': 1,
#     'Incident_No': 29194319,
#     'Time_Begun': '2019-03-07T08:15:00.000Z',
#     'UCR_No': 5021,
#     'HPD_Beat': '20G30',
#     'HPD_District': '20',
#     'Offense': 'Burglary',
#     'Address_Range': '2700-2799 WALLINGFORD',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3058832.25999,
#     'Y_Coord': 13830592.86995,
#     'Zip_Code': '77042',
#     'Time_Frame': 3,
#     'SNB_No': 19,
#     'SNB_Name': 'WESTCHASE',
#     'Council_District': 'F',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.56387196850247, 29.734411468772215]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2031,
#     'Join_Count': 1,
#     'TARGET_FID': 2031,
#     'Join_Count_1': 1,
#     'Incident_No': 27802619,
#     'Time_Begun': '2019-03-04T02:00:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '18F50',
#     'HPD_District': '18',
#     'Offense': 'Theft',
#     'Address_Range': '6700-6799 SOUTHWEST ',
#     'Premise_Type': 'Hotel or Motel Parking Lo',
#     'X_Coord': 3078531.98899,
#     'Y_Coord': 13823856.16107,
#     'Zip_Code': '77036',
#     'Time_Frame': 3,
#     'SNB_No': 26,
#     'SNB_Name': 'SHARPSTOWN',
#     'Council_District': 'J',
#     'HPD_Division': 'Midwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.50246052477443, 29.714287724526876]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2032,
#     'Join_Count': 1,
#     'TARGET_FID': 2032,
#     'Join_Count_1': 1,
#     'Incident_No': 30978219,
#     'Time_Begun': '2019-03-11T13:00:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '12D70',
#     'HPD_District': '12',
#     'Offense': 'Theft',
#     'Address_Range': '500-599 BAYBROOK MALL',
#     'Premise_Type': 'Mall Parking Lot',
#     'X_Coord': 3193759.65036,
#     'Y_Coord': 13765293.59997,
#     'Zip_Code': '77546',
#     'Time_Frame': 3,
#     'SNB_No': 81,
#     'SNB_Name': 'CLEAR LAKE',
#     'Council_District': 'E',
#     'HPD_Division': 'Clear Lake Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.14572497102509, 29.543355609466264]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2033,
#     'Join_Count': 1,
#     'TARGET_FID': 2033,
#     'Join_Count_1': 1,
#     'Incident_No': 30045919,
#     'Time_Begun': '2019-03-08T19:00:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '1A20',
#     'HPD_District': '1',
#     'Offense': 'Theft',
#     'Address_Range': '700-799 FAIRVIEW',
#     'Premise_Type': 'Commercial Parking Lot or',
#     'X_Coord': 3114145.68633,
#     'Y_Coord': 13837260.68619,
#     'Zip_Code': '77006',
#     'Time_Frame': 3,
#     'SNB_No': 24,
#     'SNB_Name': 'NEARTOWN - MONTROSE',
#     'Council_District': 'C',
#     'HPD_Division': 'Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.38901352083217, 29.74815754494665]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2034,
#     'Join_Count': 1,
#     'TARGET_FID': 2034,
#     'Join_Count_1': 1,
#     'Incident_No': 25935119,
#     'Time_Begun': '2019-02-28T12:20:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '2A30',
#     'HPD_District': '2',
#     'Offense': 'Theft',
#     'Address_Range': '1200-1299 ASHLAND',
#     'Premise_Type': 'Driveway',
#     'X_Coord': 3109071.21727,
#     'Y_Coord': 13853416.91424,
#     'Zip_Code': None,
#     'Time_Frame': 3,
#     'SNB_No': 15,
#     'SNB_Name': 'GREATER HEIGHTS',
#     'Council_District': 'C',
#     'HPD_Division': 'Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.40343224845212, 29.792996015823284]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2035,
#     'Join_Count': 1,
#     'TARGET_FID': 2035,
#     'Join_Count_1': 1,
#     'Incident_No': 29179119,
#     'Time_Begun': '2019-03-07T12:00:00.000Z',
#     'UCR_No': 5021,
#     'HPD_Beat': '17E20',
#     'HPD_District': '17',
#     'Offense': 'Burglary',
#     'Address_Range': '7600-7699 S BRAESWOOD',
#     'Premise_Type': 'Residence or House',
#     'X_Coord': 3075286.30036,
#     'Y_Coord': 13808980.37623,
#     'Zip_Code': '77071',
#     'Time_Frame': 3,
#     'SNB_No': 36,
#     'SNB_Name': 'BRAYS OAKS',
#     'Council_District': 'K',
#     'HPD_Division': 'South Gessner Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.5140778132344, 29.673663154286576]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2036,
#     'Join_Count': 1,
#     'TARGET_FID': 2036,
#     'Join_Count_1': 1,
#     'Incident_No': 34666619,
#     'Time_Begun': '2019-03-15T21:00:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '4F30',
#     'HPD_District': '4',
#     'Offense': 'Theft',
#     'Address_Range': '1300-1399 LANGHAM CREEK',
#     'Premise_Type': 'Other Parking Lot',
#     'X_Coord': 3024400.03375,
#     'Y_Coord': 13848740.14899,
#     'Zip_Code': '77084',
#     'Time_Frame': 2,
#     'SNB_No': 9,
#     'SNB_Name': 'ADDICKS PARK TEN',
#     'Council_District': 'A',
#     'HPD_Division': 'Northwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.67069650175073, 29.78703417117377]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2037,
#     'Join_Count': 1,
#     'TARGET_FID': 2037,
#     'Join_Count_1': 1,
#     'Incident_No': 25428719,
#     'Time_Begun': '2019-02-27T10:55:00.000Z',
#     'UCR_No': 6073,
#     'HPD_Beat': '2A30',
#     'HPD_District': '2',
#     'Offense': 'Theft',
#     'Address_Range': '900-999 N SHEPHERD',
#     'Premise_Type': 'Department or Discount St',
#     'X_Coord': 3107104.05439,
#     'Y_Coord': 13851393.28371,
#     'Zip_Code': '77008',
#     'Time_Frame': 3,
#     'SNB_No': 15,
#     'SNB_Name': 'GREATER HEIGHTS',
#     'Council_District': 'C',
#     'HPD_Division': 'Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.40982725263025, 29.787599878077206]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2038,
#     'Join_Count': 1,
#     'TARGET_FID': 2038,
#     'Join_Count_1': 1,
#     'Incident_No': 26988919,
#     'Time_Begun': '2019-03-02T18:30:00.000Z',
#     'UCR_No': 4042,
#     'HPD_Beat': '8C50',
#     'HPD_District': '8',
#     'Offense': 'Aggravated Assault',
#     'Address_Range': '8700-8799 TIDWELL',
#     'Premise_Type': 'Road, Street, or Sidewalk',
#     'X_Coord': 3153122.23313,
#     'Y_Coord': 13875559.22557,
#     'Zip_Code': '77028',
#     'Time_Frame': 3,
#     'SNB_No': 49,
#     'SNB_Name': 'EAST HOUSTON',
#     'Council_District': 'B',
#     'HPD_Division': 'Northeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.26238779602147, 29.85005876645183]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2039,
#     'Join_Count': 1,
#     'TARGET_FID': 2039,
#     'Join_Count_1': 1,
#     'Incident_No': 26376519,
#     'Time_Begun': '2019-02-28T10:00:00.000Z',
#     'UCR_No': 7001,
#     'HPD_Beat': '18F50',
#     'HPD_District': '18',
#     'Offense': 'Auto Theft',
#     'Address_Range': '4000-4099 JEANETTA',
#     'Premise_Type': 'Road, Street, or Sidewalk',
#     'X_Coord': 3071267.34533,
#     'Y_Coord': 13826136.12975,
#     'Zip_Code': '77063',
#     'Time_Frame': 3,
#     'SNB_No': 20,
#     'SNB_Name': 'MID WEST',
#     'Council_District': 'J',
#     'HPD_Division': 'Midwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.52512345017374, 29.721150384015232]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2040,
#     'Join_Count': 1,
#     'TARGET_FID': 2040,
#     'Join_Count_1': 1,
#     'Incident_No': 25533019,
#     'Time_Begun': '2019-02-27T07:00:00.000Z',
#     'UCR_No': 5022,
#     'HPD_Beat': '16E40',
#     'HPD_District': '16',
#     'Offense': 'Burglary',
#     'Address_Range': '15700-15799 RAYNOR',
#     'Premise_Type': 'Residence or House',
#     'X_Coord': 3085258.17497,
#     'Y_Coord': 13782174.18071,
#     'Zip_Code': '77489',
#     'Time_Frame': 3,
#     'SNB_No': 41,
#     'SNB_Name': 'FORT BEND HOUSTON',
#     'Council_District': 'K',
#     'HPD_Division': 'Southwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.48522587691119, 29.599155875372173]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2041,
#     'Join_Count': 1,
#     'TARGET_FID': 2041,
#     'Join_Count_1': 1,
#     'Incident_No': 26324619,
#     'Time_Begun': '2019-02-28T12:30:00.000Z',
#     'UCR_No': 5061,
#     'HPD_Beat': '20G70',
#     'HPD_District': '20',
#     'Offense': 'Burglary',
#     'Address_Range': '3900-3999 ASHBURNHAM',
#     'Premise_Type': 'Maintenance or Building S',
#     'X_Coord': 3044373.55976,
#     'Y_Coord': 13823743.94047,
#     'Zip_Code': '77082',
#     'Time_Frame': 3,
#     'SNB_No': 17,
#     'SNB_Name': 'ELDRIDGE / WEST OAKS',
#     'Council_District': 'F',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.61003772195654, 29.716744930366826]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2042,
#     'Join_Count': 1,
#     'TARGET_FID': 2042,
#     'Join_Count_1': 1,
#     'Incident_No': 25587919,
#     'Time_Begun': '2019-02-27T17:01:00.000Z',
#     'UCR_No': 5021,
#     'HPD_Beat': '15E10',
#     'HPD_District': '15',
#     'Offense': 'Burglary',
#     'Address_Range': '9700-9799 GLENFIELD',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3081022.73395,
#     'Y_Coord': 13809438.65122,
#     'Zip_Code': '77096',
#     'Time_Frame': 3,
#     'SNB_No': 31,
#     'SNB_Name': 'MEYERLAND AREA',
#     'Council_District': 'C',
#     'HPD_Division': 'Southwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.49597791323306, 29.674451511139637]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2043,
#     'Join_Count': 1,
#     'TARGET_FID': 2043,
#     'Join_Count_1': 1,
#     'Incident_No': 25579919,
#     'Time_Begun': '2019-02-26T21:00:00.000Z',
#     'UCR_No': 6131,
#     'HPD_Beat': '3B30',
#     'HPD_District': '3',
#     'Offense': 'Theft',
#     'Address_Range': '1000-1099 ROSEPOINT',
#     'Premise_Type': 'Road, Street, or Sidewalk',
#     'X_Coord': 3101664.09717,
#     'Y_Coord': 13863841.69236,
#     'Zip_Code': '77018',
#     'Time_Frame': 3,
#     'SNB_No': 12,
#     'SNB_Name': 'CENTRAL NORTHWEST',
#     'Council_District': 'C',
#     'HPD_Division': 'North Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.42577028565677, 29.822274745524815]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2044,
#     'Join_Count': 1,
#     'TARGET_FID': 2044,
#     'Join_Count_1': 1,
#     'Incident_No': 25589519,
#     'Time_Begun': '2019-02-27T12:40:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '4F20',
#     'HPD_District': '4',
#     'Offense': 'Theft',
#     'Address_Range': '4600-4699 WESTWAY PARK',
#     'Premise_Type': 'Commercial Parking Lot or',
#     'X_Coord': 3059350.8412,
#     'Y_Coord': 13868127.22282,
#     'Zip_Code': '77041',
#     'Time_Frame': 3,
#     'SNB_No': 8,
#     'SNB_Name': 'WESTBRANCH',
#     'Council_District': 'A',
#     'HPD_Division': 'Northwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.55875904633696, 29.837543921038066]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2045,
#     'Join_Count': 1,
#     'TARGET_FID': 2045,
#     'Join_Count_1': 1,
#     'Incident_No': 28816119,
#     'Time_Begun': '2019-03-06T17:00:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '1A50',
#     'HPD_District': '1',
#     'Offense': 'Theft',
#     'Address_Range': '4300-4399 WESTHEIMER',
#     'Premise_Type': 'Strip Business Center Par',
#     'X_Coord': 3094809.08813,
#     'Y_Coord': 13834255.93948,
#     'Zip_Code': '77027',
#     'Time_Frame': 3,
#     'SNB_No': 23,
#     'SNB_Name': 'AFTON OAKS / RIVER OAKS AREA',
#     'Council_District': 'G',
#     'HPD_Division': 'Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.45021073923284, 29.741526004927454]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2046,
#     'Join_Count': 1,
#     'TARGET_FID': 2046,
#     'Join_Count_1': 1,
#     'Incident_No': 32325119,
#     'Time_Begun': '2019-03-12T00:01:00.000Z',
#     'UCR_No': 6193,
#     'HPD_Beat': '20G10',
#     'HPD_District': '20',
#     'Offense': 'Theft',
#     'Address_Range': '3500-3599 WOODCHASE',
#     'Premise_Type': 'Other, Unknown, or Not Li',
#     'X_Coord': 3064831.45883,
#     'Y_Coord': 13827681.99545,
#     'Zip_Code': '77042',
#     'Time_Frame': 3,
#     'SNB_No': 19,
#     'SNB_Name': 'WESTCHASE',
#     'Council_District': 'F',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.54524762353853, 29.725923979303207]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2047,
#     'Join_Count': 1,
#     'TARGET_FID': 2047,
#     'Join_Count_1': 1,
#     'Incident_No': 25511119,
#     'Time_Begun': '2019-02-27T10:00:00.000Z',
#     'UCR_No': 5021,
#     'HPD_Beat': '20G10',
#     'HPD_District': '20',
#     'Offense': 'Burglary',
#     'Address_Range': '8700-8799 TOWN PARK',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3066754.99581,
#     'Y_Coord': 13823265.33236,
#     'Zip_Code': '77036',
#     'Time_Frame': 3,
#     'SNB_No': 26,
#     'SNB_Name': 'SHARPSTOWN',
#     'Council_District': 'F',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.53960139254465, 29.713626927959105]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2048,
#     'Join_Count': 1,
#     'TARGET_FID': 2048,
#     'Join_Count_1': 1,
#     'Incident_No': 250674119,
#     'Time_Begun': '2019-02-24T03:41:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '2A40',
#     'HPD_District': '2',
#     'Offense': 'Theft',
#     'Address_Range': '2400-2499 WASHINGTON',
#     'Premise_Type': 'Apartment Parking Lot',
#     'X_Coord': 3115863.84807,
#     'Y_Coord': 13844648.15279,
#     'Zip_Code': '77007',
#     'Time_Frame': 3,
#     'SNB_No': 22,
#     'SNB_Name': 'WASHINGTON AVENUE COALITION / MEMORIAL PARK',
#     'Council_District': 'H',
#     'HPD_Division': 'Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.38288151141911, 29.76831745802356]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2049,
#     'Join_Count': 1,
#     'TARGET_FID': 2049,
#     'Join_Count_1': 1,
#     'Incident_No': 25559519,
#     'Time_Begun': '2019-02-27T15:00:00.000Z',
#     'UCR_No': 6071,
#     'HPD_Beat': '20G50',
#     'HPD_District': '20',
#     'Offense': 'Theft',
#     'Address_Range': '300-399 MEMORIAL CITY',
#     'Premise_Type': 'Department or Discount St',
#     'X_Coord': 3067210.99569,
#     'Y_Coord': 13847226.49532,
#     'Zip_Code': '77024',
#     'Time_Frame': 3,
#     'SNB_No': 16,
#     'SNB_Name': 'MEMORIAL',
#     'Council_District': 'G',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.53592988978062, 29.779454568299624]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2050,
#     'Join_Count': 1,
#     'TARGET_FID': 2050,
#     'Join_Count_1': 1,
#     'Incident_No': 33295319,
#     'Time_Begun': '2019-03-16T12:00:00.000Z',
#     'UCR_No': 5021,
#     'HPD_Beat': '13D20',
#     'HPD_District': '13',
#     'Offense': 'Burglary',
#     'Address_Range': '7000-7099 AIRPORT',
#     'Premise_Type': 'Residence or House',
#     'X_Coord': 3142468.8008,
#     'Y_Coord': 13801940.6214,
#     'Zip_Code': '77061',
#     'Time_Frame': 2,
#     'SNB_No': 73,
#     'SNB_Name': 'GOLFCREST / BELLFORT / REVEILLE',
#     'Council_District': 'I',
#     'HPD_Division': 'Southeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.3033175740117, 29.64863979057961]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2051,
#     'Join_Count': 1,
#     'TARGET_FID': 2051,
#     'Join_Count_1': 1,
#     'Incident_No': 28666319,
#     'Time_Begun': '2019-03-06T14:00:00.000Z',
#     'UCR_No': 6191,
#     'HPD_Beat': '18F30',
#     'HPD_District': '18',
#     'Offense': 'Theft',
#     'Address_Range': '6200-6299 WESTPARK',
#     'Premise_Type': 'Other, Unknown, or Not Li',
#     'X_Coord': 3081177.55852,
#     'Y_Coord': 13827320.09298,
#     'Zip_Code': '77057',
#     'Time_Frame': 3,
#     'SNB_No': 20,
#     'SNB_Name': 'MID WEST',
#     'Council_District': 'J',
#     'HPD_Division': 'Midwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.49380259755117, 29.72359158558776]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2052,
#     'Join_Count': 1,
#     'TARGET_FID': 2052,
#     'Join_Count_1': 1,
#     'Incident_No': 34665219,
#     'Time_Begun': '2019-03-19T11:00:00.000Z',
#     'UCR_No': 6191,
#     'HPD_Beat': '5F10',
#     'HPD_District': '5',
#     'Offense': 'Theft',
#     'Address_Range': '7600-7699 JALNA',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3084919.47244,
#     'Y_Coord': 13855963.84845,
#     'Zip_Code': '77055',
#     'Time_Frame': 2,
#     'SNB_No': 86,
#     'SNB_Name': 'SPRING BRANCH EAST',
#     'Council_District': 'A',
#     'HPD_Division': 'Northwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.47930201101121, 29.802017434282003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2053,
#     'Join_Count': 1,
#     'TARGET_FID': 2053,
#     'Join_Count_1': 1,
#     'Incident_No': 29916219,
#     'Time_Begun': '2019-03-09T07:04:00.000Z',
#     'UCR_No': 3001,
#     'HPD_Beat': '5F20',
#     'HPD_District': '5',
#     'Offense': 'Robbery',
#     'Address_Range': '8800-8899 ALCOTT',
#     'Premise_Type': 'Road, Street, or Sidewalk',
#     'X_Coord': 3075132.00337,
#     'Y_Coord': 13861154.47175,
#     'Zip_Code': '77080',
#     'Time_Frame': 3,
#     'SNB_No': 85,
#     'SNB_Name': 'SPRING BRANCH CENTRAL',
#     'Council_District': 'A',
#     'HPD_Division': 'Northwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.50966068861777, 29.817091717193847]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2054,
#     'Join_Count': 1,
#     'TARGET_FID': 2054,
#     'Join_Count_1': 1,
#     'Incident_No': 24408119,
#     'Time_Begun': '2019-02-22T05:30:00.000Z',
#     'UCR_No': 5031,
#     'HPD_Beat': '18F30',
#     'HPD_District': '18',
#     'Offense': 'Burglary',
#     'Address_Range': '5700-5799 SAN FELIPE',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3085549.41476,
#     'Y_Coord': 13837074.08224,
#     'Zip_Code': '77057',
#     'Time_Frame': 3,
#     'SNB_No': 21,
#     'SNB_Name': 'GREATER UPTOWN',
#     'Council_District': 'G',
#     'HPD_Division': 'Midwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.47910950524553, 29.7500420584885]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2055,
#     'Join_Count': 1,
#     'TARGET_FID': 2055,
#     'Join_Count_1': 1,
#     'Incident_No': 24407119,
#     'Time_Begun': '2019-02-24T14:30:00.000Z',
#     'UCR_No': 5031,
#     'HPD_Beat': '17E40',
#     'HPD_District': '17',
#     'Offense': 'Burglary',
#     'Address_Range': '6300-6399 W AIRPORT',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3079302.44798,
#     'Y_Coord': 13798431.25156,
#     'Zip_Code': '77035',
#     'Time_Frame': 3,
#     'SNB_No': 36,
#     'SNB_Name': 'BRAYS OAKS',
#     'Council_District': 'K',
#     'HPD_Division': 'South Gessner Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.5024294544004, 29.64433542255002]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2056,
#     'Join_Count': 1,
#     'TARGET_FID': 2056,
#     'Join_Count_1': 1,
#     'Incident_No': 24390419,
#     'Time_Begun': '2019-02-24T00:01:00.000Z',
#     'UCR_No': 6131,
#     'HPD_Beat': '19G50',
#     'HPD_District': '19',
#     'Offense': 'Theft',
#     'Address_Range': '10200-10299 BISSONNET',
#     'Premise_Type': 'Apartment Parking Lot',
#     'X_Coord': 3061276.69722,
#     'Y_Coord': 13808974.15989,
#     'Zip_Code': '77036',
#     'Time_Frame': 3,
#     'SNB_No': 29,
#     'SNB_Name': 'WESTWOOD',
#     'Council_District': 'J',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.55817734834177, 29.6747870102184]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2057,
#     'Join_Count': 1,
#     'TARGET_FID': 2057,
#     'Join_Count_1': 1,
#     'Incident_No': 24445019,
#     'Time_Begun': '2019-02-25T05:00:00.000Z',
#     'UCR_No': 5041,
#     'HPD_Beat': '16E30',
#     'HPD_District': '16',
#     'Offense': 'Burglary',
#     'Address_Range': '7400-7499 S SAM HOUSTON PKWY W ',
#     'Premise_Type': 'Specialty Store (Non-Spec',
#     'X_Coord': 3080669.9634,
#     'Y_Coord': 13788436.57385,
#     'Zip_Code': '77085',
#     'Time_Frame': 3,
#     'SNB_No': 39,
#     'SNB_Name': 'FONDREN GARDENS',
#     'Council_District': 'K',
#     'HPD_Division': 'Southwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.49906791574705, 29.616748846976584]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2058,
#     'Join_Count': 1,
#     'TARGET_FID': 2058,
#     'Join_Count_1': 1,
#     'Incident_No': 24442119,
#     'Time_Begun': '2019-02-25T04:20:00.000Z',
#     'UCR_No': 4041,
#     'HPD_Beat': '22B20',
#     'HPD_District': '22',
#     'Offense': 'Aggravated Assault',
#     'Address_Range': '12800-12899 NORTHBOROUGH',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3101190.32172,
#     'Y_Coord': 13911717.7953,
#     'Zip_Code': '77067',
#     'Time_Frame': 3,
#     'SNB_No': 2,
#     'SNB_Name': 'GREATER GREENSPOINT',
#     'Council_District': 'B',
#     'HPD_Division': 'North Belt Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.42264597102825, 29.95390761198493]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2059,
#     'Join_Count': 1,
#     'TARGET_FID': 2059,
#     'Join_Count_1': 1,
#     'Incident_No': 25695119,
#     'Time_Begun': '2019-02-27T21:47:00.000Z',
#     'UCR_No': 6031,
#     'HPD_Beat': '5F10',
#     'HPD_District': '5',
#     'Offense': 'Theft',
#     'Address_Range': '7600-7699 KATY ',
#     'Premise_Type': 'Commercial Parking Lot or',
#     'X_Coord': 3089360.89532,
#     'Y_Coord': 13849655.17177,
#     'Zip_Code': '77055',
#     'Time_Frame': 3,
#     'SNB_No': 86,
#     'SNB_Name': 'SPRING BRANCH EAST',
#     'Council_District': 'A',
#     'HPD_Division': 'Northwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.46590519858239, 29.784308248588456]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2060,
#     'Join_Count': 1,
#     'TARGET_FID': 2060,
#     'Join_Count_1': 1,
#     'Incident_No': 25698419,
#     'Time_Begun': '2019-02-27T21:00:00.000Z',
#     'UCR_No': 6131,
#     'HPD_Beat': '4F10',
#     'HPD_District': '4',
#     'Offense': 'Theft',
#     'Address_Range': '9700-9799 KATY ',
#     'Premise_Type': 'Restaurant or Cafeteria P',
#     'X_Coord': 3067688.19825,
#     'Y_Coord': 13849062.25432,
#     'Zip_Code': '77055',
#     'Time_Frame': 3,
#     'SNB_No': 10,
#     'SNB_Name': 'SPRING BRANCH WEST',
#     'Council_District': 'A',
#     'HPD_Division': 'Northwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.5342547503595, 29.784461799610288]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2061,
#     'Join_Count': 1,
#     'TARGET_FID': 2061,
#     'Join_Count_1': 1,
#     'Incident_No': 23889119,
#     'Time_Begun': '2019-02-22T14:00:00.000Z',
#     'UCR_No': 6131,
#     'HPD_Beat': '18F50',
#     'HPD_District': '18',
#     'Offense': 'Theft',
#     'Address_Range': '8700-8799 PAGEWOOD',
#     'Premise_Type': 'Vehicle/Auto Sales/Lease/',
#     'X_Coord': 3073691.10061,
#     'Y_Coord': 13828134.38057,
#     'Zip_Code': '77063',
#     'Time_Frame': 3,
#     'SNB_No': 20,
#     'SNB_Name': 'MID WEST',
#     'Council_District': 'J',
#     'HPD_Division': 'Midwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.51730311243251, 29.72644497554092]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2062,
#     'Join_Count': 1,
#     'TARGET_FID': 2062,
#     'Join_Count_1': 1,
#     'Incident_No': 22936419,
#     'Time_Begun': '2019-02-21T18:53:00.000Z',
#     'UCR_No': 6073,
#     'HPD_Beat': '12D70',
#     'HPD_District': '12',
#     'Offense': 'Theft',
#     'Address_Range': '100-199 W EL DORADO',
#     'Premise_Type': 'Department or Discount St',
#     'X_Coord': 3190195.88768,
#     'Y_Coord': 13768189.90466,
#     'Zip_Code': '77546',
#     'Time_Frame': 3,
#     'SNB_No': 81,
#     'SNB_Name': 'CLEAR LAKE',
#     'Council_District': 'E',
#     'HPD_Division': 'Clear Lake Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.15662806688702, 29.551639063710873]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2063,
#     'Join_Count': 1,
#     'TARGET_FID': 2063,
#     'Join_Count_1': 1,
#     'Incident_No': 23892419,
#     'Time_Begun': '2019-02-23T18:10:00.000Z',
#     'UCR_No': 5001,
#     'HPD_Beat': '18F50',
#     'HPD_District': '18',
#     'Offense': 'Burglary',
#     'Address_Range': '3400-3499 OCEE',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3070049.92647,
#     'Y_Coord': 13828950.31559,
#     'Zip_Code': '77063',
#     'Time_Frame': 3,
#     'SNB_No': 20,
#     'SNB_Name': 'MID WEST',
#     'Council_District': 'F',
#     'HPD_Division': 'Midwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.52869422405152, 29.728985488989743]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2064,
#     'Join_Count': 1,
#     'TARGET_FID': 2064,
#     'Join_Count_1': 1,
#     'Incident_No': 31889119,
#     'Time_Begun': '2019-03-12T23:00:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '9C20',
#     'HPD_District': '9',
#     'Offense': 'Theft',
#     'Address_Range': '200-299 LATHROP',
#     'Premise_Type': 'Driveway',
#     'X_Coord': 3141590.28048,
#     'Y_Coord': 13851514.95626,
#     'Zip_Code': None,
#     'Time_Frame': 3,
#     'SNB_No': 56,
#     'SNB_Name': 'DENVER HARBOR / PORT HOUSTON',
#     'Council_District': 'H',
#     'HPD_Division': 'Northeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.30114657784729, 29.784979419805538]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2065,
#     'Join_Count': 1,
#     'TARGET_FID': 2065,
#     'Join_Count_1': 1,
#     'Incident_No': 23152619,
#     'Time_Begun': '2019-02-21T21:40:00.000Z',
#     'UCR_No': 6001,
#     'HPD_Beat': '17E10',
#     'HPD_District': '17',
#     'Offense': 'Theft',
#     'Address_Range': '5400-5499 S RICE',
#     'Premise_Type': 'Grocery Store or Supermar',
#     'X_Coord': 3089304.21084,
#     'Y_Coord': 13827763.66343,
#     'Zip_Code': '77081',
#     'Time_Frame': 3,
#     'SNB_No': 27,
#     'SNB_Name': 'GULFTON',
#     'Council_District': 'J',
#     'HPD_Division': 'South Gessner Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.46816767244098, 29.724138508409798]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2066,
#     'Join_Count': 1,
#     'TARGET_FID': 2066,
#     'Join_Count_1': 1,
#     'Incident_No': 25683619,
#     'Time_Begun': '2019-02-27T18:00:00.000Z',
#     'UCR_No': 6143,
#     'HPD_Beat': '20G60',
#     'HPD_District': '20',
#     'Offense': 'Theft',
#     'Address_Range': '14600-14699 GRISBY',
#     'Premise_Type': 'Bar or Night Club Parking',
#     'X_Coord': 3033122.04422,
#     'Y_Coord': 13847366.84261,
#     'Zip_Code': '77079',
#     'Time_Frame': 3,
#     'SNB_No': 16,
#     'SNB_Name': 'MEMORIAL',
#     'Council_District': 'G',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.64333480445828, 29.782573618170616]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2067,
#     'Join_Count': 1,
#     'TARGET_FID': 2067,
#     'Join_Count_1': 1,
#     'Incident_No': 33662619,
#     'Time_Begun': '2019-03-17T01:30:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '2A50',
#     'HPD_District': '2',
#     'Offense': 'Theft',
#     'Address_Range': '4900-4999 SCHULER',
#     'Premise_Type': 'Road, Street, or Sidewalk',
#     'X_Coord': 3107005.42673,
#     'Y_Coord': 13845946.88919,
#     'Zip_Code': '77007',
#     'Time_Frame': 2,
#     'SNB_No': 22,
#     'SNB_Name': 'WASHINGTON AVENUE COALITION / MEMORIAL PARK',
#     'Council_District': 'C',
#     'HPD_Division': 'Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.41066494272461, 29.772637714939293]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2068,
#     'Join_Count': 1,
#     'TARGET_FID': 2068,
#     'Join_Count_1': 1,
#     'Incident_No': 25681919,
#     'Time_Begun': '2019-02-27T20:43:00.000Z',
# ...
#     'Zip_Code': '77036',
#     'Time_Frame': 3,
#     'SNB_No': 26,
#     'SNB_Name': 'SHARPSTOWN',
#     'Council_District': 'J',
#     'HPD_Division': 'Midwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.50261109464861, 29.714152941216973]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2979,
#     'Join_Count': 1,
#     'TARGET_FID': 2979,
#     'Join_Count_1': 1,
#     'Incident_No': 31367219,
#     'Time_Begun': '2019-03-11T19:10:00.000Z',
#     'UCR_No': 6143,
#     'HPD_Beat': '20G10',
#     'HPD_District': '20',
#     'Offense': 'Theft',
#     'Address_Range': '6600-6699 W SAM HOUSTON PKWY S',
#     'Premise_Type': 'Other Parking Lot',
#     'X_Coord': 3061388.54536,
#     'Y_Coord': 13820340.27784,
#     'Zip_Code': '77036',
#     'Time_Frame': 3,
#     'SNB_No': 26,
#     'SNB_Name': 'SHARPSTOWN',
#     'Council_District': 'F',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.55677159694903, 29.706021917749926]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2980,
#     'Join_Count': 0,
#     'TARGET_FID': 2980,
#     'Join_Count_1': 0,
#     'Incident_No': 34469119,
#     'Time_Begun': '2019-03-19T07:30:00.000Z',
#     'UCR_No': 5021,
#     'HPD_Beat': '12D30',
#     'HPD_District': '12',
#     'Offense': 'Burglary',
#     'Address_Range': '5100-5199 ALLEN GENOA',
#     'Premise_Type': 'Residence or House',
#     'X_Coord': 3177809.09016,
#     'Y_Coord': 13797747.51241,
#     'Zip_Code': '77504',
#     'Time_Frame': 2,
#     'SNB_No': None,
#     'SNB_Name': None,
#     'Council_District': None,
#     'HPD_Division': None},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.19254232100133, 29.633996753649818]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2981,
#     'Join_Count': 1,
#     'TARGET_FID': 2981,
#     'Join_Count_1': 1,
#     'Incident_No': 30699619,
#     'Time_Begun': '2019-03-10T23:40:00.000Z',
#     'UCR_No': 3002,
#     'HPD_Beat': '22B30',
#     'HPD_District': '22',
#     'Offense': 'Robbery',
#     'Address_Range': '100-199 ALDINE BENDER',
#     'Premise_Type': 'Road, Street, or Sidewalk',
#     'X_Coord': 3107492.38127,
#     'Y_Coord': 13903854.59708,
#     'Zip_Code': '77060',
#     'Time_Frame': 3,
#     'SNB_No': 2,
#     'SNB_Name': 'GREATER GREENSPOINT',
#     'Council_District': 'B',
#     'HPD_Division': 'North Belt Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.4035182308012, 29.931763719089993]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2982,
#     'Join_Count': 1,
#     'TARGET_FID': 2982,
#     'Join_Count_1': 1,
#     'Incident_No': 30715719,
#     'Time_Begun': '2019-03-11T00:25:00.000Z',
#     'UCR_No': 4041,
#     'HPD_Beat': '6B30',
#     'HPD_District': '6',
#     'Offense': 'Aggravated Assault',
#     'Address_Range': '7600-7699 YELLOW PINE',
#     'Premise_Type': 'Road, Street, or Sidewalk',
#     'X_Coord': 3075817.88968,
#     'Y_Coord': 13886796.29641,
#     'Zip_Code': '77040',
#     'Time_Frame': 3,
#     'SNB_No': 5,
#     'SNB_Name': 'GREATER INWOOD',
#     'Council_District': 'A',
#     'HPD_Division': 'North Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.50508255248494, 29.887517255139716]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2983,
#     'Join_Count': 1,
#     'TARGET_FID': 2983,
#     'Join_Count_1': 1,
#     'Incident_No': 30712519,
#     'Time_Begun': '2019-03-10T23:30:00.000Z',
#     'UCR_No': 4041,
#     'HPD_Beat': '4F20',
#     'HPD_District': '4',
#     'Offense': 'Aggravated Assault',
#     'Address_Range': '2200-2299 SHADOWDALE',
#     'Premise_Type': 'Road, Street, or Sidewalk',
#     'X_Coord': 3060997.44795,
#     'Y_Coord': 13859305.89221,
#     'Zip_Code': '77043',
#     'Time_Frame': 3,
#     'SNB_No': 84,
#     'SNB_Name': 'SPRING BRANCH NORTH',
#     'Council_District': 'A',
#     'HPD_Division': 'Northwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.55438722485827, 29.813162863236336]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2984,
#     'Join_Count': 1,
#     'TARGET_FID': 2984,
#     'Join_Count_1': 1,
#     'Incident_No': 27753519,
#     'Time_Begun': '2019-03-04T13:18:00.000Z',
#     'UCR_No': 6031,
#     'HPD_Beat': '22B30',
#     'HPD_District': '22',
#     'Offense': 'Theft',
#     'Address_Range': '100-199 WEST ',
#     'Premise_Type': 'Restaurant or Cafeteria',
#     'X_Coord': 3105991.63548,
#     'Y_Coord': 13897769.96512,
#     'Zip_Code': None,
#     'Time_Frame': 3,
#     'SNB_No': 2,
#     'SNB_Name': 'GREATER GREENSPOINT',
#     'Council_District': 'H',
#     'HPD_Division': 'North Belt Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.40884378945519, 29.915166463750676]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2985,
#     'Join_Count': 1,
#     'TARGET_FID': 2985,
#     'Join_Count_1': 1,
#     'Incident_No': 34280419,
#     'Time_Begun': '2019-03-16T20:00:00.000Z',
#     'UCR_No': 6151,
#     'HPD_Beat': '3B30',
#     'HPD_District': '3',
#     'Offense': 'Theft',
#     'Address_Range': '1400-1499 STONECREST',
#     'Premise_Type': 'Residence or House',
#     'X_Coord': 3101725.62108,
#     'Y_Coord': 13861180.69382,
#     'Zip_Code': '77018',
#     'Time_Frame': 2,
#     'SNB_No': 12,
#     'SNB_Name': 'CENTRAL NORTHWEST',
#     'Council_District': 'C',
#     'HPD_Division': 'North Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.42583277776416, 29.814955349621584]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2986,
#     'Join_Count': 1,
#     'TARGET_FID': 2986,
#     'Join_Count_1': 1,
#     'Incident_No': 33458919,
#     'Time_Begun': '2019-03-16T22:27:00.000Z',
#     'UCR_No': 4013,
#     'HPD_Beat': '6B40',
#     'HPD_District': '6',
#     'Offense': 'Aggravated Assault',
#     'Address_Range': '1100-1199 S VICTORY',
#     'Premise_Type': 'Road, Street, or Sidewalk',
#     'X_Coord': 3099883.1855,
#     'Y_Coord': 13881443.2589,
#     'Zip_Code': '77088',
#     'Time_Frame': 2,
#     'SNB_No': 6,
#     'SNB_Name': 'ACRES HOME',
#     'Council_District': 'B',
#     'HPD_Division': 'North Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.42968978979545, 29.870804950603418]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2987,
#     'Join_Count': 1,
#     'TARGET_FID': 2987,
#     'Join_Count_1': 1,
#     'Incident_No': 34451619,
#     'Time_Begun': '2019-03-19T08:24:00.000Z',
#     'UCR_No': 3004,
#     'HPD_Beat': '18F30',
#     'HPD_District': '18',
#     'Offense': 'Robbery',
#     'Address_Range': '2700-2799 BRIARGROVE',
#     'Premise_Type': 'Apartment Parking Lot',
#     'X_Coord': 3080557.62382,
#     'Y_Coord': 13832025.40449,
#     'Zip_Code': '77057',
#     'Time_Frame': 2,
#     'SNB_No': 20,
#     'SNB_Name': 'MID WEST',
#     'Council_District': 'J',
#     'HPD_Division': 'Midwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.49531073724212, 29.736576616477937]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2988,
#     'Join_Count': 1,
#     'TARGET_FID': 2988,
#     'Join_Count_1': 1,
#     'Incident_No': 34453119,
#     'Time_Begun': '2019-03-18T06:00:00.000Z',
#     'UCR_No': 5021,
#     'HPD_Beat': '18F20',
#     'HPD_District': '18',
#     'Offense': 'Burglary',
#     'Address_Range': '5000-5099 WOODWAY',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3090293.66755,
#     'Y_Coord': 13841648.36425,
#     'Zip_Code': '77056',
#     'Time_Frame': 2,
#     'SNB_No': 21,
#     'SNB_Name': 'GREATER UPTOWN',
#     'Council_District': 'G',
#     'HPD_Division': 'Midwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.4637290616422, 29.762222078598676]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2989,
#     'Join_Count': 1,
#     'TARGET_FID': 2989,
#     'Join_Count_1': 1,
#     'Incident_No': 33420619,
#     'Time_Begun': '2019-03-16T20:59:00.000Z',
#     'UCR_No': 4043,
#     'HPD_Beat': '19G30',
#     'HPD_District': '19',
#     'Offense': 'Aggravated Assault',
#     'Address_Range': '7800-7899 PACIFIC PEARL',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3048388.88177,
#     'Y_Coord': 13815044.15354,
#     'Zip_Code': '77072',
#     'Time_Frame': 2,
#     'SNB_No': 25,
#     'SNB_Name': 'ALIEF',
#     'Council_District': 'F',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.59819009285374, 29.692509582724437]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2990,
#     'Join_Count': 1,
#     'TARGET_FID': 2990,
#     'Join_Count_1': 1,
#     'Incident_No': 31492419,
#     'Time_Begun': '2019-03-12T17:45:00.000Z',
#     'UCR_No': 4041,
#     'HPD_Beat': '17E30',
#     'HPD_District': '17',
#     'Offense': 'Aggravated Assault',
#     'Address_Range': '9000-9099 S BRAESWOOD',
#     'Premise_Type': 'Miscellaneous Business (N',
#     'X_Coord': 3068941.89659,
#     'Y_Coord': 13808658.80116,
#     'Zip_Code': '77074',
#     'Time_Frame': 3,
#     'SNB_No': 30,
#     'SNB_Name': 'BRAEBURN',
#     'Council_District': 'J',
#     'HPD_Division': 'South Gessner Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.53407839941899, 29.673297676383495]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2991,
#     'Join_Count': 1,
#     'TARGET_FID': 2991,
#     'Join_Count_1': 1,
#     'Incident_No': 34424719,
#     'Time_Begun': '2019-03-19T07:08:00.000Z',
#     'UCR_No': 6193,
#     'HPD_Beat': '18F40',
#     'HPD_District': '18',
#     'Offense': 'Theft',
#     'Address_Range': '9600-9699 WESTHEIMER',
#     'Premise_Type': 'Service or Gas Station',
#     'X_Coord': 3066792.32614,
#     'Y_Coord': 13831836.77119,
#     'Zip_Code': '77063',
#     'Time_Frame': 2,
#     'SNB_No': 20,
#     'SNB_Name': 'MID WEST',
#     'Council_District': 'G',
#     'HPD_Division': 'Midwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.53868476353774, 29.73718531926052]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2992,
#     'Join_Count': 1,
#     'TARGET_FID': 2992,
#     'Join_Count_1': 1,
#     'Incident_No': 34422419,
#     'Time_Begun': '2019-03-19T03:00:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '3B40',
#     'HPD_District': '3',
#     'Offense': 'Theft',
#     'Address_Range': '4300-4399 HAYGOOD',
#     'Premise_Type': 'Residence or House',
#     'X_Coord': 3111769.94214,
#     'Y_Coord': 13866095.76745,
#     'Zip_Code': '77022',
#     'Time_Frame': 2,
#     'SNB_No': 13,
#     'SNB_Name': 'INDEPENDENCE HEIGHTS',
#     'Council_District': 'H',
#     'HPD_Division': 'North Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.39369527008577, 29.82761742358287]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2993,
#     'Join_Count': 1,
#     'TARGET_FID': 2993,
#     'Join_Count_1': 1,
#     'Incident_No': 33304019,
#     'Time_Begun': '2019-03-16T15:40:00.000Z',
#     'UCR_No': 6073,
#     'HPD_Beat': '20G30',
#     'HPD_District': '20',
#     'Offense': 'Theft',
#     'Address_Range': '2700-2799 S KIRKWOOD',
#     'Premise_Type': 'Department or Discount St',
#     'X_Coord': 3050962.19819,
#     'Y_Coord': 13830953.57798,
#     'Zip_Code': '77082',
#     'Time_Frame': 2,
#     'SNB_No': 19,
#     'SNB_Name': 'WESTCHASE',
#     'Council_District': 'F',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.58862686970267, 29.736036508221787]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2994,
#     'Join_Count': 1,
#     'TARGET_FID': 2994,
#     'Join_Count_1': 1,
#     'Incident_No': 34645819,
#     'Time_Begun': '2019-03-19T15:46:00.000Z',
#     'UCR_No': 6073,
#     'HPD_Beat': '2A40',
#     'HPD_District': '2',
#     'Offense': 'Theft',
#     'Address_Range': '2500-2599 SHEARN',
#     'Premise_Type': 'Grocery Store or Supermar',
#     'X_Coord': 3115404.92695,
#     'Y_Coord': 13846892.31763,
#     'Zip_Code': '77007',
#     'Time_Frame': 2,
#     'SNB_No': 22,
#     'SNB_Name': 'WASHINGTON AVENUE COALITION / MEMORIAL PARK',
#     'Council_District': 'H',
#     'HPD_Division': 'Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.38410869301909, 29.77452497861132]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2995,
#     'Join_Count': 1,
#     'TARGET_FID': 2995,
#     'Join_Count_1': 1,
#     'Incident_No': 34418219,
#     'Time_Begun': '2019-03-18T12:00:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '15E40',
#     'HPD_District': '15',
#     'Offense': 'Theft',
#     'Address_Range': '2400-2499 S BRAESWOOD',
#     'Premise_Type': 'Hospital Parking Lot',
#     'X_Coord': 3105971.21254,
#     'Y_Coord': 13818552.30705,
#     'Zip_Code': '77030',
#     'Time_Frame': 2,
#     'SNB_No': 32,
#     'SNB_Name': 'BRAESWOOD',
#     'Council_District': 'K',
#     'HPD_Division': 'Southwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.41656892220644, 29.697424504285273]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2996,
#     'Join_Count': 1,
#     'TARGET_FID': 2996,
#     'Join_Count_1': 1,
#     'Incident_No': 34410019,
#     'Time_Begun': '2019-03-19T01:13:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '22B20',
#     'HPD_District': '22',
#     'Offense': 'Theft',
#     'Address_Range': '1000-1099 GREENS',
#     'Premise_Type': 'Apartment Parking Lot',
#     'X_Coord': 3111886.39339,
#     'Y_Coord': 13910898.36031,
#     'Zip_Code': '77060',
#     'Time_Frame': 2,
#     'SNB_No': 2,
#     'SNB_Name': 'GREATER GREENSPOINT',
#     'Council_District': 'B',
#     'HPD_Division': 'North Belt Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.38896594829944, 29.95075158030781]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2997,
#     'Join_Count': 1,
#     'TARGET_FID': 2997,
#     'Join_Count_1': 1,
#     'Incident_No': 33236019,
#     'Time_Begun': '2019-03-16T10:30:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '2A50',
#     'HPD_District': '2',
#     'Offense': 'Theft',
#     'Address_Range': '900-999 PATTERSON',
#     'Premise_Type': 'Apartment Parking Lot',
#     'X_Coord': 3108472.38933,
#     'Y_Coord': 13845095.75637,
#     'Zip_Code': '77007',
#     'Time_Frame': 2,
#     'SNB_No': 22,
#     'SNB_Name': 'WASHINGTON AVENUE COALITION / MEMORIAL PARK',
#     'Council_District': 'C',
#     'HPD_Division': 'Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.40612542134517, 29.770174333573706]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2998,
#     'Join_Count': 1,
#     'TARGET_FID': 2998,
#     'Join_Count_1': 1,
#     'Incident_No': 30955319,
#     'Time_Begun': '2019-03-11T14:48:00.000Z',
#     'UCR_No': 4041,
#     'HPD_Beat': '3B50',
#     'HPD_District': '3',
#     'Offense': 'Aggravated Assault',
#     'Address_Range': '4400-4499 NORTH ',
#     'Premise_Type': 'Mall Parking Lot',
#     'X_Coord': 3115882.23433,
#     'Y_Coord': 13866598.34899,
#     'Zip_Code': '77022',
#     'Time_Frame': 3,
#     'SNB_No': 45,
#     'SNB_Name': 'NORTHSIDE/NORTHLINE',
#     'Council_District': 'H',
#     'HPD_Division': 'North Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.3806827397452, 29.828649553893804]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2999,
#     'Join_Count': 1,
#     'TARGET_FID': 2999,
#     'Join_Count_1': 1,
#     'Incident_No': 31389219,
#     'Time_Begun': '2019-03-11T19:00:00.000Z',
#     'UCR_No': 6151,
#     'HPD_Beat': '2A10',
#     'HPD_District': '2',
#     'Offense': 'Theft',
#     'Address_Range': '1600-1699 LORRAINE',
#     'Premise_Type': 'Commercial Parking Lot or',
#     'X_Coord': 3125511.58471,
#     'Y_Coord': 13848599.81387,
#     'Zip_Code': '77009',
#     'Time_Frame': 3,
#     'SNB_No': 51,
#     'SNB_Name': 'NEAR NORTHSIDE',
#     'Council_District': 'H',
#     'HPD_Division': 'Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.35209768580218, 29.778355343484005]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 3000,
#     'Join_Count': 1,
#     'TARGET_FID': 3000,
#     'Join_Count_1': 1,
#     'Incident_No': 33733019,
#     'Time_Begun': '2019-03-15T20:00:00.000Z',
#     'UCR_No': 6151,
#     'HPD_Beat': '2A60',
#     'HPD_District': '2',
#     'Offense': 'Theft',
#     'Address_Range': '1000-1099 24TH',
#     'Premise_Type': 'Road, Street, or Sidewalk',
#     'X_Coord': 3114490.71508,
#     'Y_Coord': 13859122.7768,
#     'Zip_Code': None,
#     'Time_Frame': 2,
#     'SNB_No': 15,
#     'SNB_Name': 'GREATER HEIGHTS',
#     'Council_District': 'H',
#     'HPD_Division': 'Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.38579788706205, 29.808220169371115]}},
#   ...]}

# %%
# Convert "hpd_crime_report" to Pandas dataframe
hpd_crime_rpt_pd = pd.DataFrame(hpd_crime_rpt)

# View "hpd_crime_rpt_pd"
hpd_crime_rpt_pd.head()
# Out:
#                 type                                           features
# 0  FeatureCollection  {'type': 'Feature', 'properties': {'OBJECTID':...
# 1  FeatureCollection  {'type': 'Feature', 'properties': {'OBJECTID':...
# 2  FeatureCollection  {'type': 'Feature', 'properties': {'OBJECTID':...
# 3  FeatureCollection  {'type': 'Feature', 'properties': {'OBJECTID':...
# 4  FeatureCollection  {'type': 'Feature', 'properties': {'OBJECTID':...

# %%
# Write "hpd_crime_rpt_pd" to csv file
hpd_crime_rpt_pd.to_csv("../data/rawdata/hpd_crime_report.csv", index=False, header=True)

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# ###### >> Sort out retrieved crime lists

# %%
# Grab "features" data from "hpd_crime_rpt"
crime_list = hpd_crime_rpt["features"]

# Check the length of "crime_list"
print(f"There are {len(crime_list)} crime cases reported in the HPD recent crime report")

# Preview a representative "crime_list" structure
crime_list[0]
# Out:
# There are 7368 crime cases reported in the HPD recent crime report
# {'type': 'Feature',
#  'properties': {'OBJECTID': 2001,
#   'Join_Count': 1,
#   'TARGET_FID': 2001,
#   'Join_Count_1': 1,
#   'Incident_No': 33634519,
#   'Time_Begun': '2019-03-16T20:45:00.000Z',
#   'UCR_No': 7001,
#   'HPD_Beat': '10H70',
#   'HPD_District': '10',
#   'Offense': 'Auto Theft',
#   'Address_Range': '2300-2399 CAMDEN',
#   'Premise_Type': 'Road, Street, or Sidewalk',
#   'X_Coord': 3117097.76176,
#   'Y_Coord': 13823911.50133,
#   'Zip_Code': '77021',
#   'Time_Frame': 2,
#   'SNB_No': 83,
#   'SNB_Name': 'MACGREGOR',
#   'Council_District': 'D',
#   'HPD_Division': 'South Central Division'},
#  'geometry': {'type': 'Point',
#   'coordinates': [-95.38101631427402, 29.711213511623697]}}

# %% [markdown]
# ###### >>Categorize types of crimes reported

# %%
# list to store types of crimes
crime_type = []

# Loop through "crime_list"
for case in crime_list:
    
    # Append unique values of crime types to "crime_type" list
    if case["properties"]["Offense"] not in crime_type:
        crime_type.append(case["properties"]["Offense"])

# View "crime_type"
crime_type
# Out:
# ['Auto Theft',
#  'Theft',
#  'Burglary',
#  'Aggravated Assault',
#  'Robbery',
#  'Rape',
#  'Murder']

# %%
# List for violent crimes
violent_crime = ["Aggravated Assault", "Murder", "Robbery", "Rape"]

# List for non-violent crimes
non_violent_crime = ["Theft", "Burglary", "Auto Theft"]

# %% [markdown]
# ###### >> Slim and clean up crime data

# %%
# Generate a new empty Pandas dataframe with columns of "Offense", "Crime Type", "Lat", and "Lng"
crime_info_pd = pd.DataFrame(columns = ["Offense", "Crime Type", "ZIP", "LAT", "LNG"])

# Check "crime_info_pd"
crime_info_pd
# Out:
# Empty DataFrame
# Columns: [Offense, Crime Type, ZIP, LAT, LNG]
# Index: []

# %%
# List to store date of crime
crime_date = []

# Loop through "crime_list"
for case in crime_list:

    # Note that adding value to column immediately changes the length of "crime_info_pd"
    # Temporarily assign (fix) it to intermediate variable "im" to be referred before each iteration
    im = len(crime_info_pd)
    
    # Append data to "Offense" column of "crime_info_pd"
    crime_info_pd.loc[im, "Offense"] = case["properties"]["Offense"]
    
    # Append data to "Zip" column of "crime_info_pd"
    crime_info_pd.loc[im, "ZIP"] = case["properties"]["Zip_Code"]
    
    # Determine crime type (violent/non-violent) via comparison with "violent_crime" and "non_violent_crime" lists
    if case["properties"]["Offense"] in violent_crime:
        crime_info_pd.loc[im, "Crime Type"] = "Violent"
    if case["properties"]["Offense"] in non_violent_crime:
        crime_info_pd.loc[im, "Crime Type"] = "Non-Violent"
    
    # Append longitude value to "Lng" column
    crime_info_pd.loc[im, "LNG"] = case["geometry"]["coordinates"][0]

    # Append Latitude value to "Lat" column
    crime_info_pd.loc[im, "LAT"] = case["geometry"]["coordinates"][1]   
    
    # Convert date info. into datetime format and temporatorily assign it to "date_im"
    date_im = datetime.datetime.strptime(case["properties"]["Time_Begun"][:10], "%Y-%m-%d")
    # Append date info into "crime_date" list as "yyyy-mm-dd"
    crime_date.append(date_im.strftime("%Y-%m-%d"))
    
# Preview "crime_info_pd"
crime_info_pd.head()
# Out:
#       Offense  Crime Type    ZIP      LAT      LNG
# 0  Auto Theft  Non-Violet  77021  29.7112  -95.381
# 1  Auto Theft  Non-Violet  77546  29.5434 -95.1457
# 2       Theft  Non-Violet  77071  29.6442 -95.5083
# 3       Theft  Non-Violet  77036  29.6753 -95.5507
# 4  Auto Theft  Non-Violet  77075   29.652 -95.2637

# %%
# # Remove cases of crime with missing data if any
# crime_info_pd = crime_info_pd.dropna(how="any")

# Check the length of "crime_info_pd"
len(crime_info_pd)
# Out:
# 7368

# %%
# Print the date range of HPD recent crime data 
date_range = str("from " + min(crime_date) + " to " + max(crime_date))

print("Crime Report" + " " + date_range)
# Out:
# Crime Report from 2019-02-21 to 2019-03-20

# %%
# Write "crime_info_pd" to csv file
crime_info_pd.to_csv("../data/cleandata/HPD_Crime_Report.csv", index=False, header=True)

# %%
# Group "crime_info_pd" by "Zip" and "Crime Type" and calculate violent and non-violent crime counts with given zipcodes
crime_ct = crime_info_pd.groupby(["ZIP", "Crime Type"]).count().reset_index()

# Preview "crime_ct"
crime_ct.head()
# Out:
#      ZIP  Crime Type  Offense  LAT  LNG
# 0  77002  Non-Violet      148  148  148
# 1  77002      Violet       32   32   32
# 2  77003  Non-Violet       54   54   54
# 3  77003      Violet        7    7    7
# 4  77004  Non-Violet      131  131  131

# %%
# Remove "LAT" and "LNG" columns
crime_ct = crime_ct.drop(["LAT", "LNG"], axis=1)

# Preview "crime_ct"
crime_ct.head()
# Out:
#      ZIP  Crime Type  Offense
# 0  77002  Non-Violet      148
# 1  77002      Violet       32
# 2  77003  Non-Violet       54
# 3  77003      Violet        7
# 4  77004  Non-Violet      131

# %%
# Add empty new columns "Non-Violent Ct" and "Violent Ct" to "crime_ct"
crime_ct["Non-Violent Ct"] = ""
crime_ct["Violent Ct"] = ""

# Preview "crime_ct"
crime_ct.head()
# Out:
#      ZIP  Crime Type  Offense Non-Violet Ct Violet Ct
# 0  77002  Non-Violet      148
# 1  77002      Violet       32
# 2  77003  Non-Violet       54
# 3  77003      Violet        7
# 4  77004  Non-Violet      131

# %%
# Save values in "Offense" to "Non-Violent Ct" and "Violent Ct" columns
# Write "0" for columns without data to facilitate following manipulation
crime_ct.loc[crime_ct["Crime Type"] == "Violent", "Violent Ct"] = crime_ct.loc[crime_ct["Crime Type"] == "Violent", "Offense"]
crime_ct.loc[crime_ct["Crime Type"] == "Violent", "Non-Violent Ct"] = 0
crime_ct.loc[crime_ct["Crime Type"] == "Non-Violent", "Non-Violent Ct"] = crime_ct.loc[crime_ct["Crime Type"] == "Non-Violent", "Offense"]
crime_ct.loc[crime_ct["Crime Type"] == "Non-Violent", "Violent Ct"] = 0

# Preview "crime_ct"
crime_ct.head()
# Out:
#      ZIP  Crime Type  Offense  Non-Violet Ct  Violet Ct
# 0  77002  Non-Violet      148            148          0
# 1  77002      Violet       32              0         32
# 2  77003  Non-Violet       54             54          0
# 3  77003      Violet        7              0          7
# 4  77004  Non-Violet      131            131          0

# %%
# Delete "Crime Type" and "Offense" columns from "crime_ct"
crime_info_ct = crime_ct.drop(["Crime Type", "Offense"], axis=1)

# Preview "crime_info_ct"
crime_info_ct.head()
# Out:
#      ZIP  Non-Violet Ct  Violet Ct
# 0  77002            148          0
# 1  77002              0         32
# 2  77003             54          0
# 3  77003              0          7
# 4  77004            131          0

# %%
# Merge data with the same zipcode
crime_info_ct = crime_info_ct.groupby("ZIP").sum().reset_index()

# Preview "crime_info_ct"
crime_info_ct.head()
# Out:
#      ZIP  Non-Violet Ct  Violet Ct
# 0  77002            148         32
# 1  77003             54          7
# 2  77004            131         42
# 3  77005             30          1
# 4  77006            131         16

# %%
len(crime_info_ct)
# Out:
# 105

# %%
# Write "crime_info_pd" to csv file
crime_info_ct.to_csv("../data/cleandata/HPD_Crime_Report_Counts.csv", index=False, header=True)
