# %%
# Dependencies
import requests
import pandas as pd
import datetime

# %% [markdown]
# ### Data Retrieval

# %%
# Query url for HPD recent crime reports (rpt) from COHGIS Open Data Portal
url = "https://opendata.arcgis.com/datasets/8d515a90e80840b3bc7a3ada352b0d15_0.geojson"

# Get HPD crime reports data and save as "hpd_crime_rpt"
hpd_crime_rpt = requests.get(url).json()

# View "hpd_crime_rpt"
hpd_crime_rpt
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'OBJECTID': 1,
#     'Join_Count': 1,
#     'TARGET_FID': 1,
#     'Join_Count_1': 1,
#     'Incident_No': 30807419,
#     'Time_Begun': '2019-03-11T08:30:00.000Z',
#     'UCR_No': 6073,
#     'HPD_Beat': '3B50',
#     'HPD_District': '3',
#     'Offense': 'Theft',
#     'Address_Range': '4400-4499 NORTH ',
#     'Premise_Type': 'Department or Discount St',
#     'X_Coord': 3115832.95607,
#     'Y_Coord': 13866716.49565,
#     'Zip_Code': '77022',
#     'Time_Frame': 3,
#     'SNB_No': 45,
#     'SNB_Name': 'NORTHSIDE/NORTHLINE',
#     'Council_District': 'H',
#     'HPD_Division': 'North Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.38082655494368, 29.828978489304113]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2,
#     'Join_Count': 1,
#     'TARGET_FID': 2,
#     'Join_Count_1': 1,
#     'Incident_No': 31567919,
#     'Time_Begun': '2019-03-12T21:21:00.000Z',
#     'UCR_No': 3023,
#     'HPD_Beat': '14D10',
#     'HPD_District': '14',
#     'Offense': 'Robbery',
#     'Address_Range': '4300-4399 OLD SPANISH TRL ',
#     'Premise_Type': 'Service or Gas Station',
#     'X_Coord': 3126998.64582,
#     'Y_Coord': 13821436.73848,
#     'Zip_Code': '77021',
#     'Time_Frame': 3,
#     'SNB_No': 83,
#     'SNB_Name': 'MACGREGOR',
#     'Council_District': 'D',
#     'HPD_Division': 'Southeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.35008413559338, 29.703565065692064]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 3,
#     'Join_Count': 1,
#     'TARGET_FID': 3,
#     'Join_Count_1': 1,
#     'Incident_No': 30300119,
#     'Time_Begun': '2019-03-09T23:57:00.000Z',
#     'UCR_No': 5002,
#     'HPD_Beat': '7C10',
#     'HPD_District': '7',
#     'Offense': 'Burglary',
#     'Address_Range': '5300-5399 COKE',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3136166.02144,
#     'Y_Coord': 13845153.50715,
#     'Zip_Code': '77020',
#     'Time_Frame': 3,
#     'SNB_No': 55,
#     'SNB_Name': 'GREATER FIFTH WARD',
#     'Council_District': 'B',
#     'HPD_Division': 'Northeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.3188695831117, 29.767964740055827]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 4,
#     'Join_Count': 1,
#     'TARGET_FID': 4,
#     'Join_Count_1': 1,
#     'Incident_No': 32070719,
#     'Time_Begun': '2019-03-13T15:45:00.000Z',
#     'UCR_No': 5031,
#     'HPD_Beat': '12D60',
#     'HPD_District': '12',
#     'Offense': 'Burglary',
#     'Address_Range': '16300-16399 EL CAMINO REAL ',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3199944.17468,
#     'Y_Coord': 13771749.92464,
#     'Zip_Code': '77062',
#     'Time_Frame': 3,
#     'SNB_No': 81,
#     'SNB_Name': 'CLEAR LAKE',
#     'Council_District': 'E',
#     'HPD_Division': 'Clear Lake Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.12561201192459, 29.560539885420383]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 5,
#     'Join_Count': 1,
#     'TARGET_FID': 5,
#     'Join_Count_1': 1,
#     'Incident_No': 24438619,
#     'Time_Begun': '2019-02-25T03:53:00.000Z',
#     'UCR_No': 3013,
#     'HPD_Beat': '22B30',
#     'HPD_District': '22',
#     'Offense': 'Robbery',
#     'Address_Range': '100-199 W DYNA',
#     'Premise_Type': 'Bar or Night Club',
#     'X_Coord': 3105466.79337,
#     'Y_Coord': 13900108.25055,
#     'Zip_Code': '77037',
#     'Time_Frame': 3,
#     'SNB_No': 2,
#     'SNB_Name': 'GREATER GREENSPOINT',
#     'Council_District': 'B',
#     'HPD_Division': 'North Belt Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.41027320324855, 29.921637728021345]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 6,
#     'Join_Count': 1,
#     'TARGET_FID': 6,
#     'Join_Count_1': 1,
#     'Incident_No': 33050619,
#     'Time_Begun': '2019-03-15T04:04:00.000Z',
#     'UCR_No': 4043,
#     'HPD_Beat': '6B20',
#     'HPD_District': '6',
#     'Offense': 'Aggravated Assault',
#     'Address_Range': '5600-5699 YALE',
#     'Premise_Type': 'Apartment Parking Lot',
#     'X_Coord': 3108599.55421,
#     'Y_Coord': 13873275.97428,
#     'Zip_Code': '77091',
#     'Time_Frame': 2,
#     'SNB_No': 45,
#     'SNB_Name': 'NORTHSIDE/NORTHLINE',
#     'Council_District': 'H',
#     'HPD_Division': 'North Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.40299318834315, 29.847621691098293]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 7,
#     'Join_Count': 1,
#     'TARGET_FID': 7,
#     'Join_Count_1': 1,
#     'Incident_No': 25145819,
#     'Time_Begun': '2019-02-26T17:25:00.000Z',
#     'UCR_No': 6073,
#     'HPD_Beat': '3B50',
#     'HPD_District': '3',
#     'Offense': 'Theft',
#     'Address_Range': '4400-4499 NORTH ',
#     'Premise_Type': 'Specialty Store (Non-Spec',
#     'X_Coord': 3115735.76505,
#     'Y_Coord': 13866924.18221,
#     'Zip_Code': '77022',
#     'Time_Frame': 3,
#     'SNB_No': 45,
#     'SNB_Name': 'NORTHSIDE/NORTHLINE',
#     'Council_District': 'H',
#     'HPD_Division': 'North Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.38111267599272, 29.829557613473572]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 8,
#     'Join_Count': 1,
#     'TARGET_FID': 8,
#     'Join_Count_1': 1,
#     'Incident_No': 25527719,
#     'Time_Begun': '2019-02-27T14:00:00.000Z',
#     'UCR_No': 4041,
#     'HPD_Beat': '16E20',
#     'HPD_District': '16',
#     'Offense': 'Aggravated Assault',
#     'Address_Range': '4400-4499 EBBTIDE',
#     'Premise_Type': 'Residence or House',
#     'X_Coord': 3097966.52904,
#     'Y_Coord': 13794286.12824,
#     'Zip_Code': '77045',
#     'Time_Frame': 3,
#     'SNB_No': 40,
#     'SNB_Name': 'CENTRAL SOUTHWEST',
#     'Council_District': 'K',
#     'HPD_Division': 'Southwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.44409458407726, 29.631393520956777]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 9,
#     'Join_Count': 1,
#     'TARGET_FID': 9,
#     'Join_Count_1': 1,
#     'Incident_No': 33229419,
#     'Time_Begun': '2019-03-16T10:40:00.000Z',
#     'UCR_No': 6191,
#     'HPD_Beat': '19G20',
#     'HPD_District': '19',
#     'Offense': 'Theft',
#     'Address_Range': '11200-11299 BELLAIRE',
#     'Premise_Type': 'Grocery Store or Supermar',
#     'X_Coord': 3055450.8027,
#     'Y_Coord': 13819381.82453,
#     'Zip_Code': '77072',
#     'Time_Frame': 2,
#     'SNB_No': 25,
#     'SNB_Name': 'ALIEF',
#     'Council_District': 'F',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.5755566233961, 29.703866635503875]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 10,
#     'Join_Count': 1,
#     'TARGET_FID': 10,
#     'Join_Count_1': 1,
#     'Incident_No': 31525519,
#     'Time_Begun': '2019-03-12T19:15:00.000Z',
#     'UCR_No': 4043,
#     'HPD_Beat': '15E20',
#     'HPD_District': '15',
#     'Offense': 'Aggravated Assault',
#     'Address_Range': '5500-5599 GASMER',
#     'Premise_Type': 'Apartment Parking Lot',
#     'X_Coord': 3086686.76617,
#     'Y_Coord': 13801091.02475,
#     'Zip_Code': '77035',
#     'Time_Frame': 3,
#     'SNB_No': 37,
#     'SNB_Name': 'WESTBURY',
#     'Council_District': 'K',
#     'HPD_Division': 'Southwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.4789404209623, 29.65103747216105]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 11,
#     'Join_Count': 1,
#     'TARGET_FID': 11,
#     'Join_Count_1': 1,
#     'Incident_No': 30175019,
#     'Time_Begun': '2019-03-09T19:00:00.000Z',
#     'UCR_No': 4043,
#     'HPD_Beat': '4F30',
#     'HPD_District': '4',
#     'Offense': 'Aggravated Assault',
#     'Address_Range': '14700-14799 PARK ROW',
#     'Premise_Type': 'Highway or Freeway',
#     'X_Coord': 3032587.61705,
#     'Y_Coord': 13849313.37177,
#     'Zip_Code': '77079',
#     'Time_Frame': 3,
#     'SNB_No': 9,
#     'SNB_Name': 'ADDICKS PARK TEN',
#     'Council_District': 'A',
#     'HPD_Division': 'Northwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.6448428671796, 29.787966513283955]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 12,
#     'Join_Count': 1,
#     'TARGET_FID': 12,
#     'Join_Count_1': 1,
#     'Incident_No': 31532719,
#     'Time_Begun': '2019-03-12T19:00:00.000Z',
#     'UCR_No': 6073,
#     'HPD_Beat': '3B50',
#     'HPD_District': '3',
#     'Offense': 'Theft',
#     'Address_Range': '4400-4499 NORTH ',
#     'Premise_Type': 'Grocery Store or Supermar',
#     'X_Coord': 3115832.95607,
#     'Y_Coord': 13866716.49565,
#     'Zip_Code': '77022',
#     'Time_Frame': 3,
#     'SNB_No': 45,
#     'SNB_Name': 'NORTHSIDE/NORTHLINE',
#     'Council_District': 'H',
#     'HPD_Division': 'North Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.38082655494368, 29.828978489304113]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 13,
#     'Join_Count': 1,
#     'TARGET_FID': 13,
#     'Join_Count_1': 1,
#     'Incident_No': 29893519,
#     'Time_Begun': '2019-03-08T20:00:00.000Z',
#     'UCR_No': 6131,
#     'HPD_Beat': '1A10',
#     'HPD_District': '1',
#     'Offense': 'Theft',
#     'Address_Range': '800-899 COMMERCE',
#     'Premise_Type': 'Commercial Parking Lot or',
#     'X_Coord': 3122764.93822,
#     'Y_Coord': 13843578.71438,
#     'Zip_Code': '77002',
#     'Time_Frame': 3,
#     'SNB_No': 61,
#     'SNB_Name': 'DOWNTOWN',
#     'Council_District': 'I',
#     'HPD_Division': 'Downtown Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.36124431296199, 29.764789291069683]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 14,
#     'Join_Count': 1,
#     'TARGET_FID': 14,
#     'Join_Count_1': 1,
#     'Incident_No': 24075419,
#     'Time_Begun': '2019-02-24T05:57:00.000Z',
#     'UCR_No': 2004,
#     'HPD_Beat': '16E10',
#     'HPD_District': '16',
#     'Offense': 'Rape',
#     'Address_Range': '13300-13399 REMME RIDGE',
#     'Premise_Type': 'Residence or House',
#     'X_Coord': 3108447.03852,
#     'Y_Coord': 13788601.83293,
#     'Zip_Code': '77047',
#     'Time_Frame': 3,
#     'SNB_No': 40,
#     'SNB_Name': 'CENTRAL SOUTHWEST',
#     'Council_District': 'D',
#     'HPD_Division': 'Southwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.41166819716572, 29.61488819055526]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 15,
#     'Join_Count': 1,
#     'TARGET_FID': 15,
#     'Join_Count_1': 1,
#     'Incident_No': 28011819,
#     'Time_Begun': '2019-03-05T07:55:00.000Z',
#     'UCR_No': 6003,
#     'HPD_Beat': '19G50',
#     'HPD_District': '19',
#     'Offense': 'Theft',
#     'Address_Range': '10100-10199 FORUM WEST',
#     'Premise_Type': 'Condominium',
#     'X_Coord': 3062085.53306,
#     'Y_Coord': 13806437.86812,
#     'Zip_Code': '77036',
#     'Time_Frame': 3,
#     'SNB_No': 29,
#     'SNB_Name': 'WESTWOOD',
#     'Council_District': 'J',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.55586647925415, 29.667749571133946]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 16,
#     'Join_Count': 1,
#     'TARGET_FID': 16,
#     'Join_Count_1': 1,
#     'Incident_No': 32356519,
#     'Time_Begun': '2019-03-14T14:41:00.000Z',
#     'UCR_No': 3033,
#     'HPD_Beat': '19G40',
#     'HPD_District': '19',
#     'Offense': 'Robbery',
#     'Address_Range': '11700-11799 BEECHNUT',
#     'Premise_Type': 'Convenience Store',
#     'X_Coord': 3052419.9205,
#     'Y_Coord': 13813858.16933,
#     'Zip_Code': '77072',
#     'Time_Frame': 2,
#     'SNB_No': 25,
#     'SNB_Name': 'ALIEF',
#     'Council_District': 'F',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.58560793800976, 29.688926437799466]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 17,
#     'Join_Count': 1,
#     'TARGET_FID': 17,
#     'Join_Count_1': 1,
#     'Incident_No': 26501519,
#     'Time_Begun': '2019-02-25T19:30:00.000Z',
#     'UCR_No': 6163,
#     'HPD_Beat': '15E40',
#     'HPD_District': '15',
#     'Offense': 'Theft',
#     'Address_Range': '8400-8499 CAMBRIDGE',
#     'Premise_Type': 'Apartment Parking Lot',
#     'X_Coord': 3112801.03758,
#     'Y_Coord': 13813508.19071,
#     'Zip_Code': '77054',
#     'Time_Frame': 3,
#     'SNB_No': 34,
#     'SNB_Name': 'ASTRODOME AREA',
#     'Council_District': 'K',
#     'HPD_Division': 'Southwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.39555572714774, 29.682982334052628]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 18,
#     'Join_Count': 1,
#     'TARGET_FID': 18,
#     'Join_Count_1': 1,
#     'Incident_No': 30183719,
#     'Time_Begun': '2019-03-09T17:30:00.000Z',
#     'UCR_No': 7001,
#     'HPD_Beat': '10H70',
#     'HPD_District': '10',
#     'Offense': 'Auto Theft',
#     'Address_Range': '4800-4899 CHENEVERT',
#     'Premise_Type': 'Road, Street, or Sidewalk',
#     'X_Coord': 3117798.38792,
#     'Y_Coord': 13829836.31248,
#     'Zip_Code': '77004',
#     'Time_Frame': 3,
#     'SNB_No': 66,
#     'SNB_Name': 'MUSEUM PARK',
#     'Council_District': 'D',
#     'HPD_Division': 'South Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.37823227190049, 29.727439529354978]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 19,
#     'Join_Count': 1,
#     'TARGET_FID': 19,
#     'Join_Count_1': 1,
#     'Incident_No': 25220419,
#     'Time_Begun': '2019-02-26T20:00:00.000Z',
#     'UCR_No': 6133,
#     'HPD_Beat': '13D10',
#     'HPD_District': '13',
#     'Offense': 'Theft',
#     'Address_Range': '7500-7599 KINGSLEY',
#     'Premise_Type': 'Road, Street, or Sidewalk',
#     'X_Coord': 3145423.32055,
#     'Y_Coord': 13816007.39978,
#     'Zip_Code': '77087',
#     'Time_Frame': 3,
#     'SNB_No': 73,
#     'SNB_Name': 'GOLFCREST / BELLFORT / REVEILLE',
#     'Council_District': 'I',
#     'HPD_Division': 'Southeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.29261667411646, 29.68704795592979]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 20,
#     'Join_Count': 1,
#     'TARGET_FID': 20,
#     'Join_Count_1': 1,
#     'Incident_No': 26427819,
#     'Time_Begun': '2019-03-01T15:21:00.000Z',
#     'UCR_No': 6003,
#     'HPD_Beat': '2A50',
#     'HPD_District': '2',
#     'Offense': 'Theft',
#     'Address_Range': '5200-5299 BLOSSOM',
#     'Premise_Type': 'Residence or House',
#     'X_Coord': 3106102.16993,
#     'Y_Coord': 13844037.0812,
#     'Zip_Code': '77007',
#     'Time_Frame': 3,
#     'SNB_No': 22,
#     'SNB_Name': 'WASHINGTON AVENUE COALITION / MEMORIAL PARK',
#     'Council_District': 'C',
#     'HPD_Division': 'Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.41369541295619, 29.76746440422692]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 21,
#     'Join_Count': 1,
#     'TARGET_FID': 21,
#     'Join_Count_1': 1,
#     'Incident_No': 31830419,
#     'Time_Begun': '2019-03-13T12:40:00.000Z',
#     'UCR_No': 6191,
#     'HPD_Beat': '17E20',
#     'HPD_District': '17',
#     'Offense': 'Theft',
#     'Address_Range': '9700-9799 FONDREN',
#     'Premise_Type': 'Apartment Parking Lot',
#     'X_Coord': 3077025.12767,
#     'Y_Coord': 13808984.317,
#     'Zip_Code': '77071',
#     'Time_Frame': 3,
#     'SNB_No': 36,
#     'SNB_Name': 'BRAYS OAKS',
#     'Council_District': 'K',
#     'HPD_Division': 'South Gessner Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.50860408971015, 29.673531363005928]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 22,
#     'Join_Count': 1,
#     'TARGET_FID': 22,
#     'Join_Count_1': 1,
#     'Incident_No': 31842219,
#     'Time_Begun': '2019-03-13T11:30:00.000Z',
#     'UCR_No': 6131,
#     'HPD_Beat': '1A50',
#     'HPD_District': '1',
#     'Offense': 'Theft',
#     'Address_Range': '4700-4799 RICHMOND',
#     'Premise_Type': 'Restaurant or Cafeteria P',
#     'X_Coord': 3092931.79681,
#     'Y_Coord': 13830990.89966,
#     'Zip_Code': '77027',
#     'Time_Frame': 3,
#     'SNB_No': 23,
#     'SNB_Name': 'AFTON OAKS / RIVER OAKS AREA',
#     'Council_District': 'G',
#     'HPD_Division': 'Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.45643548968265, 29.732707728524673]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 23,
#     'Join_Count': 1,
#     'TARGET_FID': 23,
#     'Join_Count_1': 1,
#     'Incident_No': 33302119,
#     'Time_Begun': '2019-03-16T15:37:00.000Z',
#     'UCR_No': 4014,
#     'HPD_Beat': '2A10',
#     'HPD_District': '2',
#     'Offense': 'Aggravated Assault',
#     'Address_Range': '4400-4499 FULTON',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3120247.44644,
#     'Y_Coord': 13856336.22823,
#     'Zip_Code': '77009',
#     'Time_Frame': 2,
#     'SNB_No': 51,
#     'SNB_Name': 'NEAR NORTHSIDE',
#     'Council_District': 'H',
#     'HPD_Division': 'Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.36792687047695, 29.800070551734454]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 24,
#     'Join_Count': 1,
#     'TARGET_FID': 24,
#     'Join_Count_1': 1,
#     'Incident_No': 32226419,
#     'Time_Begun': '2019-03-12T23:15:00.000Z',
#     'UCR_No': 7031,
#     'HPD_Beat': '20G80',
#     'HPD_District': '20',
#     'Offense': 'Auto Theft',
#     'Address_Range': '14900-14999 WESTHEIMER',
#     'Premise_Type': 'Other Parking Lot',
#     'X_Coord': 3031813.02974,
#     'Y_Coord': 13830163.68001,
#     'Zip_Code': '77082',
#     'Time_Frame': 3,
#     'SNB_No': 17,
#     'SNB_Name': 'ELDRIDGE / WEST OAKS',
#     'Council_District': 'F',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.6490134846396, 29.735387442674657]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 25,
#     'Join_Count': 1,
#     'TARGET_FID': 25,
#     'Join_Count_1': 1,
#     'Incident_No': 31293319,
#     'Time_Begun': '2019-03-09T22:30:00.000Z',
#     'UCR_No': 6003,
#     'HPD_Beat': '5F20',
#     'HPD_District': '5',
#     'Offense': 'Theft',
#     'Address_Range': '8500-8599 PITNER',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3077855.48891,
#     'Y_Coord': 13865712.20829,
#     'Zip_Code': '77080',
#     'Time_Frame': 3,
#     'SNB_No': 85,
#     'SNB_Name': 'SPRING BRANCH CENTRAL',
#     'Council_District': 'A',
#     'HPD_Division': 'Northwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.50064586061357, 29.82939592860049]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 26,
#     'Join_Count': 1,
#     'TARGET_FID': 26,
#     'Join_Count_1': 1,
#     'Incident_No': 31296419,
#     'Time_Begun': '2019-03-11T17:00:00.000Z',
#     'UCR_No': 6071,
#     'HPD_Beat': '19G10',
#     'HPD_District': '19',
#     'Offense': 'Theft',
#     'Address_Range': '9300-9399 W SAM HOUSTON PKWY S ',
#     'Premise_Type': 'Department or Discount St',
#     'X_Coord': 3060812.56463,
#     'Y_Coord': 13811381.28723,
#     'Zip_Code': '77099',
#     'Time_Frame': 3,
#     'SNB_No': 25,
#     'SNB_Name': 'ALIEF',
#     'Council_District': 'J',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.55941536872281, 29.681441461067134]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 27,
#     'Join_Count': 1,
#     'TARGET_FID': 27,
#     'Join_Count_1': 1,
#     'Incident_No': 30095619,
#     'Time_Begun': '2019-03-08T08:00:00.000Z',
#     'UCR_No': 2004,
#     'HPD_Beat': '3B40',
#     'HPD_District': '3',
#     'Offense': 'Rape',
#     'Address_Range': '5000-5099 YALE',
#     'Premise_Type': 'Apartment Parking Lot',
#     'X_Coord': 3108714.12328,
#     'Y_Coord': 13870275.56104,
#     'Zip_Code': '77018',
#     'Time_Frame': 3,
#     'SNB_No': 13,
#     'SNB_Name': 'INDEPENDENCE HEIGHTS',
#     'Council_District': 'H',
#     'HPD_Division': 'North Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.40292301575332, 29.83936494647195]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 28,
#     'Join_Count': 1,
#     'TARGET_FID': 28,
#     'Join_Count_1': 1,
#     'Incident_No': 30439319,
#     'Time_Begun': '2019-03-10T10:40:00.000Z',
#     'UCR_No': 6031,
#     'HPD_Beat': '18F50',
#     'HPD_District': '18',
#     'Offense': 'Theft',
#     'Address_Range': '6600-6699 FONDREN',
#     'Premise_Type': 'Residence or House',
#     'X_Coord': 3072601.66366,
#     'Y_Coord': 13821532.87392,
#     'Zip_Code': '77036',
#     'Time_Frame': 3,
#     'SNB_No': 26,
#     'SNB_Name': 'SHARPSTOWN',
#     'Council_District': 'J',
#     'HPD_Division': 'Midwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.52135273325904, 29.70838776060585]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 29,
#     'Join_Count': 1,
#     'TARGET_FID': 29,
#     'Join_Count_1': 1,
#     'Incident_No': 29547219,
#     'Time_Begun': '2019-03-08T13:12:00.000Z',
#     'UCR_No': 4014,
#     'HPD_Beat': '1A10',
#     'HPD_District': '1',
#     'Offense': 'Aggravated Assault',
#     'Address_Range': '1400-1499 ST JOSEPH ',
#     'Premise_Type': 'Hospital',
#     'X_Coord': 3121208.42555,
#     'Y_Coord': 13837467.31139,
#     'Zip_Code': '77002',
#     'Time_Frame': 3,
#     'SNB_No': 61,
#     'SNB_Name': 'DOWNTOWN',
#     'Council_District': 'I',
#     'HPD_Division': 'Downtown Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.36674631559738, 29.748124047143474]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 30,
#     'Join_Count': 1,
#     'TARGET_FID': 30,
#     'Join_Count_1': 1,
#     'Incident_No': 24241919,
#     'Time_Begun': '2019-02-24T16:29:00.000Z',
#     'UCR_No': 5021,
#     'HPD_Beat': '8C10',
#     'HPD_District': '8',
#     'Offense': 'Burglary',
#     'Address_Range': '9500-9599 CROFTON',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3141585.64341,
#     'Y_Coord': 13874988.25198,
#     'Zip_Code': '77016',
#     'Time_Frame': 3,
#     'SNB_No': 47,
#     'SNB_Name': 'EAST LITTLE YORK / HOMESTEAD',
#     'Council_District': 'B',
#     'HPD_Division': 'Northeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.29881964440968, 29.849498197589917]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 31,
#     'Join_Count': 1,
#     'TARGET_FID': 31,
#     'Join_Count_1': 1,
#     'Incident_No': 31003919,
#     'Time_Begun': '2019-03-11T16:33:00.000Z',
#     'UCR_No': 4171,
#     'HPD_Beat': '10H60',
#     'HPD_District': '10',
#     'Offense': 'Aggravated Assault',
#     'Address_Range': '3700-3799 GRIGGS',
#     'Premise_Type': 'Daycare, Child Care, or K',
#     'X_Coord': 3123858.37133,
#     'Y_Coord': 13821936.37775,
#     'Zip_Code': '77021',
#     'Time_Frame': 3,
#     'SNB_No': 83,
#     'SNB_Name': 'MACGREGOR',
#     'Council_District': 'D',
#     'HPD_Division': 'South Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.35992239448117, 29.705207541517794]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 32,
#     'Join_Count': 1,
#     'TARGET_FID': 32,
#     'Join_Count_1': 1,
#     'Incident_No': 28559119,
#     'Time_Begun': '2019-03-03T12:00:00.000Z',
#     'UCR_No': 6191,
#     'HPD_Beat': '8C10',
#     'HPD_District': '8',
#     'Offense': 'Theft',
#     'Address_Range': '9600-9699 HOMESTEAD',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3140891.05835,
#     'Y_Coord': 13875413.99537,
#     'Zip_Code': '77016',
#     'Time_Frame': 3,
#     'SNB_No': 47,
#     'SNB_Name': 'EAST LITTLE YORK / HOMESTEAD',
#     'Council_District': 'B',
#     'HPD_Division': 'Northeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.30096718849938, 29.850728799574103]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 33,
#     'Join_Count': 1,
#     'TARGET_FID': 33,
#     'Join_Count_1': 1,
#     'Incident_No': 30402319,
#     'Time_Begun': '2019-03-10T04:06:00.000Z',
#     'UCR_No': 5041,
#     'HPD_Beat': '22B40',
#     'HPD_District': '22',
#     'Offense': 'Burglary',
#     'Address_Range': '15400-15499 LEE',
#     'Premise_Type': 'Department or Discount St',
#     'X_Coord': 3139008.86454,
#     'Y_Coord': 13908738.52573,
#     'Zip_Code': '77032',
#     'Time_Frame': 3,
#     'SNB_No': 42,
#     'SNB_Name': 'IAH / AIRPORT AREA',
#     'Council_District': 'B',
#     'HPD_Division': 'North Belt Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.3035796835126, 29.942485558930194]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 34,
#     'Join_Count': 1,
#     'TARGET_FID': 34,
#     'Join_Count_1': 1,
#     'Incident_No': 33248119,
#     'Time_Begun': '2019-03-16T11:08:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '1A20',
#     'HPD_District': '1',
#     'Offense': 'Theft',
#     'Address_Range': '3200-3299 D AMICO',
#     'Premise_Type': 'Road, Street, or Sidewalk',
#     'X_Coord': 3110709.68234,
#     'Y_Coord': 13841261.74882,
#     'Zip_Code': '77019',
#     'Time_Frame': 2,
#     'SNB_No': 24,
#     'SNB_Name': 'NEARTOWN - MONTROSE',
#     'Council_District': 'C',
#     'HPD_Division': 'Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.39944857893646, 29.75944657055846]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 35,
#     'Join_Count': 1,
#     'TARGET_FID': 35,
#     'Join_Count_1': 1,
#     'Incident_No': 347908119,
#     'Time_Begun': '2019-03-19T16:20:00.000Z',
#     'UCR_No': 6131,
#     'HPD_Beat': '15E40',
#     'HPD_District': '15',
#     'Offense': 'Theft',
#     'Address_Range': '8600-8699 MAIN',
#     'Premise_Type': 'Restaurant or Cafeteria P',
#     'X_Coord': 3105787.66558,
#     'Y_Coord': 13816033.18512,
#     'Zip_Code': '77025',
#     'Time_Frame': 2,
#     'SNB_No': 35,
#     'SNB_Name': 'SOUTH MAIN',
#     'Council_District': 'K',
#     'HPD_Division': 'Southwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.41738983341536, 29.690515488417756]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 36,
#     'Join_Count': 1,
#     'TARGET_FID': 36,
#     'Join_Count_1': 1,
#     'Incident_No': 28464819,
#     'Time_Begun': '2019-02-27T19:44:00.000Z',
#     'UCR_No': 6193,
#     'HPD_Beat': '6B30',
#     'HPD_District': '6',
#     'Offense': 'Theft',
#     'Address_Range': '7700-7799 BATTLEPINE',
#     'Premise_Type': 'Residence or House',
#     'X_Coord': 3075485.0133,
#     'Y_Coord': 13885795.52204,
#     'Zip_Code': '77040',
#     'Time_Frame': 3,
#     'SNB_No': 5,
#     'SNB_Name': 'GREATER INWOOD',
#     'Council_District': 'A',
#     'HPD_Division': 'North Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.50622688719224, 29.884793795817433]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 37,
#     'Join_Count': 1,
#     'TARGET_FID': 37,
#     'Join_Count_1': 1,
#     'Incident_No': 30197819,
#     'Time_Begun': '2019-03-09T19:50:00.000Z',
#     'UCR_No': 4042,
#     'HPD_Beat': '13D10',
#     'HPD_District': '13',
#     'Offense': 'Aggravated Assault',
#     'Address_Range': '2500-2599 BEATTY',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3139504.75016,
#     'Y_Coord': 13824120.14378,
#     'Zip_Code': '77023',
#     'Time_Frame': 3,
#     'SNB_No': 69,
#     'SNB_Name': 'GULFGATE RIVERVIEW / PINE VALLEY',
#     'Council_District': 'I',
#     'HPD_Division': 'Southeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.3104422290027, 29.70986192433175]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 38,
#     'Join_Count': 1,
#     'TARGET_FID': 38,
#     'Join_Count_1': 1,
#     'Incident_No': 27661119,
#     'Time_Begun': '2019-03-04T10:00:00.000Z',
#     'UCR_No': 6131,
#     'HPD_Beat': '18F30',
#     'HPD_District': '18',
#     'Offense': 'Theft',
#     'Address_Range': '5700-5799 SAN FELIPE',
#     'Premise_Type': 'Hospital Parking Lot',
#     'X_Coord': 3085956.68975,
#     'Y_Coord': 13837091.08377,
#     'Zip_Code': '77057',
#     'Time_Frame': 3,
#     'SNB_No': 21,
#     'SNB_Name': 'GREATER UPTOWN',
#     'Council_District': 'G',
#     'HPD_Division': 'Midwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.47782495171873, 29.75005507214269]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 39,
#     'Join_Count': 1,
#     'TARGET_FID': 39,
#     'Join_Count_1': 1,
#     'Incident_No': 34452819,
#     'Time_Begun': '2019-03-17T20:30:00.000Z',
#     'UCR_No': 6191,
#     'HPD_Beat': '16E30',
#     'HPD_District': '16',
#     'Offense': 'Theft',
#     'Address_Range': '5200-5299 ALLUM',
#     'Premise_Type': 'Service or Gas Station',
#     'X_Coord': 3092549.63861,
#     'Y_Coord': 13797563.01158,
#     'Zip_Code': '77045',
#     'Time_Frame': 2,
#     'SNB_No': 40,
#     'SNB_Name': 'CENTRAL SOUTHWEST',
#     'Council_District': 'K',
#     'HPD_Division': 'Southwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.4608261047903, 29.64085293195492]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 40,
#     'Join_Count': 1,
#     'TARGET_FID': 40,
#     'Join_Count_1': 1,
#     'Incident_No': 29099119,
#     'Time_Begun': '2019-03-07T00:15:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '10H30',
#     'HPD_District': '10',
#     'Offense': 'Theft',
#     'Address_Range': '2100-2199 WALKER',
#     'Premise_Type': 'Restaurant or Cafeteria P',
#     'X_Coord': 3124984.75034,
#     'Y_Coord': 13838959.07062,
#     'Zip_Code': '77003',
#     'Time_Frame': 3,
#     'SNB_No': 61,
#     'SNB_Name': 'DOWNTOWN',
#     'Council_District': 'I',
#     'HPD_Division': 'South Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.35470477256352, 29.7519013156637]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 41,
#     'Join_Count': 1,
#     'TARGET_FID': 41,
#     'Join_Count_1': 1,
#     'Incident_No': 31826919,
#     'Time_Begun': '2019-03-08T18:00:00.000Z',
#     'UCR_No': 5031,
#     'HPD_Beat': '18F20',
#     'HPD_District': '18',
#     'Offense': 'Burglary',
#     'Address_Range': '2500-2599 MCCUE',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3090373.13068,
#     'Y_Coord': 13834016.07213,
#     'Zip_Code': '77056',
#     'Time_Frame': 3,
#     'SNB_No': 21,
#     'SNB_Name': 'GREATER UPTOWN',
#     'Council_District': 'G',
#     'HPD_Division': 'Midwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.4642058951317, 29.741236153174555]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 42,
#     'Join_Count': 1,
#     'TARGET_FID': 42,
#     'Join_Count_1': 1,
#     'Incident_No': 31302819,
#     'Time_Begun': '2019-03-11T19:30:00.000Z',
#     'UCR_No': 7001,
#     'HPD_Beat': '19G50',
#     'HPD_District': '19',
#     'Offense': 'Auto Theft',
#     'Address_Range': '10800-10899 KIPP WAY',
#     'Premise_Type': 'Apartment Parking Lot',
#     'X_Coord': 3058107.58467,
#     'Y_Coord': 13807526.28736,
#     'Zip_Code': '77099',
#     'Time_Frame': 3,
#     'SNB_No': 25,
#     'SNB_Name': 'ALIEF',
#     'Council_District': 'J',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.5682868827042, 29.6710630502168]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 43,
#     'Join_Count': 1,
#     'TARGET_FID': 43,
#     'Join_Count_1': 1,
#     'Incident_No': 32202819,
#     'Time_Begun': '2019-03-14T00:01:00.000Z',
#     'UCR_No': 6131,
#     'HPD_Beat': '6B30',
#     'HPD_District': '6',
#     'Offense': 'Theft',
#     'Address_Range': '7200-7299 T C JESTER',
#     'Premise_Type': 'Apartment Parking Lot',
#     'X_Coord': 3090657.3251,
#     'Y_Coord': 13879292.6257,
#     'Zip_Code': '77088',
#     'Time_Frame': 2,
#     'SNB_No': 5,
#     'SNB_Name': 'GREATER INWOOD',
#     'Council_District': 'A',
#     'HPD_Division': 'North Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.45899149855941, 29.86566483222741]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 44,
#     'Join_Count': 1,
#     'TARGET_FID': 44,
#     'Join_Count_1': 1,
#     'Incident_No': 24811019,
#     'Time_Begun': '2019-02-25T21:00:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '18F20',
#     'HPD_District': '18',
#     'Offense': 'Theft',
#     'Address_Range': '5600-5699 WESTHEIMER',
#     'Premise_Type': 'Strip Business Center Par',
#     'X_Coord': 3087187.60972,
#     'Y_Coord': 13832738.99199,
#     'Zip_Code': '77056',
#     'Time_Frame': 3,
#     'SNB_No': 21,
#     'SNB_Name': 'GREATER UPTOWN',
#     'Council_District': 'J',
#     'HPD_Division': 'Midwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.4743608972335, 29.737990182803802]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 45,
#     'Join_Count': 1,
#     'TARGET_FID': 45,
#     'Join_Count_1': 1,
#     'Incident_No': 24817919,
#     'Time_Begun': '2019-02-25T11:00:00.000Z',
#     'UCR_No': 6193,
#     'HPD_Beat': '24C10',
#     'HPD_District': '24',
#     'Offense': 'Theft',
#     'Address_Range': '2100-2199 LAKE VILLAGE',
#     'Premise_Type': 'Residence or House',
#     'X_Coord': 3163608.69905,
#     'Y_Coord': 13946252.34002,
#     'Zip_Code': '77339',
#     'Time_Frame': 3,
#     'SNB_No': 43,
#     'SNB_Name': 'KINGWOOD AREA',
#     'Council_District': 'E',
#     'HPD_Division': 'Kingwood Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.22212210753908, 30.043427365540854]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 46,
#     'Join_Count': 0,
#     'TARGET_FID': 46,
#     'Join_Count_1': 1,
#     'Incident_No': 29916419,
#     'Time_Begun': '2019-03-08T21:00:00.000Z',
#     'UCR_No': 6131,
#     'HPD_Beat': '22B40',
#     'HPD_District': '22',
#     'Offense': 'Theft',
#     'Address_Range': '1900-1999 N SAM HOUSTON PKWY E',
#     'Premise_Type': 'Hotel, Motel, Inn, Etc.',
#     'X_Coord': 3122198.55006,
#     'Y_Coord': 13906833.56178,
#     'Zip_Code': '77032',
#     'Time_Frame': 3,
#     'SNB_No': None,
#     'SNB_Name': None,
#     'Council_District': 'B',
#     'HPD_Division': 'North Belt Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.35681885183224, 29.938700047100046]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 47,
#     'Join_Count': 1,
#     'TARGET_FID': 47,
#     'Join_Count_1': 1,
#     'Incident_No': 31087819,
#     'Time_Begun': '2019-03-11T19:00:00.000Z',
#     'UCR_No': 4043,
#     'HPD_Beat': '20G30',
#     'HPD_District': '20',
#     'Offense': 'Aggravated Assault',
#     'Address_Range': '3100-3199 S DAIRY ASHFORD',
#     'Premise_Type': 'Service or Gas Station',
#     'X_Coord': 3045590.31642,
#     'Y_Coord': 13828725.12618,
#     'Zip_Code': '77082',
#     'Time_Frame': 3,
#     'SNB_No': 17,
#     'SNB_Name': 'ELDRIDGE / WEST OAKS',
#     'Council_District': 'F',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.60575060180011, 29.73034056667424]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 48,
#     'Join_Count': 1,
#     'TARGET_FID': 48,
#     'Join_Count_1': 1,
#     'Incident_No': 32035319,
#     'Time_Begun': '2019-03-13T16:00:00.000Z',
#     'UCR_No': 5021,
#     'HPD_Beat': '20G80',
#     'HPD_District': '20',
#     'Offense': 'Burglary',
#     'Address_Range': '2500-2599 JOEL WHEATON',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3036501.98793,
#     'Y_Coord': 13830165.81863,
#     'Zip_Code': '77082',
#     'Time_Frame': 3,
#     'SNB_No': 17,
#     'SNB_Name': 'ELDRIDGE / WEST OAKS',
#     'Council_District': 'F',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.63424434052811, 29.73502308507644]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 49,
#     'Join_Count': 1,
#     'TARGET_FID': 49,
#     'Join_Count_1': 1,
#     'Incident_No': 29450319,
#     'Time_Begun': '2019-03-04T23:00:00.000Z',
#     'UCR_No': 7021,
#     'HPD_Beat': '1A50',
#     'HPD_District': '1',
#     'Offense': 'Auto Theft',
#     'Address_Range': '3700-3799 W ALABAMA',
#     'Premise_Type': 'Apartment Parking Lot',
#     'X_Coord': 3098918.02498,
#     'Y_Coord': 13833193.99485,
#     'Zip_Code': '77027',
#     'Time_Frame': 3,
#     'SNB_No': 87,
#     'SNB_Name': 'GREENWAY / UPPER KIRBY AREA',
#     'Council_District': 'C',
#     'HPD_Division': 'Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.43737049099414, 29.738263438110582]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 50,
#     'Join_Count': 1,
#     'TARGET_FID': 50,
#     'Join_Count_1': 1,
#     'Incident_No': 29550119,
#     'Time_Begun': '2019-03-08T00:01:00.000Z',
#     'UCR_No': 6193,
#     'HPD_Beat': '8C10',
#     'HPD_District': '8',
#     'Offense': 'Theft',
#     'Address_Range': '4200-4299 DENMARK',
#     'Premise_Type': 'Other, Unknown, or Not Li',
#     'X_Coord': 3132326.44531,
#     'Y_Coord': 13866626.67999,
#     'Zip_Code': '77016',
#     'Time_Frame': 3,
#     'SNB_No': 48,
#     'SNB_Name': 'TRINITY / HOUSTON GARDENS',
#     'Council_District': 'B',
#     'HPD_Division': 'Northeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.32884181973226, 29.827318167846567]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 51,
#     'Join_Count': 1,
#     'TARGET_FID': 51,
#     'Join_Count_1': 1,
#     'Incident_No': 27856819,
#     'Time_Begun': '2019-03-04T19:29:00.000Z',
#     'UCR_No': 4041,
#     'HPD_Beat': '12D10',
#     'HPD_District': '12',
#     'Offense': 'Aggravated Assault',
#     'Address_Range': '9700-9799 WINDWATER',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3161658.01002,
#     'Y_Coord': 13793833.25913,
#     'Zip_Code': '77075',
#     'Time_Frame': 3,
#     'SNB_No': 80,
#     'SNB_Name': 'SOUTH BELT / ELLINGTON',
#     'Council_District': 'I',
#     'HPD_Division': 'Clear Lake Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.24375388865185, 29.624673857506217]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 52,
#     'Join_Count': 1,
#     'TARGET_FID': 52,
#     'Join_Count_1': 1,
#     'Incident_No': 28781319,
#     'Time_Begun': '2019-03-06T18:00:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '1A50',
#     'HPD_District': '1',
#     'Offense': 'Theft',
#     'Address_Range': '4800-4899 LOOP CENTRAL',
#     'Premise_Type': 'Parks and Recreation, Zoo',
#     'X_Coord': 3093610.2194,
#     'Y_Coord': 13828298.77818,
#     'Zip_Code': '77081',
#     'Time_Frame': 3,
#     'SNB_No': 87,
#     'SNB_Name': 'GREENWAY / UPPER KIRBY AREA',
#     'Council_District': 'G',
#     'HPD_Division': 'Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.45455591585286, 29.725251174623466]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 53,
#     'Join_Count': 1,
#     'TARGET_FID': 53,
#     'Join_Count_1': 1,
#     'Incident_No': 27575019,
#     'Time_Begun': '2019-03-04T07:34:00.000Z',
#     'UCR_No': 7001,
#     'HPD_Beat': '19G20',
#     'HPD_District': '19',
#     'Offense': 'Auto Theft',
#     'Address_Range': '4700-4799 S KIRKWOOD',
#     'Premise_Type': 'Apartment Parking Lot',
#     'X_Coord': 3051524.08053,
#     'Y_Coord': 13819634.12044,
#     'Zip_Code': '77072',
#     'Time_Frame': 3,
#     'SNB_No': 25,
#     'SNB_Name': 'ALIEF',
#     'Council_District': 'F',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.58789759204579, 29.704875746743216]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 54,
#     'Join_Count': 1,
#     'TARGET_FID': 54,
#     'Join_Count_1': 1,
#     'Incident_No': 31052719,
#     'Time_Begun': '2019-03-11T18:15:00.000Z',
#     'UCR_No': 6003,
#     'HPD_Beat': '20G10',
#     'HPD_District': '20',
#     'Offense': 'Theft',
#     'Address_Range': '10000-10099 WESTPARK',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3065364.55365,
#     'Y_Coord': 13826684.40857,
#     'Zip_Code': '77042',
#     'Time_Frame': 3,
#     'SNB_No': 19,
#     'SNB_Name': 'WESTCHASE',
#     'Council_District': 'F',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.54366159091431, 29.723138467652387]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 55,
#     'Join_Count': 1,
#     'TARGET_FID': 55,
#     'Join_Count_1': 1,
#     'Incident_No': 27545419,
#     'Time_Begun': '2019-03-04T03:00:00.000Z',
#     'UCR_No': 6091,
#     'HPD_Beat': '8C60',
#     'HPD_District': '8',
#     'Offense': 'Theft',
#     'Address_Range': '10100-10199 HOMESTEAD',
#     'Premise_Type': 'Residence or House',
#     'X_Coord': 3140955.87481,
#     'Y_Coord': 13877977.07817,
#     'Zip_Code': '77016',
#     'Time_Frame': 3,
#     'SNB_No': 47,
#     'SNB_Name': 'EAST LITTLE YORK / HOMESTEAD',
#     'Council_District': 'B',
#     'HPD_Division': 'Northeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.30050709596934, 29.857767939031366]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 56,
#     'Join_Count': 1,
#     'TARGET_FID': 56,
#     'Join_Count_1': 1,
#     'Incident_No': 31475319,
#     'Time_Begun': '2019-03-12T13:00:00.000Z',
#     'UCR_No': 5023,
#     'HPD_Beat': '10H20',
#     'HPD_District': '10',
#     'Offense': 'Burglary',
#     'Address_Range': '5200-5299 HILLMAN',
#     'Premise_Type': 'Residence or House',
#     'X_Coord': 3134791.52538,
#     'Y_Coord': 13830558.10925,
#     'Zip_Code': '77023',
#     'Time_Frame': 3,
#     'SNB_No': 64,
#     'SNB_Name': 'GREATER EASTWOOD',
#     'Council_District': 'I',
#     'HPD_Division': 'South Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.32464545717671, 29.72796585927181]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 57,
#     'Join_Count': 1,
#     'TARGET_FID': 57,
#     'Join_Count_1': 1,
#     'Incident_No': 27810719,
#     'Time_Begun': '2019-03-04T03:00:00.000Z',
#     'UCR_No': 3002,
#     'HPD_Beat': '13D10',
#     'HPD_District': '13',
#     'Offense': 'Robbery',
#     'Address_Range': '100-199 WINKLER',
#     'Premise_Type': 'Apartment Parking Lot',
#     'X_Coord': 3142189.48869,
#     'Y_Coord': 13821573.11175,
#     'Zip_Code': '77087',
#     'Time_Frame': 3,
#     'SNB_No': 69,
#     'SNB_Name': 'GULFGATE RIVERVIEW / PINE VALLEY',
#     'Council_District': 'I',
#     'HPD_Division': 'Southeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.30224252096109, 29.702627812592578]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 58,
#     'Join_Count': 1,
#     'TARGET_FID': 58,
#     'Join_Count_1': 1,
#     'Incident_No': 29893319,
#     'Time_Begun': '2019-03-09T03:35:00.000Z',
#     'UCR_No': 3001,
#     'HPD_Beat': '17E10',
#     'HPD_District': '17',
#     'Offense': 'Robbery',
#     'Address_Range': '5900-5999 BISSONNET',
#     'Premise_Type': 'Apartment Parking Lot',
#     'X_Coord': 3084350.72273,
#     'Y_Coord': 13818529.45427,
#     'Zip_Code': '77081',
#     'Time_Frame': 3,
#     'SNB_No': 27,
#     'SNB_Name': 'GULFTON',
#     'Council_District': 'J',
#     'HPD_Division': 'South Gessner Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.4846419035766, 29.699165912079845]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 59,
#     'Join_Count': 1,
#     'TARGET_FID': 59,
#     'Join_Count_1': 1,
#     'Incident_No': 30814619,
#     'Time_Begun': '2019-03-10T18:15:00.000Z',
#     'UCR_No': 5071,
#     'HPD_Beat': '5F20',
#     'HPD_District': '5',
#     'Offense': 'Burglary',
#     'Address_Range': '1400-1499 WIRT',
#     'Premise_Type': 'Barber And Beauty Shops',
#     'X_Coord': 3083209.4416,
#     'Y_Coord': 13853753.58557,
#     'Zip_Code': '77055',
#     'Time_Frame': 3,
#     'SNB_No': 86,
#     'SNB_Name': 'SPRING BRANCH EAST',
#     'Council_District': 'A',
#     'HPD_Division': 'Northwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.4849008961572, 29.796083443003678]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 60,
#     'Join_Count': 1,
#     'TARGET_FID': 60,
#     'Join_Count_1': 1,
#     'Incident_No': 31107119,
#     'Time_Begun': '2019-03-11T06:30:00.000Z',
#     'UCR_No': 5031,
#     'HPD_Beat': '17E20',
#     'HPD_District': '17',
#     'Offense': 'Burglary',
#     'Address_Range': '8700-8799 BRAE ACRES',
#     'Premise_Type': 'Condominium',
#     'X_Coord': 3072722.83751,
#     'Y_Coord': 13812837.8926,
#     'Zip_Code': '77074',
#     'Time_Frame': 3,
#     'SNB_No': 26,
#     'SNB_Name': 'SHARPSTOWN',
#     'Council_District': 'J',
#     'HPD_Division': 'South Gessner Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.52178568910271, 29.684476747769427]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 61,
#     'Join_Count': 1,
#     'TARGET_FID': 61,
#     'Join_Count_1': 1,
#     'Incident_No': 31106419,
#     'Time_Begun': '2019-03-11T09:30:00.000Z',
#     'UCR_No': 5031,
#     'HPD_Beat': '20G30',
#     'HPD_District': '20',
#     'Offense': 'Burglary',
#     'Address_Range': '3400-3499 ROGERDALE',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3060302.26224,
#     'Y_Coord': 13826580.8713,
#     'Zip_Code': '77042',
#     'Time_Frame': 3,
#     'SNB_No': 19,
#     'SNB_Name': 'WESTCHASE',
#     'Council_District': 'F',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.55961382535166, 29.723264283485396]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 62,
#     'Join_Count': 1,
#     'TARGET_FID': 62,
#     'Join_Count_1': 1,
#     'Incident_No': 29460119,
#     'Time_Begun': '2019-03-05T15:00:00.000Z',
#     'UCR_No': 6151,
#     'HPD_Beat': '9C40',
#     'HPD_District': '9',
#     'Offense': 'Theft',
#     'Address_Range': '12200-12299 FLEMING',
#     'Premise_Type': 'Apartment Parking Lot',
#     'X_Coord': 3167054.56792,
#     'Y_Coord': 13848975.91551,
#     'Zip_Code': '77013',
#     'Time_Frame': 3,
#     'SNB_No': 58,
#     'SNB_Name': 'NORTHSHORE',
#     'Council_District': 'I',
#     'HPD_Division': 'Northeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.22116921211133, 29.775762323807847]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 63,
#     'Join_Count': 1,
#     'TARGET_FID': 63,
#     'Join_Count_1': 1,
#     'Incident_No': 31565919,
#     'Time_Begun': '2019-03-12T09:00:00.000Z',
#     'UCR_No': 5031,
#     'HPD_Beat': '17E20',
#     'HPD_District': '17',
#     'Offense': 'Burglary',
#     'Address_Range': '8400-8499 NAIRN',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3070770.15189,
#     'Y_Coord': 13811143.71922,
#     'Zip_Code': '77074',
#     'Time_Frame': 3,
#     'SNB_No': 30,
#     'SNB_Name': 'BRAEBURN',
#     'Council_District': 'J',
#     'HPD_Division': 'South Gessner Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.5280912688222, 29.679979256936132]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 64,
#     'Join_Count': 1,
#     'TARGET_FID': 64,
#     'Join_Count_1': 1,
#     'Incident_No': 30306819,
#     'Time_Begun': '2019-03-10T00:13:00.000Z',
#     'UCR_No': 5002,
#     'HPD_Beat': '9C30',
#     'HPD_District': '9',
#     'Offense': 'Burglary',
#     'Address_Range': '500-599 FALLOON',
#     'Premise_Type': 'Residence or House',
#     'X_Coord': 3162829.43016,
#     'Y_Coord': 13850327.84865,
#     'Zip_Code': '77013',
#     'Time_Frame': 3,
#     'SNB_No': 58,
#     'SNB_Name': 'NORTHSHORE',
#     'Council_District': 'I',
#     'HPD_Division': 'Northeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.2343439357605, 29.779852906921693]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 65,
#     'Join_Count': 1,
#     'TARGET_FID': 65,
#     'Join_Count_1': 1,
#     'Incident_No': 30477219,
#     'Time_Begun': '2019-03-10T11:00:00.000Z',
#     'UCR_No': 6193,
#     'HPD_Beat': '15E40',
#     'HPD_District': '15',
#     'Offense': 'Theft',
#     'Address_Range': '9800-9899 MAIN',
#     'Premise_Type': 'Service or Gas Station',
#     'X_Coord': 3102991.55599,
#     'Y_Coord': 13811724.94655,
#     'Zip_Code': '77025',
#     'Time_Frame': 3,
#     'SNB_No': 35,
#     'SNB_Name': 'SOUTH MAIN',
#     'Council_District': 'K',
#     'HPD_Division': 'Southwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.42660703338204, 29.6789083186899]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 66,
#     'Join_Count': 1,
#     'TARGET_FID': 66,
#     'Join_Count_1': 1,
#     'Incident_No': 30463319,
#     'Time_Begun': '2019-03-10T12:00:00.000Z',
#     'UCR_No': 6191,
#     'HPD_Beat': '17E20',
#     'HPD_District': '17',
#     'Offense': 'Theft',
#     'Address_Range': '7600-7699 BEECHNUT',
#     'Premise_Type': 'Hospital',
#     'X_Coord': 3073053.94773,
#     'Y_Coord': 13815401.49368,
#     'Zip_Code': '77074',
#     'Time_Frame': 3,
#     'SNB_No': 26,
#     'SNB_Name': 'SHARPSTOWN',
#     'Council_District': 'J',
#     'HPD_Division': 'South Gessner Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.52050315164087, 29.69149660700896]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 67,
#     'Join_Count': 1,
#     'TARGET_FID': 67,
#     'Join_Count_1': 1,
#     'Incident_No': 35072919,
#     'Time_Begun': '2019-02-25T13:55:00.000Z',
#     'UCR_No': 6191,
#     'HPD_Beat': '1A30',
#     'HPD_District': '1',
#     'Offense': 'Theft',
#     'Address_Range': '000-099 MANDELL / RICHMOND AVE',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3110976.71903,
#     'Y_Coord': 13832167.31601,
#     'Zip_Code': '77006',
#     'Time_Frame': 3,
#     'SNB_No': 24,
#     'SNB_Name': 'NEARTOWN - MONTROSE',
#     'Council_District': 'C',
#     'HPD_Division': 'Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.39948965044634, 29.734425964728747]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 68,
#     'Join_Count': 1,
#     'TARGET_FID': 68,
#     'Join_Count_1': 1,
#     'Incident_No': 30445619,
#     'Time_Begun': '2019-03-10T11:04:00.000Z',
#     'UCR_No': 4042,
#     'HPD_Beat': '17E10',
#     'HPD_District': '17',
#     'Offense': 'Aggravated Assault',
#     'Address_Range': '6700-6799 ATWELL',
#     'Premise_Type': 'Road, Street, or Sidewalk',
#     'X_Coord': 3084920.61047,
#     'Y_Coord': 13821450.94701,
#     'Zip_Code': '77081',
#     'Time_Frame': 3,
#     'SNB_No': 27,
#     'SNB_Name': 'GULFTON',
# ...
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3152161.18308,
#     'Y_Coord': 13806426.77888,
#     'Zip_Code': '77061',
#     'Time_Frame': 3,
#     'SNB_No': 73,
#     'SNB_Name': 'GOLFCREST / BELLFORT / REVEILLE',
#     'Council_District': 'I',
#     'HPD_Division': 'Southeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.27236787190058, 29.660124974599405]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 979,
#     'Join_Count': 1,
#     'TARGET_FID': 979,
#     'Join_Count_1': 1,
#     'Incident_No': 29561219,
#     'Time_Begun': '2019-03-07T20:00:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '14D40',
#     'HPD_District': '14',
#     'Offense': 'Theft',
#     'Address_Range': '11500-11599 ROANDALE',
#     'Premise_Type': 'Driveway',
#     'X_Coord': 3126765.35308,
#     'Y_Coord': 13796718.85178,
#     'Zip_Code': '77048',
#     'Time_Frame': 3,
#     'SNB_No': 76,
#     'SNB_Name': 'SOUTH ACRES / CRESTMONT PARK',
#     'Council_District': 'D',
#     'HPD_Division': 'Southeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.3532461754236, 29.63564213174105]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 980,
#     'Join_Count': 1,
#     'TARGET_FID': 980,
#     'Join_Count_1': 1,
#     'Incident_No': 29571319,
#     'Time_Begun': '2019-03-08T13:30:00.000Z',
#     'UCR_No': 5021,
#     'HPD_Beat': '7C10',
#     'HPD_District': '7',
#     'Offense': 'Burglary',
#     'Address_Range': '1400-1499 GRANGER',
#     'Premise_Type': 'Residence or House',
#     'X_Coord': 3132444.624,
#     'Y_Coord': 13847057.23302,
#     'Zip_Code': '77020',
#     'Time_Frame': 3,
#     'SNB_No': 55,
#     'SNB_Name': 'GREATER FIFTH WARD',
#     'Council_District': 'B',
#     'HPD_Division': 'Northeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.3304055526934, 29.773518961565237]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 981,
#     'Join_Count': 1,
#     'TARGET_FID': 981,
#     'Join_Count_1': 1,
#     'Incident_No': 28780219,
#     'Time_Begun': '2019-03-06T20:29:00.000Z',
#     'UCR_No': 4041,
#     'HPD_Beat': '10H60',
#     'HPD_District': '10',
#     'Offense': 'Aggravated Assault',
#     'Address_Range': '2300-2399 ARBOR',
#     'Premise_Type': 'Road, Street, or Sidewalk',
#     'X_Coord': 3119060.54181,
#     'Y_Coord': 13828684.35511,
#     'Zip_Code': '77004',
#     'Time_Frame': 3,
#     'SNB_No': 83,
#     'SNB_Name': 'MACGREGOR',
#     'Council_District': 'D',
#     'HPD_Division': 'South Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.37436990530256, 29.72416559838636]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 982,
#     'Join_Count': 1,
#     'TARGET_FID': 982,
#     'Join_Count_1': 1,
#     'Incident_No': 29609319,
#     'Time_Begun': '2019-03-08T15:44:00.000Z',
#     'UCR_No': 5021,
#     'HPD_Beat': '24C50',
#     'HPD_District': '24',
#     'Offense': 'Burglary',
#     'Address_Range': '200-299 KELLINGTON',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3152992.57515,
#     'Y_Coord': 13951603.97807,
#     'Zip_Code': '77339',
#     'Time_Frame': 3,
#     'SNB_No': 43,
#     'SNB_Name': 'KINGWOOD AREA',
#     'Council_District': 'E',
#     'HPD_Division': 'Kingwood Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.25511642977683, 30.059074110391705]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 983,
#     'Join_Count': 1,
#     'TARGET_FID': 983,
#     'Join_Count_1': 1,
#     'Incident_No': 29602519,
#     'Time_Begun': '2019-03-08T15:30:00.000Z',
#     'UCR_No': 6071,
#     'HPD_Beat': '2A60',
#     'HPD_District': '2',
#     'Offense': 'Theft',
#     'Address_Range': '900-999 N LOOP W',
#     'Premise_Type': 'Department or Discount St',
#     'X_Coord': 3104725.80622,
#     'Y_Coord': 13860345.1968,
#     'Zip_Code': '77008',
#     'Time_Frame': 3,
#     'SNB_No': 15,
#     'SNB_Name': 'GREATER HEIGHTS',
#     'Council_District': 'C',
#     'HPD_Division': 'Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.41645687670389, 29.812406403483728]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 984,
#     'Join_Count': 1,
#     'TARGET_FID': 984,
#     'Join_Count_1': 1,
#     'Incident_No': 27436319,
#     'Time_Begun': '2019-03-03T20:02:00.000Z',
#     'UCR_No': 3031,
#     'HPD_Beat': '6B30',
#     'HPD_District': '6',
#     'Offense': 'Robbery',
#     'Address_Range': '9200-9299 N HOUSTON ROSSLYN',
#     'Premise_Type': 'Convenience Store',
#     'X_Coord': 3079315.93199,
#     'Y_Coord': 13882767.34944,
#     'Zip_Code': '77040',
#     'Time_Frame': 3,
#     'SNB_No': 5,
#     'SNB_Name': 'GREATER INWOOD',
#     'Council_District': 'A',
#     'HPD_Division': 'North Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.49442965560984, 29.876155130110817]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 985,
#     'Join_Count': 1,
#     'TARGET_FID': 985,
#     'Join_Count_1': 1,
#     'Incident_No': 23904119,
#     'Time_Begun': '2019-02-23T21:22:00.000Z',
#     'UCR_No': 4041,
#     'HPD_Beat': '14D30',
#     'HPD_District': '14',
#     'Offense': 'Aggravated Assault',
#     'Address_Range': '5900-5999 SOUTHVILLE',
#     'Premise_Type': 'Residence or House',
#     'X_Coord': 3133337.82906,
#     'Y_Coord': 13813502.44654,
#     'Zip_Code': '77033',
#     'Time_Frame': 3,
#     'SNB_No': 72,
#     'SNB_Name': 'SOUTH PARK',
#     'Council_District': 'D',
#     'HPD_Division': 'Southeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.33090919141303, 29.681210573532034]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 986,
#     'Join_Count': 1,
#     'TARGET_FID': 986,
#     'Join_Count_1': 1,
#     'Incident_No': 31642319,
#     'Time_Begun': '2019-03-13T01:00:00.000Z',
#     'UCR_No': 4043,
#     'HPD_Beat': '17E10',
#     'HPD_District': '17',
#     'Offense': 'Aggravated Assault',
#     'Address_Range': '5400-5499 CHIMNEY ROCK',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3086649.92003,
#     'Y_Coord': 13827792.31679,
#     'Zip_Code': '77081',
#     'Time_Frame': 3,
#     'SNB_No': 27,
#     'SNB_Name': 'GULFTON',
#     'Council_District': 'J',
#     'HPD_Division': 'South Gessner Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.47652399728649, 29.724437411865065]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 987,
#     'Join_Count': 1,
#     'TARGET_FID': 987,
#     'Join_Count_1': 1,
#     'Incident_No': 24692519,
#     'Time_Begun': '2019-02-25T08:00:00.000Z',
#     'UCR_No': 7033,
#     'HPD_Beat': '8C40',
#     'HPD_District': '8',
#     'Offense': 'Auto Theft',
#     'Address_Range': '8900-8999 LAURA KOPPE',
#     'Premise_Type': 'Residence or House',
#     'X_Coord': 3154070.49644,
#     'Y_Coord': 13872152.22126,
#     'Zip_Code': '77078',
#     'Time_Frame': 3,
#     'SNB_No': 49,
#     'SNB_Name': 'EAST HOUSTON',
#     'Council_District': 'B',
#     'HPD_Division': 'Northeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.25974162090023, 29.8406111474901]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 988,
#     'Join_Count': 1,
#     'TARGET_FID': 988,
#     'Join_Count_1': 1,
#     'Incident_No': 30532419,
#     'Time_Begun': '2019-03-10T15:53:00.000Z',
#     'UCR_No': 6073,
#     'HPD_Beat': '2A40',
#     'HPD_District': '2',
#     'Offense': 'Theft',
#     'Address_Range': '2500-2599 SHEARN',
#     'Premise_Type': 'Department or Discount St',
#     'X_Coord': 3115404.92695,
#     'Y_Coord': 13846892.31763,
#     'Zip_Code': '77007',
#     'Time_Frame': 3,
#     'SNB_No': 22,
#     'SNB_Name': 'WASHINGTON AVENUE COALITION / MEMORIAL PARK',
#     'Council_District': 'H',
#     'HPD_Division': 'Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.38410869301909, 29.77452497861132]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 989,
#     'Join_Count': 1,
#     'TARGET_FID': 989,
#     'Join_Count_1': 1,
#     'Incident_No': 26435819,
#     'Time_Begun': '2019-03-01T13:00:00.000Z',
#     'UCR_No': 3021,
#     'HPD_Beat': '19G10',
#     'HPD_District': '19',
#     'Offense': 'Robbery',
#     'Address_Range': '10300-10399 BISSONNET',
#     'Premise_Type': 'Service or Gas Station',
#     'X_Coord': 3060228.74835,
#     'Y_Coord': 13808863.18002,
#     'Zip_Code': '77099',
#     'Time_Frame': 3,
#     'SNB_No': 25,
#     'SNB_Name': 'ALIEF',
#     'Council_District': 'J',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.56148635914528, 29.67456670128166]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 990,
#     'Join_Count': 1,
#     'TARGET_FID': 990,
#     'Join_Count_1': 1,
#     'Incident_No': 26491019,
#     'Time_Begun': '2019-02-28T21:45:00.000Z',
#     'UCR_No': 6003,
#     'HPD_Beat': '19G10',
#     'HPD_District': '19',
#     'Offense': 'Theft',
#     'Address_Range': '8300-8399 SOUTH COURSE',
#     'Premise_Type': 'Apartment Rental Office',
#     'X_Coord': 3059667.23398,
#     'Y_Coord': 13814148.96383,
#     'Zip_Code': '77072',
#     'Time_Frame': 3,
#     'SNB_No': 25,
#     'SNB_Name': 'ALIEF',
#     'Council_District': 'J',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.56276473825646, 29.689142059819982]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 991,
#     'Join_Count': 1,
#     'TARGET_FID': 991,
#     'Join_Count_1': 1,
#     'Incident_No': 29591919,
#     'Time_Begun': '2019-03-07T19:00:00.000Z',
#     'UCR_No': 6153,
#     'HPD_Beat': '22B20',
#     'HPD_District': '22',
#     'Offense': 'Theft',
#     'Address_Range': '500-599 N SAM HOUSTON PKWY E ',
#     'Premise_Type': 'Other Parking Lot',
#     'X_Coord': 3111055.84529,
#     'Y_Coord': 13906587.44004,
#     'Zip_Code': '77060',
#     'Time_Frame': 3,
#     'SNB_No': 2,
#     'SNB_Name': 'GREATER GREENSPOINT',
#     'Council_District': 'B',
#     'HPD_Division': 'North Belt Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.39200720839314, 29.938973314561952]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 992,
#     'Join_Count': 1,
#     'TARGET_FID': 992,
#     'Join_Count_1': 1,
#     'Incident_No': 33378119,
#     'Time_Begun': '2019-03-15T17:15:00.000Z',
#     'UCR_No': 6191,
#     'HPD_Beat': '14D20',
#     'HPD_District': '14',
#     'Offense': 'Theft',
#     'Address_Range': '7500-7599 SOUTH ',
#     'Premise_Type': 'Commercial Building',
#     'X_Coord': 3118166.04093,
#     'Y_Coord': 13814805.93513,
#     'Zip_Code': '77021',
#     'Time_Frame': 2,
#     'SNB_No': 68,
#     'SNB_Name': 'GREATER OST / SOUTH UNION',
#     'Council_District': 'D',
#     'HPD_Division': 'Southeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.37854065170765, 29.68609378685251]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 993,
#     'Join_Count': 1,
#     'TARGET_FID': 993,
#     'Join_Count_1': 1,
#     'Incident_No': 33379219,
#     'Time_Begun': '2019-03-16T18:00:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '3B30',
#     'HPD_District': '3',
#     'Offense': 'Theft',
#     'Address_Range': '4200-4299 W T C JESTER',
#     'Premise_Type': 'Field, Woods, Forest, Par',
#     'X_Coord': 3092478.58584,
#     'Y_Coord': 13865182.19105,
#     'Zip_Code': '77018',
#     'Time_Frame': 2,
#     'SNB_No': 12,
#     'SNB_Name': 'CENTRAL NORTHWEST',
#     'Council_District': 'C',
#     'HPD_Division': 'North Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.45459735777499, 29.826728102268937]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 994,
#     'Join_Count': 1,
#     'TARGET_FID': 994,
#     'Join_Count_1': 1,
#     'Incident_No': 29436819,
#     'Time_Begun': '2019-03-07T17:00:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '24C30',
#     'HPD_District': '24',
#     'Offense': 'Theft',
#     'Address_Range': '3500-3599 WHISPERING BROOK',
#     'Premise_Type': 'Driveway',
#     'X_Coord': 3179996.41327,
#     'Y_Coord': 13954649.94443,
#     'Zip_Code': '77345',
#     'Time_Frame': 3,
#     'SNB_No': 43,
#     'SNB_Name': 'KINGWOOD AREA',
#     'Council_District': 'E',
#     'HPD_Division': 'Kingwood Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.16948615682239, 30.06504089200649]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 995,
#     'Join_Count': 1,
#     'TARGET_FID': 995,
#     'Join_Count_1': 1,
#     'Incident_No': 31728619,
#     'Time_Begun': '2019-03-12T22:30:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '19G20',
#     'HPD_District': '19',
#     'Offense': 'Theft',
#     'Address_Range': '4300-4399 UNIVERSAL',
#     'Premise_Type': 'Driveway',
#     'X_Coord': 3050623.75151,
#     'Y_Coord': 13821356.02378,
#     'Zip_Code': '77072',
#     'Time_Frame': 3,
#     'SNB_No': 25,
#     'SNB_Name': 'ALIEF',
#     'Council_District': 'F',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.59057440058541, 29.709681247454153]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 996,
#     'Join_Count': 1,
#     'TARGET_FID': 996,
#     'Join_Count_1': 1,
#     'Incident_No': 31717919,
#     'Time_Begun': '2019-03-12T20:00:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '4F20',
#     'HPD_District': '4',
#     'Offense': 'Theft',
#     'Address_Range': '10400-10499 CLAY',
#     'Premise_Type': 'Hotel or Motel Parking Lo',
#     'X_Coord': 3061873.14199,
#     'Y_Coord': 13866241.9244,
#     'Zip_Code': '77041',
#     'Time_Frame': 3,
#     'SNB_No': 8,
#     'SNB_Name': 'WESTBRANCH',
#     'Council_District': 'A',
#     'HPD_Division': 'Northwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.55098203297621, 29.832157401860655]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 997,
#     'Join_Count': 1,
#     'TARGET_FID': 997,
#     'Join_Count_1': 1,
#     'Incident_No': 31716019,
#     'Time_Begun': '2019-03-12T17:00:00.000Z',
#     'UCR_No': 5071,
#     'HPD_Beat': '14D20',
#     'HPD_District': '14',
#     'Offense': 'Burglary',
#     'Address_Range': '2900-2999 REED',
#     'Premise_Type': 'Maintenance or Building S',
#     'X_Coord': 3117215.07073,
#     'Y_Coord': 13804540.68059,
#     'Zip_Code': '77051',
#     'Time_Frame': 3,
#     'SNB_No': 71,
#     'SNB_Name': 'SUNNYSIDE',
#     'Council_District': 'D',
#     'HPD_Division': 'Southeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.38253418500926, 29.657958035852896]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 998,
#     'Join_Count': 1,
#     'TARGET_FID': 998,
#     'Join_Count_1': 1,
#     'Incident_No': 32697819,
#     'Time_Begun': '2019-03-14T08:00:00.000Z',
#     'UCR_No': 4013,
#     'HPD_Beat': '22B20',
#     'HPD_District': '22',
#     'Offense': 'Aggravated Assault',
#     'Address_Range': '600-699 RUSHCREEK DR APT 206',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3099842.33422,
#     'Y_Coord': 13914069.82239,
#     'Zip_Code': '77067',
#     'Time_Frame': 2,
#     'SNB_No': 2,
#     'SNB_Name': 'GREATER GREENSPOINT',
#     'Council_District': 'B',
#     'HPD_Division': 'North Belt Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.42667375625712, 29.960485589139076]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 999,
#     'Join_Count': 1,
#     'TARGET_FID': 999,
#     'Join_Count_1': 1,
#     'Incident_No': 27111919,
#     'Time_Begun': '2019-03-02T23:55:00.000Z',
#     'UCR_No': 5003,
#     'HPD_Beat': '19G10',
#     'HPD_District': '19',
#     'Offense': 'Burglary',
#     'Address_Range': '10000-10099 SPICE',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3060979.28768,
#     'Y_Coord': 13813247.35087,
#     'Zip_Code': '77072',
#     'Time_Frame': 3,
#     'SNB_No': 25,
#     'SNB_Name': 'ALIEF',
#     'Council_District': 'J',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.55871761973076, 29.686557546306457]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1000,
#     'Join_Count': 1,
#     'TARGET_FID': 1000,
#     'Join_Count_1': 1,
#     'Incident_No': 27113219,
#     'Time_Begun': '2019-03-02T22:30:00.000Z',
#     'UCR_No': 6131,
#     'HPD_Beat': '16E30',
#     'HPD_District': '16',
#     'Offense': 'Theft',
#     'Address_Range': '5400-5499 WILLOMINE',
#     'Premise_Type': 'Road, Street, or Sidewalk',
#     'X_Coord': 3092024.50873,
#     'Y_Coord': 13793664.46607,
#     'Zip_Code': '77045',
#     'Time_Frame': 3,
#     'SNB_No': 40,
#     'SNB_Name': 'CENTRAL SOUTHWEST',
#     'Council_District': 'K',
#     'HPD_Division': 'Southwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.46284965947078, 29.630180141840615]}},
#   ...]}

# %%
# Convert "hpd_crime_report" to Pandas dataframe
hpd_crime_rpt_pd = pd.DataFrame(hpd_crime_rpt)

# View "hpd_crime_rpt_pd"
hpd_crime_rpt_pd.head()
# Out:
#                 type                                           features
# 0  FeatureCollection  {'type': 'Feature', 'properties': {'OBJECTID':...
# 1  FeatureCollection  {'type': 'Feature', 'properties': {'OBJECTID':...
# 2  FeatureCollection  {'type': 'Feature', 'properties': {'OBJECTID':...
# 3  FeatureCollection  {'type': 'Feature', 'properties': {'OBJECTID':...
# 4  FeatureCollection  {'type': 'Feature', 'properties': {'OBJECTID':...

# %%
# Write "hpd_crime_rpt_pd" to csv file
hpd_crime_rpt_pd.to_csv("../data/rawdata/hpd_crime_report.csv", index=False, header=True)

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# ###### >> Sort out retrieved crime lists

# %%
# Grab "features" data from "hpd_crime_rpt"
crime_list = hpd_crime_rpt["features"]

# Check the length of "crime_list"
print(f"There are {len(crime_list)} crime cases reported in the HPD recent crime report")

# Preview a representative "crime_list" structure
crime_list[0]
# Out:
# There are 7368 crime cases reported in the HPD recent crime report
# {'type': 'Feature',
#  'properties': {'OBJECTID': 1,
#   'Join_Count': 1,
#   'TARGET_FID': 1,
#   'Join_Count_1': 1,
#   'Incident_No': 30807419,
#   'Time_Begun': '2019-03-11T08:30:00.000Z',
#   'UCR_No': 6073,
#   'HPD_Beat': '3B50',
#   'HPD_District': '3',
#   'Offense': 'Theft',
#   'Address_Range': '4400-4499 NORTH ',
#   'Premise_Type': 'Department or Discount St',
#   'X_Coord': 3115832.95607,
#   'Y_Coord': 13866716.49565,
#   'Zip_Code': '77022',
#   'Time_Frame': 3,
#   'SNB_No': 45,
#   'SNB_Name': 'NORTHSIDE/NORTHLINE',
#   'Council_District': 'H',
#   'HPD_Division': 'North Division'},
#  'geometry': {'type': 'Point',
#   'coordinates': [-95.38082655494368, 29.828978489304113]}}

# %% [markdown]
# ###### >>Categorize types of crimes reported

# %%
# list to store types of crimes
crime_type = []

# Loop through "crime_list"
for case in crime_list:
    
    # Append unique values of crime types to "crime_type" list
    if case["properties"]["Offense"] not in crime_type:
        crime_type.append(case["properties"]["Offense"])

# View "crime_type"
crime_type
# Out:
# ['Theft',
#  'Robbery',
#  'Burglary',
#  'Aggravated Assault',
#  'Rape',
#  'Auto Theft',
#  'Murder']

# %%
# List for violet crimes
violet_crime = ["Aggravated Assault", "Murder", "Robbery", "Rape"]

# List for non-violet crimes
non_violet_crime = ["Theft", "Burglary", "Auto Theft"]

# %% [markdown]
# ###### >> Slim and clean up crime data

# %%
# Generate a new empty Pandas dataframe with columns of "Offense", "Crime Type", "Lat", and "Lng"
crime_info_pd = pd.DataFrame(columns = ["Offense", "Crime Type", "Lat", "Lng"])

# Check "crime_info_pd"
crime_info_pd
# Out:
# Empty DataFrame
# Columns: [Offense, Crime Type, Lat, Lng]
# Index: []

# %%
# List to store date of crime
crime_date = []

# Loop through "crime_list"
for case in crime_list:

    # Note that adding value to column immediately changes the length of "crime_info_pd"
    # Temporarily assign (fix) it to intermediate variable "im" to be referred before each iteration
    im = len(crime_info_pd)
    
    # Append data to "Offense" column of "crime_info_pd"
    crime_info_pd.loc[im, "Offense"] = case["properties"]["Offense"]
    
    # Determine crime type (violet/non-violet) via comparison with "violet_crime" and "non_violet_crime" lists
    if case["properties"]["Offense"] in violet_crime:
        crime_info_pd.loc[im, "Crime Type"] = "Violet"
    if case["properties"]["Offense"] in non_violet_crime:
        crime_info_pd.loc[im, "Crime Type"] = "Non-Violet"
    
    # Append longitude value to "Lng" column
    crime_info_pd.loc[im, "Lng"] = case["geometry"]["coordinates"][0]

    # Append Latitude value to "Lat" column
    crime_info_pd.loc[im, "Lat"] = case["geometry"]["coordinates"][1]   
    
    # Convert date info. into datetime format and temporatorily assign it to "date_im"
    date_im = datetime.datetime.strptime(case["properties"]["Time_Begun"][:10], "%Y-%m-%d")
    # Append date info into "crime_date" list as "yyyy-mm-dd"
    crime_date.append(date_im.strftime("%Y-%m-%d"))
    
# Preview "crime_info_pd"
crime_info_pd.head()
# Out:
#     Offense  Crime Type      Lat      Lng
# 0     Theft  Non-Violet   29.829 -95.3808
# 1   Robbery      Violet  29.7036 -95.3501
# 2  Burglary  Non-Violet   29.768 -95.3189
# 3  Burglary  Non-Violet  29.5605 -95.1256
# 4   Robbery      Violet  29.9216 -95.4103

# %%
# Remove cases of crime with missing data if any
crime_info_pd = crime_info_pd.dropna(how="any")

# Check the length of "crime_info_pd"
len(crime_info_pd)
# Out:
# 7368

# %%
# Print the date range of HPD recent crime data 
date_range = str("from " + min(crime_date) + " to " + max(crime_date))

print("Crime Report" + " " + date_range)
# Out:
# Crime Report from 2019-02-21 to 2019-03-20

# %%
# Write "crime_info_pd" to csv file
crime_info_pd.to_csv("../data/cleandata/HPD_Crime_Report.csv", index=False, header=True)
