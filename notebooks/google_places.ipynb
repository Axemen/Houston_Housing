# %%
# Dependencies
import requests
import json
import pandas as pd
import numpy as np

# Google developer API key
from api_keys import gkey

# %%
# read addresses file and create dataframe
addresses_file = "County_Adds.csv"
addresses_df = pd.read_csv(addresses_file, encoding="ISO-8859-1")
addresses_df.set_index(addresses_df.iloc[:,0],inplace=True)
addresses_df.drop(columns='Unnamed: 0',inplace=True)
del addresses_df.index.name
addresses_df.head()
# Out:
#      zip                              address        lat        lng  County
# 0  78944   187 BUENGER RD, INDUSTRY, TX 78944  29.967902 -96.493013  Austin
# 1  78944  7523 ERNST PKWY, INDUSTRY, TX 78944  29.968208 -96.501229  Austin
# 2  78944     7586 ABKE LN, INDUSTRY, TX 78944  29.968105 -96.499605  Austin
# 3  78944  7474 ERNST PKWY, INDUSTRY, TX 78944  29.968003 -96.500844  Austin
# 4  78944     7571 ABKE LN, INDUSTRY, TX 78944  29.967776 -96.499775  Austin

# %%
#find max and min lats and lngs in Houston
max_lat=addresses_df['lat'].max()
min_lat=addresses_df['lat'].min()
max_lng=addresses_df['lng'].max()
min_lng=addresses_df['lng'].min()
houston_lng_range=max_lng-min_lng
houston_lat_range=max_lat-min_lat

print(f"Houston max lat is: {max_lat}.")
print(f"Houston min lat is: {min_lat}.")
print(f"Houston max lng is: {max_lng}.")
print(f"Houston min lng is: {min_lng}.")

#find increment for walking distance (miles for ranges found in google maps)
miles_per_lat=houston_lat_range/150
miles_per_lng=houston_lng_range/160
# Out:
# Houston max lat is: 30.655781.
# Houston min lat is: 28.870009000000003.
# Houston max lng is: -94.3831.
# Houston min lng is: -96.594711.

# %%
#create arrays for lat and lng for API calls from google places (each call will be for 1 mile increments)
lat_range=np.arange(min_lat,max_lat,miles_per_lat)
lng_range=np.arange(min_lng,max_lng,miles_per_lng)
lat_lng=[]
for lat in lat_range:
    for lng in lng_range:
        lat_lng.append((str(lat),str(lng)))
len(lat_lng)
# Out:
# 24000

# %%
# geocoordinates
target_coordinates = "29.832686, -95.648138"
#target_search = "Spanish"
target_radius = 1000
target_type = "bar"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)
# Out:
#             Unnamed: 0    zip                                        address  \
# Unnamed: 0
# 0                    0  78944             187 BUENGER RD, INDUSTRY, TX 78944
# 1                    1  78944            7523 ERNST PKWY, INDUSTRY, TX 78944
# 2                    2  78944               7586 ABKE LN, INDUSTRY, TX 78944
# 3                    3  78944            7474 ERNST PKWY, INDUSTRY, TX 78944
# 4                    4  78944               7571 ABKE LN, INDUSTRY, TX 78944
# 5                    5  78944            7481 ERNST PKWY, INDUSTRY, TX 78944
# 6                    6  78944             158 BUENGER RD, INDUSTRY, TX 78944
# 7                    7  78944             951 BUENGER RD, INDUSTRY, TX 78944
# 8                    8  78944            7352 ERNST PKWY, INDUSTRY, TX 78944
# 9                    9  78944            7302 ERNST PKWY, INDUSTRY, TX 78944
# 10                  10  78944             836 BUENGER RD, INDUSTRY, TX 78944
# 11                  11  78944               564 JONES ST, INDUSTRY, TX 78944
# 12                  12  78944            7260 ERNST PKWY, INDUSTRY, TX 78944
# 13                  13  78944            7096 ERNST PKWY, INDUSTRY, TX 78944
# 14                  14  78944             500 BUENGER RD, INDUSTRY, TX 78944
# 15                  15  78944             419 BUENGER RD, INDUSTRY, TX 78944
# 16                  16  78944            7558 ERNST PKWY, INDUSTRY, TX 78944
# 17                  17  78944               477 JONES ST, INDUSTRY, TX 78944
# 18                  18  78944            7577 ERNST PKWY, INDUSTRY, TX 78944
# 19                  19  78944            7514 ERNST PKWY, INDUSTRY, TX 78944
# 16          29.969180 -96.501174  Austin
# 17          29.969875 -96.503822  Austin
# 18          29.969050 -96.501462  Austin
# 19          29.968562 -96.501005  Austin
# 20          29.968212 -96.492646  Austin
# 21          29.969449 -96.501567  Austin
# 22          29.969453 -96.501245  Austin
# 23          29.969461 -96.505881  Austin
# 24          29.969572 -96.505298  Austin
# 25          29.969650 -96.504890  Austin
# 26          29.970378 -96.501802  Austin
# 27          29.969660 -96.504833  Austin
# 28          29.969713 -96.504534  Austin
# 29          29.969763 -96.501321  Austin
# ...               ...        ...     ...
# 390458      29.788863 -95.944047  Waller
# 390459      29.788872 -95.957250  Waller
# 390460      29.788933 -95.951850  Waller
# 390461      29.788941 -95.957213  Waller
# 390462      29.788960 -95.951436  Waller
# 390463      29.787888 -95.947388  Waller
# 390464      29.787963 -95.956321  Waller
# 390465      29.787970 -95.944110  Waller
# 390466      29.788043 -95.951418  Waller
# 390467      29.787311 -95.956234  Waller
# 390468      29.788975 -95.949826  Waller
# 390469      29.822780 -95.992580  Waller
# 390470      29.822780 -95.992580  Waller
# 390471      29.822780 -95.992580  Waller
# 390472      29.822780 -95.992580  Waller
# 390473      29.822780 -95.992580  Waller
# 390474      29.822780 -95.992580  Waller
# 390475      29.822780 -95.992580  Waller
# 390476      29.757597 -95.950779  Waller
# 390477      29.822780 -95.992580  Waller
# 390478      29.822780 -95.992580  Waller
# 390479      29.822780 -95.992580  Waller
# 390480      29.822780 -95.992580  Waller
# 390481      29.822780 -95.992580  Waller
# 390482      29.822780 -95.992580  Waller
# 390483      29.822780 -95.992580  Waller
# 390484      29.822780 -95.992580  Waller
# 390485      29.822780 -95.992580  Waller
# 390486      29.822780 -95.992580  Waller
# 390487      29.822780 -95.992580  Waller
#
# [390488 rows x 6 columns]

# %%
# convert response to json
places_data = response.json()

# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 29.8367417,
#                     "lng": -95.64847979999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.8380914802915,
#                         "lng": -95.64701601970849
#                     },
#                     "southwest": {
#                         "lat": 29.8353935197085,
#                         "lng": -95.6497139802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "4f6136b97418531b513f85b60288c3a3b617dc61",
#             "name": "Los Cucos Mexican Restaurant",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103965961790541241148/photos\">Zombistino\u2019s My name</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAsjXpUtdT73lDWib0lOQWOUv7Z9FR9IocdUrVfgAknMuB_kwhkHT0ovxEumtbeWxJhQdBmAvqDrNOPvf1lgxXFtztykQrYA5_vKvYVDdqPt2_sohnlLg999zcmoBoPkPXEhBPuY345_r8fZOrx7aozrEEGhSWqxb2grot-rRZ0ol9sU_acAmsng",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJIdUjZfbZQIYRox8ClzFKARA",
#             "plus_code": {
#                 "compound_code": "R9P2+MJ Bear Creek Central, Texas, United States",
#                 "global_code": "76X6R9P2+MJ"
#             },
#             "price_level": 2,
#             "rating": 4.2,
#             "reference": "ChIJIdUjZfbZQIYRox8ClzFKARA",
#             "scope": "GOOGLE",
#             "types": [
#                 "bar",
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 1308,
#             "vicinity": "16216 Clay Road, Houston"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 29.8344332,
#                     "lng": -95.6460748
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.8357831302915,
#                         "lng": -95.6446663697085
#                     },
#                     "southwest": {
#                         "lat": 29.8330851697085,
#                         "lng": -95.64736433029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "e7145c384faf3f2fa69ff4aa0ab6c0ae230168d2",
#             "name": "Agave Bar",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 720,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110566443132676909325/photos\">jose Alvarez Majano</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAfKdadT1eCg6eIPOojZj99xpw1aDFbs5s2HCT5WfYJmG3dzVD15KTmMzVGlFBdTjQYmlRyU6Z0R16ptz7cm3fW9Ap1aeTwwSe-IlvbgGqzqKoPKce3iYcCL0oHT0B5midEhA1ISs-QxEJXXNQOi1bvhECGhSZOkednt9dNGyNRjGpUNrcqnPVOQ",
#                     "width": 960
#                 }
#             ],
#             "place_id": "ChIJy7WN1PXZQIYRWTgx2_bVzpY",
#             "plus_code": {
#                 "compound_code": "R9M3+QH Clay Hills Plaza, Houston, TX, United States",
#                 "global_code": "76X6R9M3+QH"
#             },
#             "rating": 4,
#             "reference": "ChIJy7WN1PXZQIYRWTgx2_bVzpY",
#             "scope": "GOOGLE",
#             "types": [
#                 "bar",
#                 "night_club",
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 105,
#             "vicinity": "16231 Clay Road #440, Houston"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 29.8380625,
#                     "lng": -95.64621760000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.8394134802915,
#                         "lng": -95.6446469697085
#                     },
#                     "southwest": {
#                         "lat": 29.8367155197085,
#                         "lng": -95.64734493029152
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "fd88c89c88e1cde356f1baf6570e6cd3cc026398",
#             "name": "Hank's Crawfish Bar & Grill",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 492,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107312701215270531945/photos\">Hank&#39;s Crawfish Bar &amp; Grill</a>"
#                     ],
#                     "photo_reference": "CmRaAAAADqkGuc3c8q7XwAt48pgjn1D-KjIY3XCGwr2ahV5E6R3Qgis6h_zkOHrDXrbjK7kd2tEv-gO8KIf1LkcyuC0tH_-MPmPKGLrGpsFWzKkbP_Zx4W8GMAkOwzQ8BHWcJlK7EhCHYutwR6mkf5rUdNN_rJRDGhR61d9RrkfIL_W8NwrfF846UEEBgA",
#                     "width": 874
#                 }
#             ],
#             "place_id": "ChIJW5hLI_bZQIYRUUI_v6koNg0",
#             "plus_code": {
#                 "compound_code": "R9Q3+6G Bear Creek Central, Texas, United States",
#                 "global_code": "76X6R9Q3+6G"
#             },
#             "price_level": 2,
#             "rating": 4.3,
#             "reference": "ChIJW5hLI_bZQIYRUUI_v6koNg0",
#             "scope": "GOOGLE",
#             "types": [
#                 "bar",
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 697,
#             "vicinity": "4409 Highway 6 North, Houston"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 29.8372623,
#                     "lng": -95.6468101
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.8386122302915,
#                         "lng": -95.64537821970849
#                     },
#                     "southwest": {
#                         "lat": 29.8359142697085,
#                         "lng": -95.6480761802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "fd067d441e8375eca0be30bd1004e673c1986770",
#             "name": "Lazy Frog Bar",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114304213551286564060/photos\">Lazy Frog Bar</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAA15hCmOQS5YkGEn2bbbjF13e8um8llJ1DsGkLsk6EiMF-_aKlftY2TuDVGyc2qc4JCq8jkzI2ZQTeKyDI53mSmcL-vyAJJEWcnaT5uBxPWcn8yPrnA8-SpG--1mIAwO2EhCK1r8HU6XWhZkykWv7THqrGhQdM1QU-umvIe-WbvVV7yp-xLsDfg",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJVYcEFPbZQIYR8uztlGV-nng",
#             "plus_code": {
#                 "compound_code": "R9P3+W7 Bear Creek Central, Texas, United States",
#                 "global_code": "76X6R9P3+W7"
#             },
#             "rating": 3.8,
#             "reference": "ChIJVYcEFPbZQIYR8uztlGV-nng",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "bar",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 145,
#             "vicinity": "4329 Highway 6 North, Houston"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 29.8390231,
#                     "lng": -95.646512
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.84037703029149,
#                         "lng": -95.64480046970849
#                     },
#                     "southwest": {
#                         "lat": 29.83767906970849,
#                         "lng": -95.6474984302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png",
#             "id": "0f6f90adb4e0ee51fe38219faa339c32751fa1a6",
#             "name": "J J's Bar",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108274901784615281318/photos\">Rachel McKellar</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAXApg2QZucnVkEfuAPTmIHvmgBG1q3dsqkjQmabIBdh-nmycM5NAIcFwWNMGDd3vlxee7riDFwU6cX7nFenPwseTaOlhV-j0105J6i83-rBtl8zcuno8LhrKZXgkOd3YdEhCrlyEdnkeEk8_W5MXzfNH2GhT8Sr0FRTq6KElJwj3De-o2W_VHPQ",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJLWLvMfbZQIYRZgFYrThHidM",
#             "plus_code": {
#                 "compound_code": "R9Q3+J9 Bear Creek Central, Texas, United States",
#                 "global_code": "76X6R9Q3+J9"
#             },
#             "price_level": 1,
#             "rating": 4.3,
#             "reference": "ChIJLWLvMfbZQIYRZgFYrThHidM",
#             "scope": "GOOGLE",
#             "types": [
#                 "bar",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 72,
#             "vicinity": "4505 Highway 6 # 25, Houston"
#         }
#     ],
#     "status": "OK"
# }

# %%
places=places_data["results"]
places
names = [place["name"] for place in places]
ammenity_count=len(names)
ammenity_count
# Out:
# 5
