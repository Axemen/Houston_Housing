# %%
# Dependencies
import gmaps
import requests
import pandas as pd
import datetime
from api_keys import gkey

# %% [markdown]
# ### Data Retrieval

# %%
# Query url from COHGIS Open Data Portal
url = "https://opendata.arcgis.com/datasets/8d515a90e80840b3bc7a3ada352b0d15_0.geojson"

# Get HPD recent crime data
response = requests.get(url)

# Convert "response" to JSON format
crime_report = response.json()

# Preview "crime_report"
crime_report
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'OBJECTID': 1001,
#     'Join_Count': 1,
#     'TARGET_FID': 1001,
#     'Join_Count_1': 1,
#     'Incident_No': 33788619,
#     'Time_Begun': '2019-03-17T16:06:00.000Z',
#     'UCR_No': 6143,
#     'HPD_Beat': '15E40',
#     'HPD_District': '15',
#     'Offense': 'Theft',
#     'Address_Range': '2500-2599 S LOOP W',
#     'Premise_Type': 'Restaurant or Cafeteria P',
#     'X_Coord': 3106127.89573,
#     'Y_Coord': 13811273.98095,
#     'Zip_Code': '77054',
#     'Time_Frame': 2,
#     'SNB_No': 35,
#     'SNB_Name': 'SOUTH MAIN',
#     'Council_District': 'K',
#     'HPD_Division': 'Southwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.41677792670406, 29.677404853365786]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1002,
#     'Join_Count': 1,
#     'TARGET_FID': 1002,
#     'Join_Count_1': 1,
#     'Incident_No': 23193419,
#     'Time_Begun': '2019-02-21T14:45:00.000Z',
#     'UCR_No': 6013,
#     'HPD_Beat': '16E10',
#     'HPD_District': '16',
#     'Offense': 'Theft',
#     'Address_Range': '1800-1899 ALMEDA GENOA',
#     'Premise_Type': 'Vehicle/Auto Sales/Lease/',
#     'X_Coord': 3114071.71201,
#     'Y_Coord': 13788437.22854,
#     'Zip_Code': '77047',
#     'Time_Frame': 3,
#     'SNB_No': 40,
#     'SNB_Name': 'CENTRAL SOUTHWEST',
#     'Council_District': 'D',
#     'HPD_Division': 'Southwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.39398994213073, 29.613960019908866]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1003,
#     'Join_Count': 1,
#     'TARGET_FID': 1003,
#     'Join_Count_1': 1,
#     'Incident_No': 25663519,
#     'Time_Begun': '2019-02-27T20:08:00.000Z',
#     'UCR_No': 3001,
#     'HPD_Beat': '2A10',
#     'HPD_District': '2',
#     'Offense': 'Robbery',
#     'Address_Range': '200-299 PATTON',
#     'Premise_Type': 'Other Parking Lot',
#     'X_Coord': 3119608.83317,
#     'Y_Coord': 13855619.05184,
#     'Zip_Code': '77009',
#     'Time_Frame': 3,
#     'SNB_No': 51,
#     'SNB_Name': 'NEAR NORTHSIDE',
#     'Council_District': 'H',
#     'HPD_Division': 'Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.37000964458869, 29.798153799505492]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1004,
#     'Join_Count': 1,
#     'TARGET_FID': 1004,
#     'Join_Count_1': 1,
#     'Incident_No': 25675519,
#     'Time_Begun': '2019-02-27T18:00:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '18F30',
#     'HPD_District': '18',
#     'Offense': 'Theft',
#     'Address_Range': '3900-3999 HILLCROFT',
#     'Premise_Type': 'Convenience Store Parking',
#     'X_Coord': 3078865.05928,
#     'Y_Coord': 13827459.302,
#     'Zip_Code': '77057',
#     'Time_Frame': 3,
#     'SNB_No': 20,
#     'SNB_Name': 'MID WEST',
#     'Council_District': 'J',
#     'HPD_Division': 'Midwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.50107213982906, 29.724164674462216]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1005,
#     'Join_Count': 1,
#     'TARGET_FID': 1005,
#     'Join_Count_1': 1,
#     'Incident_No': 27840019,
#     'Time_Begun': '2019-03-04T13:00:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '13D40',
#     'HPD_District': '13',
#     'Offense': 'Theft',
#     'Address_Range': '10100-10199 GULF MEADOWS',
#     'Premise_Type': 'Road, Street, or Sidewalk',
#     'X_Coord': 3149526.04539,
#     'Y_Coord': 13791633.9938,
#     'Zip_Code': '77075',
#     'Time_Frame': 3,
#     'SNB_No': 78,
#     'SNB_Name': 'GREATER HOBBY AREA',
#     'Council_District': 'D',
#     'HPD_Division': 'Southeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.28214143909432, 29.619694669527973]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1006,
#     'Join_Count': 1,
#     'TARGET_FID': 1006,
#     'Join_Count_1': 1,
#     'Incident_No': 27837219,
#     'Time_Begun': '2019-03-04T14:35:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '12D40',
#     'HPD_District': '12',
#     'Offense': 'Theft',
#     'Address_Range': '11900-11999 ASTORIA',
#     'Premise_Type': 'Hospital Parking Lot',
#     'X_Coord': 3173916.92746,
#     'Y_Coord': 13780015.16487,
#     'Zip_Code': '77089',
#     'Time_Frame': 3,
#     'SNB_No': 80,
#     'SNB_Name': 'SOUTH BELT / ELLINGTON',
#     'Council_District': 'D',
#     'HPD_Division': 'Clear Lake Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.20659828775459, 29.585604291721136]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1007,
#     'Join_Count': 1,
#     'TARGET_FID': 1007,
#     'Join_Count_1': 1,
#     'Incident_No': 23975619,
#     'Time_Begun': '2019-02-23T23:15:00.000Z',
#     'UCR_No': 6031,
#     'HPD_Beat': '22B10',
#     'HPD_District': '22',
#     'Offense': 'Theft',
#     'Address_Range': '17700-17799 TOMBALL PKWY OB',
#     'Premise_Type': 'Bar or Night Club',
#     'X_Coord': 3061899.49397,
#     'Y_Coord': 13913000.332,
#     'Zip_Code': '77070',
#     'Time_Frame': 3,
#     'SNB_No': 1,
#     'SNB_Name': 'WILLOWBROOK',
#     'Council_District': 'A',
#     'HPD_Division': 'North Belt Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.54654471968797, 29.96067995758791]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1008,
#     'Join_Count': 1,
#     'TARGET_FID': 1008,
#     'Join_Count_1': 1,
#     'Incident_No': 24456319,
#     'Time_Begun': '2019-02-22T15:00:00.000Z',
#     'UCR_No': 5072,
#     'HPD_Beat': '10H40',
#     'HPD_District': '10',
#     'Offense': 'Burglary',
#     'Address_Range': '2800-2899 FANNIN',
#     'Premise_Type': 'Construction Site',
#     'X_Coord': 3118816.97916,
#     'Y_Coord': 13835632.8755,
#     'Zip_Code': '77002',
#     'Time_Frame': 3,
#     'SNB_No': 62,
#     'SNB_Name': 'MIDTOWN',
#     'Council_District': 'D',
#     'HPD_Division': 'South Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.37445835286795, 29.743285802476763]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1009,
#     'Join_Count': 1,
#     'TARGET_FID': 1009,
#     'Join_Count_1': 1,
#     'Incident_No': 29705819,
#     'Time_Begun': '2019-02-25T01:50:00.000Z',
#     'UCR_No': 6191,
#     'HPD_Beat': '21I10',
#     'HPD_District': '21',
#     'Offense': 'Theft',
#     'Address_Range': '2800-2899 N TERMINAL',
#     'Premise_Type': 'Airport Terminal',
#     'X_Coord': 3123084.49635,
#     'Y_Coord': 13924055.67264,
#     'Zip_Code': '77032',
#     'Time_Frame': 3,
#     'SNB_No': 42,
#     'SNB_Name': 'IAH / AIRPORT AREA',
#     'Council_District': 'B',
#     'HPD_Division': 'Airport-IAH Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.35232729964432, 29.985959071551164]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1010,
#     'Join_Count': 1,
#     'TARGET_FID': 1010,
#     'Join_Count_1': 1,
#     'Incident_No': 28932119,
#     'Time_Begun': '2019-03-06T20:00:00.000Z',
#     'UCR_No': 7001,
#     'HPD_Beat': '1A10',
#     'HPD_District': '1',
#     'Offense': 'Auto Theft',
#     'Address_Range': '1700-1799 MAIN',
#     'Premise_Type': 'Apartment Parking Lot',
#     'X_Coord': 3120385.42774,
#     'Y_Coord': 13838685.98095,
#     'Zip_Code': '77002',
#     'Time_Frame': 3,
#     'SNB_No': 61,
#     'SNB_Name': 'DOWNTOWN',
#     'Council_District': 'I',
#     'HPD_Division': 'Downtown Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.36921947157492, 29.751544067540344]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1011,
#     'Join_Count': 1,
#     'TARGET_FID': 1011,
#     'Join_Count_1': 1,
#     'Incident_No': 24589319,
#     'Time_Begun': '2019-02-25T12:20:00.000Z',
#     'UCR_No': 6131,
#     'HPD_Beat': '10H30',
#     'HPD_District': '10',
#     'Offense': 'Theft',
#     'Address_Range': '2100-2199 LAMAR',
#     'Premise_Type': 'Commercial Parking Lot or',
#     'X_Coord': 3124619.42303,
#     'Y_Coord': 13838408.98229,
#     'Zip_Code': '77003',
#     'Time_Frame': 3,
#     'SNB_No': 61,
#     'SNB_Name': 'DOWNTOWN',
#     'Council_District': 'I',
#     'HPD_Division': 'South Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.35590956761968, 29.75042060311242]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1012,
#     'Join_Count': 1,
#     'TARGET_FID': 1012,
#     'Join_Count_1': 1,
#     'Incident_No': 32585319,
#     'Time_Begun': '2019-03-14T23:00:00.000Z',
#     'UCR_No': 4043,
#     'HPD_Beat': '22B20',
#     'HPD_District': '22',
#     'Offense': 'Aggravated Assault',
#     'Address_Range': '200-299 W GREENS',
#     'Premise_Type': 'Convenience Store Parking',
#     'X_Coord': 3102166.66259,
#     'Y_Coord': 13909973.42947,
#     'Zip_Code': '77067',
#     'Time_Frame': 2,
#     'SNB_No': 2,
#     'SNB_Name': 'GREATER GREENSPOINT',
#     'Council_District': 'B',
#     'HPD_Division': 'North Belt Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.4197329339901, 29.949030978858087]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1013,
#     'Join_Count': 1,
#     'TARGET_FID': 1013,
#     'Join_Count_1': 1,
#     'Incident_No': 30864219,
#     'Time_Begun': '2019-03-11T04:20:00.000Z',
#     'UCR_No': 5041,
#     'HPD_Beat': '19G20',
#     'HPD_District': '19',
#     'Offense': 'Burglary',
#     'Address_Range': '11700-11799 BELLAIRE',
#     'Premise_Type': 'Other, Unknown, or Not Li',
#     'X_Coord': 3052332.56111,
#     'Y_Coord': 13819251.95844,
#     'Zip_Code': '77072',
#     'Time_Frame': 3,
#     'SNB_No': 25,
#     'SNB_Name': 'ALIEF',
#     'Council_District': 'F',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.58538703207141, 29.703760347636862]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1014,
#     'Join_Count': 1,
#     'TARGET_FID': 1014,
#     'Join_Count_1': 1,
#     'Incident_No': 27612419,
#     'Time_Begun': '2019-03-03T21:00:00.000Z',
#     'UCR_No': 7001,
#     'HPD_Beat': '12D40',
#     'HPD_District': '12',
#     'Offense': 'Auto Theft',
#     'Address_Range': '700-799 FM 1959',
#     'Premise_Type': 'Apartment Parking Lot',
#     'X_Coord': 3182300.99949,
#     'Y_Coord': 13783103.99409,
#     'Zip_Code': '77598',
#     'Time_Frame': 3,
#     'SNB_No': 80,
#     'SNB_Name': 'SOUTH BELT / ELLINGTON',
#     'Council_District': 'E',
#     'HPD_Division': 'Clear Lake Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.17991517502237, 29.593344085473497]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1015,
#     'Join_Count': 1,
#     'TARGET_FID': 1015,
#     'Join_Count_1': 1,
#     'Incident_No': 33300619,
#     'Time_Begun': '2019-03-16T12:30:00.000Z',
#     'UCR_No': 6131,
#     'HPD_Beat': '14D10',
#     'HPD_District': '14',
#     'Offense': 'Theft',
#     'Address_Range': '4900-4999 MARTIN LUTHER KING',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3131726.42823,
#     'Y_Coord': 13822696.24485,
#     'Zip_Code': '77021',
#     'Time_Frame': 2,
#     'SNB_No': 68,
#     'SNB_Name': 'GREATER OST / SOUTH UNION',
#     'Council_District': 'D',
#     'HPD_Division': 'Southeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.33507437455371, 29.706620540832766]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1016,
#     'Join_Count': 1,
#     'TARGET_FID': 1016,
#     'Join_Count_1': 1,
#     'Incident_No': 27830019,
#     'Time_Begun': '2019-03-04T18:28:00.000Z',
#     'UCR_No': 6073,
#     'HPD_Beat': '1A50',
#     'HPD_District': '1',
#     'Offense': 'Theft',
#     'Address_Range': '3800-3899 RICHMOND',
#     'Premise_Type': 'Convenience Store',
#     'X_Coord': 3098315.74882,
#     'Y_Coord': 13831145.87577,
#     'Zip_Code': '77027',
#     'Time_Frame': 3,
#     'SNB_No': 87,
#     'SNB_Name': 'GREENWAY / UPPER KIRBY AREA',
#     'Council_District': 'C',
#     'HPD_Division': 'Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.43946391448387, 29.732684099145025]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1017,
#     'Join_Count': 1,
#     'TARGET_FID': 1017,
#     'Join_Count_1': 1,
#     'Incident_No': 26373019,
#     'Time_Begun': '2019-03-01T11:30:00.000Z',
#     'UCR_No': 6143,
#     'HPD_Beat': '1A50',
#     'HPD_District': '1',
#     'Offense': 'Theft',
#     'Address_Range': '2100-2199 BRIARGLEN',
#     'Premise_Type': 'Driveway',
#     'X_Coord': 3094622.68936,
#     'Y_Coord': 13835839.52849,
#     'Zip_Code': '77027',
#     'Time_Frame': 3,
#     'SNB_No': 23,
#     'SNB_Name': 'AFTON OAKS / RIVER OAKS AREA',
#     'Council_District': 'G',
#     'HPD_Division': 'Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.45064642736665, 29.74589445686976]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1018,
#     'Join_Count': 1,
#     'TARGET_FID': 1018,
#     'Join_Count_1': 1,
#     'Incident_No': 34978219,
#     'Time_Begun': '2019-03-19T19:30:00.000Z',
#     'UCR_No': 6071,
#     'HPD_Beat': '12D70',
#     'HPD_District': '12',
#     'Offense': 'Theft',
#     'Address_Range': '1400-1499 W BAY AREA',
#     'Premise_Type': 'Department or Discount St',
#     'X_Coord': 3194014.10324,
#     'Y_Coord': 13763693.44695,
#     'Zip_Code': '77598',
#     'Time_Frame': 2,
#     'SNB_No': 81,
#     'SNB_Name': 'CLEAR LAKE',
#     'Council_District': 'E',
#     'HPD_Division': 'Clear Lake Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.14509097710037, 29.538934268359373]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1019,
#     'Join_Count': 1,
#     'TARGET_FID': 1019,
#     'Join_Count_1': 1,
#     'Incident_No': 32440419,
#     'Time_Begun': '2019-03-13T21:00:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '22B40',
#     'HPD_District': '22',
#     'Offense': 'Theft',
#     'Address_Range': '5700-5799 HOWELL',
#     'Premise_Type': 'Driveway',
#     'X_Coord': 3137880.90628,
#     'Y_Coord': 13911205.90093,
#     'Zip_Code': '77032',
#     'Time_Frame': 3,
#     'SNB_No': 42,
#     'SNB_Name': 'IAH / AIRPORT AREA',
#     'Council_District': 'B',
#     'HPD_Division': 'North Belt Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.30689339772728, 29.949365058622384]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1020,
#     'Join_Count': 1,
#     'TARGET_FID': 1020,
#     'Join_Count_1': 1,
#     'Incident_No': 32428319,
#     'Time_Begun': '2019-03-14T00:01:00.000Z',
#     'UCR_No': 6191,
#     'HPD_Beat': '17E30',
#     'HPD_District': '17',
#     'Offense': 'Theft',
#     'Address_Range': '11500-11599 SOUTHWEST ',
#     'Premise_Type': 'Service or Gas Station',
#     'X_Coord': 3059222.14976,
#     'Y_Coord': 13801232.36609,
#     'Zip_Code': '77031',
#     'Time_Frame': 2,
#     'SNB_No': 36,
#     'SNB_Name': 'BRAYS OAKS',
#     'Council_District': 'K',
#     'HPD_Division': 'South Gessner Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.56536056582789, 29.65367175973748]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1021,
#     'Join_Count': 1,
#     'TARGET_FID': 1021,
#     'Join_Count_1': 1,
#     'Incident_No': 31992219,
#     'Time_Begun': '2019-03-12T20:00:00.000Z',
#     'UCR_No': 6191,
#     'HPD_Beat': '20G30',
#     'HPD_District': '20',
#     'Offense': 'Theft',
#     'Address_Range': '12400-12499 OXFORD PARK',
#     'Premise_Type': 'Apartment Parking Lot',
#     'X_Coord': 3048206.03357,
#     'Y_Coord': 13830029.6261,
#     'Zip_Code': '77082',
#     'Time_Frame': 3,
#     'SNB_No': 17,
#     'SNB_Name': 'ELDRIDGE / WEST OAKS',
#     'Council_District': 'F',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.59739271230058, 29.73371746761051]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1022,
#     'Join_Count': 1,
#     'TARGET_FID': 1022,
#     'Join_Count_1': 1,
#     'Incident_No': 30477119,
#     'Time_Begun': '2019-03-09T01:00:00.000Z',
#     'UCR_No': 6191,
#     'HPD_Beat': '6B40',
#     'HPD_District': '6',
#     'Offense': 'Theft',
#     'Address_Range': '9600-9699 NORTH ',
#     'Premise_Type': 'Miscellaneous Business (N',
#     'X_Coord': 3104880.65946,
#     'Y_Coord': 13893625.31227,
#     'Zip_Code': '77038',
#     'Time_Frame': 3,
#     'SNB_No': 7,
#     'SNB_Name': 'HIDDEN VALLEY',
#     'Council_District': 'B',
#     'HPD_Division': 'North Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.41275027407839, 29.903868264076774]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1023,
#     'Join_Count': 1,
#     'TARGET_FID': 1023,
#     'Join_Count_1': 1,
#     'Incident_No': 32245019,
#     'Time_Begun': '2019-03-14T10:42:00.000Z',
#     'UCR_No': 4043,
#     'HPD_Beat': '9C10',
#     'HPD_District': '9',
#     'Offense': 'Aggravated Assault',
#     'Address_Range': '8700-8799 JOSIE',
#     'Premise_Type': 'Residence or House',
#     'X_Coord': 3151913.86323,
#     'Y_Coord': 13843712.2648,
#     'Zip_Code': '77029',
#     'Time_Frame': 2,
#     'SNB_No': 57,
#     'SNB_Name': 'PLEASANTVILLE AREA',
#     'Council_District': 'B',
#     'HPD_Division': 'Northeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.26940188603429, 29.762631265865622]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1024,
#     'Join_Count': 1,
#     'TARGET_FID': 1024,
#     'Join_Count_1': 1,
#     'Incident_No': 31380319,
#     'Time_Begun': '2019-03-12T13:07:00.000Z',
#     'UCR_No': 5022,
#     'HPD_Beat': '14D20',
#     'HPD_District': '14',
#     'Offense': 'Burglary',
#     'Address_Range': '4600-4699 MAYFLOWER',
#     'Premise_Type': 'Residence or House',
#     'X_Coord': 3125695.8676,
#     'Y_Coord': 13811425.56792,
#     'Zip_Code': '77033',
#     'Time_Frame': 3,
#     'SNB_No': 71,
#     'SNB_Name': 'SUNNYSIDE',
#     'Council_District': 'D',
#     'HPD_Division': 'Southeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.35516862861378, 29.6761588516518]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1025,
#     'Join_Count': 1,
#     'TARGET_FID': 1025,
#     'Join_Count_1': 1,
#     'Incident_No': 30549819,
#     'Time_Begun': '2019-03-09T10:30:00.000Z',
#     'UCR_No': 6131,
#     'HPD_Beat': '20G50',
#     'HPD_District': '20',
#     'Offense': 'Theft',
#     'Address_Range': '12500-12599 MEMORIAL',
#     'Premise_Type': 'Commercial Parking Lot or',
#     'X_Coord': 3062865.81814,
#     'Y_Coord': 13842307.29774,
#     'Zip_Code': '77024',
#     'Time_Frame': 3,
#     'SNB_No': 16,
#     'SNB_Name': 'MEMORIAL',
#     'Council_District': 'G',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.55007902900896, 29.76628585512363]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1026,
#     'Join_Count': 1,
#     'TARGET_FID': 1026,
#     'Join_Count_1': 1,
#     'Incident_No': 34285219,
#     'Time_Begun': '2019-03-18T18:45:00.000Z',
#     'UCR_No': 3022,
#     'HPD_Beat': '13D10',
#     'HPD_District': '13',
#     'Offense': 'Robbery',
#     'Address_Range': '2400-2499 S WAYSIDE',
#     'Premise_Type': 'Car Wash',
#     'X_Coord': 3137652.52512,
#     'Y_Coord': 13825251.69398,
#     'Zip_Code': '77023',
#     'Time_Frame': 2,
#     'SNB_No': 69,
#     'SNB_Name': 'GULFGATE RIVERVIEW / PINE VALLEY',
#     'Council_District': 'I',
#     'HPD_Division': 'Southeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.31616203522995, 29.713132735176025]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1027,
#     'Join_Count': 1,
#     'TARGET_FID': 1027,
#     'Join_Count_1': 1,
#     'Incident_No': 34760219,
#     'Time_Begun': '2019-03-19T19:55:00.000Z',
#     'UCR_No': 3033,
#     'HPD_Beat': '9C40',
#     'HPD_District': '9',
#     'Offense': 'Robbery',
#     'Address_Range': '1000-1099 CENTERWOOD',
#     'Premise_Type': 'Convenience Store',
#     'X_Coord': 3165512.70071,
#     'Y_Coord': 13847757.58912,
#     'Zip_Code': '77013',
#     'Time_Frame': 2,
#     'SNB_No': 58,
#     'SNB_Name': 'NORTHSHORE',
#     'Council_District': 'I',
#     'HPD_Division': 'Northeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.22615098795664, 29.772550566497163]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1028,
#     'Join_Count': 1,
#     'TARGET_FID': 1028,
#     'Join_Count_1': 1,
#     'Incident_No': 34730119,
#     'Time_Begun': '2019-03-19T18:43:00.000Z',
#     'UCR_No': 6071,
#     'HPD_Beat': '15E40',
#     'HPD_District': '15',
#     'Offense': 'Theft',
#     'Address_Range': '7900-7999 KIRBY',
#     'Premise_Type': 'Drug Store or Medical Sup',
#     'X_Coord': 3107120.97861,
#     'Y_Coord': 13816921.8166,
#     'Zip_Code': '77030',
#     'Time_Frame': 2,
#     'SNB_No': 34,
#     'SNB_Name': 'ASTRODOME AREA',
#     'Council_District': 'K',
#     'HPD_Division': 'Southwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.41310651127965, 29.69284575616589]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1029,
#     'Join_Count': 1,
#     'TARGET_FID': 1029,
#     'Join_Count_1': 1,
#     'Incident_No': 34496319,
#     'Time_Begun': '2019-03-14T17:00:00.000Z',
#     'UCR_No': 6033,
#     'HPD_Beat': '12D70',
#     'HPD_District': '12',
#     'Offense': 'Theft',
#     'Address_Range': '500-599 BARRINGER',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3192984.1168,
#     'Y_Coord': 13773185.69149,
#     'Zip_Code': '77598',
#     'Time_Frame': 2,
#     'SNB_No': 81,
#     'SNB_Name': 'CLEAR LAKE',
#     'Council_District': 'E',
#     'HPD_Division': 'Clear Lake Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.14734525584332, 29.56511851672808]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1030,
#     'Join_Count': 1,
#     'TARGET_FID': 1030,
#     'Join_Count_1': 1,
#     'Incident_No': 34714119,
#     'Time_Begun': '2019-03-19T17:15:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '2A50',
#     'HPD_District': '2',
#     'Offense': 'Theft',
#     'Address_Range': '100-199 HEIGHTS',
#     'Premise_Type': 'Restaurant or Cafeteria P',
#     'X_Coord': 3111260.53084,
#     'Y_Coord': 13845279.67504,
#     'Zip_Code': '77007',
#     'Time_Frame': 2,
#     'SNB_No': 22,
#     'SNB_Name': 'WASHINGTON AVENUE COALITION / MEMORIAL PARK',
#     'Council_District': 'C',
#     'HPD_Division': 'Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.39732320925248, 29.770444001937815]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1031,
#     'Join_Count': 1,
#     'TARGET_FID': 1031,
#     'Join_Count_1': 1,
#     'Incident_No': 34708819,
#     'Time_Begun': '2019-03-06T00:05:00.000Z',
#     'UCR_No': 6191,
#     'HPD_Beat': '7C10',
#     'HPD_District': '7',
#     'Offense': 'Theft',
#     'Address_Range': '1100-1199 SYDNOR',
#     'Premise_Type': 'Road, Street, or Sidewalk',
#     'X_Coord': 3129939.68318,
#     'Y_Coord': 13846246.31578,
#     'Zip_Code': '77020',
#     'Time_Frame': 3,
#     'SNB_No': 55,
#     'SNB_Name': 'GREATER FIFTH WARD',
#     'Council_District': 'B',
#     'HPD_Division': 'Northeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.33837780622211, 29.771505910905194]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1032,
#     'Join_Count': 1,
#     'TARGET_FID': 1032,
#     'Join_Count_1': 1,
#     'Incident_No': 30832319,
#     'Time_Begun': '2019-03-10T20:30:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '18F30',
#     'HPD_District': '18',
#     'Offense': 'Theft',
#     'Address_Range': '6400-6499 WESTHEIMER',
#     'Premise_Type': 'Apartment Parking Lot',
#     'X_Coord': 3079981.80674,
#     'Y_Coord': 13832403.25739,
#     'Zip_Code': '77057',
#     'Time_Frame': 3,
#     'SNB_No': 20,
#     'SNB_Name': 'MID WEST',
#     'Council_District': 'J',
#     'HPD_Division': 'Midwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.49708870728965, 29.737662689517485]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1033,
#     'Join_Count': 1,
#     'TARGET_FID': 1033,
#     'Join_Count_1': 1,
#     'Incident_No': 34481719,
#     'Time_Begun': '2019-03-18T21:30:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '17E10',
#     'HPD_District': '17',
#     'Offense': 'Theft',
#     'Address_Range': '5300-5399 S RICE',
#     'Premise_Type': 'Hotel, Motel, Inn, Etc.',
#     'X_Coord': 3089295.19067,
#     'Y_Coord': 13827961.86553,
#     'Zip_Code': '77081',
#     'Time_Frame': 2,
#     'SNB_No': 27,
#     'SNB_Name': 'GULFTON',
#     'Council_District': 'J',
#     'HPD_Division': 'South Gessner Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.46817722296917, 29.724684071359725]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1034,
#     'Join_Count': 1,
#     'TARGET_FID': 1034,
#     'Join_Count_1': 1,
#     'Incident_No': 34482119,
#     'Time_Begun': '2019-03-19T09:34:00.000Z',
#     'UCR_No': 6191,
#     'HPD_Beat': '10H70',
#     'HPD_District': '10',
#     'Offense': 'Theft',
#     'Address_Range': '2000-2099 HERMANN',
#     'Premise_Type': 'Other Parking Lot',
#     'X_Coord': 3116651.78817,
#     'Y_Coord': 13826010.58703,
#     'Zip_Code': '77030',
#     'Time_Frame': 2,
#     'SNB_No': 66,
#     'SNB_Name': 'MUSEUM PARK',
#     'Council_District': 'D',
#     'HPD_Division': 'South Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.38221606050983, 29.717021263041957]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1035,
#     'Join_Count': 1,
#     'TARGET_FID': 1035,
#     'Join_Count_1': 1,
#     'Incident_No': 34482019,
#     'Time_Begun': '2019-03-19T07:00:00.000Z',
#     'UCR_No': 6191,
#     'HPD_Beat': '15E30',
#     'HPD_District': '15',
#     'Offense': 'Theft',
#     'Address_Range': '3500-3599 NORRIS',
#     'Premise_Type': 'Residence or House',
#     'X_Coord': 3102123.1024,
#     'Y_Coord': 13814835.93095,
#     'Zip_Code': '77025',
#     'Time_Frame': 2,
#     'SNB_No': 32,
#     'SNB_Name': 'BRAESWOOD',
#     'Council_District': 'K',
#     'HPD_Division': 'Southwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.42904166699857, 29.68753267348142]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1036,
#     'Join_Count': 1,
#     'TARGET_FID': 1036,
#     'Join_Count_1': 1,
#     'Incident_No': 26107919,
#     'Time_Begun': '2019-02-28T20:05:00.000Z',
#     'UCR_No': 3041,
#     'HPD_Beat': '2A10',
#     'HPD_District': '2',
#     'Offense': 'Robbery',
#     'Address_Range': '900-999 HENRY',
#     'Premise_Type': 'Residence or House',
#     'X_Coord': 3122707.20369,
#     'Y_Coord': 13849289.77925,
#     'Zip_Code': '77009',
#     'Time_Frame': 3,
#     'SNB_No': 51,
#     'SNB_Name': 'NEAR NORTHSIDE',
#     'Council_District': 'H',
#     'HPD_Division': 'Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.36086616088811, 29.780492046409755]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1037,
#     'Join_Count': 1,
#     'TARGET_FID': 1037,
#     'Join_Count_1': 1,
#     'Incident_No': 26769719,
#     'Time_Begun': '2019-03-02T08:00:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '1A50',
#     'HPD_District': '1',
#     'Offense': 'Theft',
#     'Address_Range': '4400-4499 SAN FELIPE',
#     'Premise_Type': 'Service or Gas Station',
#     'X_Coord': 3093518.04661,
#     'Y_Coord': 13836069.06315,
#     'Zip_Code': '77027',
#     'Time_Frame': 3,
#     'SNB_No': 23,
#     'SNB_Name': 'AFTON OAKS / RIVER OAKS AREA',
#     'Council_District': 'G',
#     'HPD_Division': 'Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.45410402409591, 29.746617526002343]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1038,
#     'Join_Count': 1,
#     'TARGET_FID': 1038,
#     'Join_Count_1': 1,
#     'Incident_No': 25982619,
#     'Time_Begun': '2019-02-21T13:20:00.000Z',
#     'UCR_No': 6191,
#     'HPD_Beat': '21I10',
#     'HPD_District': '21',
#     'Offense': 'Theft',
#     'Address_Range': '2800-2899 N TERMINAL',
#     'Premise_Type': 'Airport Terminal',
#     'X_Coord': 3123084.49635,
#     'Y_Coord': 13924055.67264,
#     'Zip_Code': '77032',
#     'Time_Frame': 3,
#     'SNB_No': 42,
#     'SNB_Name': 'IAH / AIRPORT AREA',
#     'Council_District': 'B',
#     'HPD_Division': 'Airport-IAH Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.35232729964432, 29.985959071551164]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1039,
#     'Join_Count': 1,
#     'TARGET_FID': 1039,
#     'Join_Count_1': 1,
#     'Incident_No': 31292219,
#     'Time_Begun': '2019-03-12T09:00:00.000Z',
#     'UCR_No': 6073,
#     'HPD_Beat': '1A30',
#     'HPD_District': '1',
#     'Offense': 'Theft',
#     'Address_Range': '2100-2199 WESTHEIMER',
#     'Premise_Type': 'Convenience Store',
#     'X_Coord': 3107267.18997,
#     'Y_Coord': 13835021.39884,
#     'Zip_Code': '77019',
#     'Time_Frame': 3,
#     'SNB_No': 87,
#     'SNB_Name': 'GREENWAY / UPPER KIRBY AREA',
#     'Council_District': 'G',
#     'HPD_Division': 'Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.4108969415089, 29.742584568932955]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1040,
#     'Join_Count': 1,
#     'TARGET_FID': 1040,
#     'Join_Count_1': 1,
#     'Incident_No': 34710819,
#     'Time_Begun': '2019-03-14T13:01:00.000Z',
#     'UCR_No': 6191,
#     'HPD_Beat': '19G40',
#     'HPD_District': '19',
#     'Offense': 'Theft',
#     'Address_Range': '11400-11499 GLENWOLDE',
#     'Premise_Type': 'Other, Unknown, or Not Li',
#     'X_Coord': 3054894.94096,
#     'Y_Coord': 13810620.32228,
#     'Zip_Code': '77099',
#     'Time_Frame': 2,
#     'SNB_No': 25,
#     'SNB_Name': 'ALIEF',
#     'Council_District': 'F',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.57811428893815, 29.679827049195627]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1041,
#     'Join_Count': 1,
#     'TARGET_FID': 1041,
#     'Join_Count_1': 1,
#     'Incident_No': 27477019,
#     'Time_Begun': '2019-03-02T20:30:00.000Z',
#     'UCR_No': 6131,
#     'HPD_Beat': '19G10',
#     'HPD_District': '19',
#     'Offense': 'Theft',
#     'Address_Range': '8800-8899 BOONE',
#     'Premise_Type': 'Apartment Parking Lot',
#     'X_Coord': 3055986.93229,
#     'Y_Coord': 13811640.40376,
#     'Zip_Code': '77099',
#     'Time_Frame': 3,
#     'SNB_No': 25,
#     'SNB_Name': 'ALIEF',
#     'Council_District': 'F',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.57458265348993, 29.68254323965792]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1042,
#     'Join_Count': 1,
#     'TARGET_FID': 1042,
#     'Join_Count_1': 1,
#     'Incident_No': 31627319,
#     'Time_Begun': '2019-03-13T00:49:00.000Z',
#     'UCR_No': 3003,
#     'HPD_Beat': '14D20',
#     'HPD_District': '14',
#     'Offense': 'Robbery',
#     'Address_Range': '9200-9299 CULLEN',
#     'Premise_Type': 'Road, Street, or Sidewalk',
#     'X_Coord': 3125806.95535,
#     'Y_Coord': 13804969.49725,
#     'Zip_Code': '77033',
#     'Time_Frame': 3,
#     'SNB_No': 71,
#     'SNB_Name': 'SUNNYSIDE',
#     'Council_District': 'D',
#     'HPD_Division': 'Southeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.35545244933836, 29.65840326977713]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1043,
#     'Join_Count': 0,
#     'TARGET_FID': 1043,
#     'Join_Count_1': 0,
#     'Incident_No': 31613419,
#     'Time_Begun': '2019-03-13T00:05:00.000Z',
#     'UCR_No': 4042,
#     'HPD_Beat': '22B10',
#     'HPD_District': '22',
#     'Offense': 'Aggravated Assault',
#     'Address_Range': '13200-13299 CHAMPIONS CENTRE',
#     'Premise_Type': 'Hotel, Motel, Inn, Etc.',
#     'X_Coord': 3064479.94794,
#     'Y_Coord': 13916058.37565,
#     'Zip_Code': '77069',
#     'Time_Frame': 3,
#     'SNB_No': None,
#     'SNB_Name': None,
#     'Council_District': None,
#     'HPD_Division': None},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.53811337550057, 29.968875631818793]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1044,
#     'Join_Count': 1,
#     'TARGET_FID': 1044,
#     'Join_Count_1': 1,
#     'Incident_No': 31594119,
#     'Time_Begun': '2019-03-09T12:00:00.000Z',
#     'UCR_No': 4041,
#     'HPD_Beat': '17E10',
#     'HPD_District': '17',
#     'Offense': 'Aggravated Assault',
#     'Address_Range': '6600-6699 CHIMNEY ROCK',
#     'Premise_Type': 'Convenience Store Parking',
#     'X_Coord': 3086901.72976,
#     'Y_Coord': 13821785.65969,
#     'Zip_Code': '77081',
#     'Time_Frame': 3,
#     'SNB_No': 27,
#     'SNB_Name': 'GULFTON',
#     'Council_District': 'J',
#     'HPD_Division': 'South Gessner Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.47630110421822, 29.707905495658405]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1045,
#     'Join_Count': 1,
#     'TARGET_FID': 1045,
#     'Join_Count_1': 1,
#     'Incident_No': 34420819,
#     'Time_Begun': '2019-03-19T03:48:00.000Z',
#     'UCR_No': 6143,
#     'HPD_Beat': '22B40',
#     'HPD_District': '22',
#     'Offense': 'Theft',
#     'Address_Range': '15200-15299 JOHN F KENNEDY BLVD OB',
#     'Premise_Type': 'Hotel or Motel Parking Lo',
#     'X_Coord': 3130266.14148,
#     'Y_Coord': 13907585.05302,
#     'Zip_Code': '77032',
#     'Time_Frame': 2,
#     'SNB_No': 42,
#     'SNB_Name': 'IAH / AIRPORT AREA',
#     'Council_District': 'B',
#     'HPD_Division': 'North Belt Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.33128496629729, 29.940072137331477]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1046,
#     'Join_Count': 1,
#     'TARGET_FID': 1046,
#     'Join_Count_1': 1,
#     'Incident_No': 34652919,
#     'Time_Begun': '2019-03-18T20:45:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '1A20',
#     'HPD_District': '1',
#     'Offense': 'Theft',
#     'Address_Range': '800-899 GILLETTE',
#     'Premise_Type': 'Other Parking Lot',
#     'X_Coord': 3115911.01027,
#     'Y_Coord': 13841256.04542,
#     'Zip_Code': '77019',
#     'Time_Frame': 2,
#     'SNB_No': 60,
#     'SNB_Name': 'FOURTH WARD',
#     'Council_District': 'C',
#     'HPD_Division': 'Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.38306354681663, 29.758989595874905]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1047,
#     'Join_Count': 1,
#     'TARGET_FID': 1047,
#     'Join_Count_1': 1,
#     'Incident_No': 31149519,
#     'Time_Begun': '2019-03-11T21:00:00.000Z',
#     'UCR_No': 6143,
#     'HPD_Beat': '1A50',
#     'HPD_District': '1',
#     'Offense': 'Theft',
#     'Address_Range': '3800-3899 RICHMOND',
#     'Premise_Type': 'Commercial Parking Lot or',
#     'X_Coord': 3098315.74882,
#     'Y_Coord': 13831145.87577,
#     'Zip_Code': '77027',
#     'Time_Frame': 3,
#     'SNB_No': 87,
#     'SNB_Name': 'GREENWAY / UPPER KIRBY AREA',
#     'Council_District': 'C',
#     'HPD_Division': 'Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.43946391448387, 29.732684099145025]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1048,
#     'Join_Count': 1,
#     'TARGET_FID': 1048,
#     'Join_Count_1': 1,
#     'Incident_No': 34646419,
#     'Time_Begun': '2019-03-19T15:15:00.000Z',
#     'UCR_No': 6192,
#     'HPD_Beat': '19G50',
#     'HPD_District': '19',
#     'Offense': 'Theft',
#     'Address_Range': '11600-11699 VANDERFORD',
#     'Premise_Type': 'Driveway',
#     'X_Coord': 3054440.39185,
#     'Y_Coord': 13801884.34684,
#     'Zip_Code': '77099',
#     'Time_Frame': 2,
#     'SNB_No': 25,
#     'SNB_Name': 'ALIEF',
#     'Council_District': 'F',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.58034954586704, 29.655849292848863]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1049,
#     'Join_Count': 1,
#     'TARGET_FID': 1049,
#     'Join_Count_1': 1,
#     'Incident_No': 34417119,
#     'Time_Begun': '2019-03-19T06:35:00.000Z',
#     'UCR_No': 7031,
#     'HPD_Beat': '6B10',
#     'HPD_District': '6',
#     'Offense': 'Auto Theft',
#     'Address_Range': '10200-10299 BAUMAN',
#     'Premise_Type': 'Convenience Store',
#     'X_Coord': 3118370.75444,
#     'Y_Coord': 13875979.25644,
#     'Zip_Code': '77076',
#     'Time_Frame': 2,
#     'SNB_No': 45,
#     'SNB_Name': 'NORTHSIDE/NORTHLINE',
#     'Council_District': 'H',
#     'HPD_Division': 'North Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.37192023626794, 29.854222121969865]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1050,
#     'Join_Count': 1,
#     'TARGET_FID': 1050,
#     'Join_Count_1': 1,
#     'Incident_No': 34644219,
#     'Time_Begun': '2019-03-19T15:30:00.000Z',
#     'UCR_No': 6073,
#     'HPD_Beat': '18F40',
#     'HPD_District': '18',
#     'Offense': 'Theft',
#     'Address_Range': '7700-7799 WESTHEIMER',
#     'Premise_Type': 'Restaurant or Cafeteria P',
#     'X_Coord': 3077561.18519,
#     'Y_Coord': 13832293.18115,
#     'Zip_Code': '77063',
#     'Time_Frame': 2,
#     'SNB_No': 20,
#     'SNB_Name': 'MID WEST',
#     'Council_District': 'F',
#     'HPD_Division': 'Midwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.5047232975707, 29.737559249027534]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1051,
#     'Join_Count': 0,
#     'TARGET_FID': 1051,
#     'Join_Count_1': 1,
#     'Incident_No': 34640919,
#     'Time_Begun': '2019-03-19T15:30:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '20G60',
#     'HPD_District': '20',
#     'Offense': 'Theft',
#     'Address_Range': '16800-16899 KATY ',
#     'Premise_Type': 'Other Parking Lot',
#     'X_Coord': 3022825.70171,
#     'Y_Coord': 13847789.92438,
#     'Zip_Code': '77094',
#     'Time_Frame': 2,
#     'SNB_No': None,
#     'SNB_Name': None,
#     'Council_District': 'F',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.67574292273301, 29.784545258871173]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1052,
#     'Join_Count': 1,
#     'TARGET_FID': 1052,
#     'Join_Count_1': 1,
#     'Incident_No': 34635519,
#     'Time_Begun': '2019-03-19T11:30:00.000Z',
#     'UCR_No': 5021,
#     'HPD_Beat': '16E40',
#     'HPD_District': '16',
#     'Offense': 'Burglary',
#     'Address_Range': '14000-14099 FONDREN',
#     'Premise_Type': 'Residence or House',
#     'X_Coord': 3077620.22252,
#     'Y_Coord': 13789585.94715,
#     'Zip_Code': '77085',
#     'Time_Frame': 2,
#     'SNB_No': 41,
#     'SNB_Name': 'FORT BEND HOUSTON',
#     'Council_District': 'K',
#     'HPD_Division': 'Southwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.50855433951682, 29.620159027563254]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1053,
#     'Join_Count': 1,
#     'TARGET_FID': 1053,
#     'Join_Count_1': 1,
#     'Incident_No': 23131319,
#     'Time_Begun': '2019-02-21T14:00:00.000Z',
#     'UCR_No': 7001,
#     'HPD_Beat': '19G10',
#     'HPD_District': '19',
#     'Offense': 'Auto Theft',
#     'Address_Range': '10500-10599 BEECHNUT',
#     'Premise_Type': 'Apartment Parking Lot',
#     'X_Coord': 3058688.48158,
#     'Y_Coord': 13814134.04723,
#     'Zip_Code': '77072',
#     'Time_Frame': 3,
#     'SNB_No': 25,
#     'SNB_Name': 'ALIEF',
#     'Council_District': 'J',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.565847474187, 29.689180117057496]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1054,
#     'Join_Count': 1,
#     'TARGET_FID': 1054,
#     'Join_Count_1': 1,
#     'Incident_No': 30750019,
#     'Time_Begun': '2019-03-09T18:00:00.000Z',
#     'UCR_No': 2004,
#     'HPD_Beat': '2A30',
#     'HPD_District': '2',
#     'Offense': 'Rape',
#     'Address_Range': '1100-1199 NICHOLSON',
#     'Premise_Type': 'Residence or House',
#     'X_Coord': 3108415.81206,
#     'Y_Coord': 13852743.54151,
#     'Zip_Code': '77008',
#     'Time_Frame': 3,
#     'SNB_No': 15,
#     'SNB_Name': 'GREATER HEIGHTS',
#     'Council_District': 'C',
#     'HPD_Division': 'Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.40556288299257, 29.79120052899379]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1055,
#     'Join_Count': 1,
#     'TARGET_FID': 1055,
#     'Join_Count_1': 1,
#     'Incident_No': 31458619,
#     'Time_Begun': '2019-03-11T12:00:00.000Z',
#     'UCR_No': 5031,
#     'HPD_Beat': '3B50',
#     'HPD_District': '3',
#     'Offense': 'Burglary',
#     'Address_Range': '800-899 BERRY',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3120858.57925,
#     'Y_Coord': 13870018.15217,
#     'Zip_Code': '77022',
#     'Time_Frame': 3,
#     'SNB_No': 45,
#     'SNB_Name': 'NORTHSIDE/NORTHLINE',
#     'Council_District': 'H',
#     'HPD_Division': 'North Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.36466013165142, 29.837624942239618]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1056,
#     'Join_Count': 1,
#     'TARGET_FID': 1056,
#     'Join_Count_1': 1,
#     'Incident_No': 31383919,
#     'Time_Begun': '2019-03-11T21:00:00.000Z',
#     'UCR_No': 6151,
#     'HPD_Beat': '18F30',
#     'HPD_District': '18',
#     'Offense': 'Theft',
#     'Address_Range': '6300-6399 SKYLINE',
#     'Premise_Type': 'Vehicle/Auto Sales/Lease/',
#     'X_Coord': 3080858.72061,
#     'Y_Coord': 13828985.14525,
#     'Zip_Code': '77057',
#     'Time_Frame': 3,
#     'SNB_No': 20,
#     'SNB_Name': 'MID WEST',
#     'Council_District': 'J',
#     'HPD_Division': 'Midwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.49464948472945, 29.728194758708195]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1057,
#     'Join_Count': 1,
#     'TARGET_FID': 1057,
#     'Join_Count_1': 1,
#     'Incident_No': 31029119,
#     'Time_Begun': '2019-03-08T14:40:00.000Z',
#     'UCR_No': 6162,
#     'HPD_Beat': '15E40',
#     'HPD_District': '15',
#     'Offense': 'Theft',
#     'Address_Range': '8200-8299 KIRBY',
#     'Premise_Type': None,
#     'X_Coord': 3107361.14474,
#     'Y_Coord': 13815318.8526,
#     'Zip_Code': '77054',
#     'Time_Frame': 3,
#     'SNB_No': 34,
#     'SNB_Name': 'ASTRODOME AREA',
#     'Council_District': 'K',
#     'HPD_Division': 'Southwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.41250526201802, 29.688419328291772]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1058,
#     'Join_Count': 1,
#     'TARGET_FID': 1058,
#     'Join_Count_1': 1,
#     'Incident_No': 34178319,
#     'Time_Begun': '2019-03-17T15:00:00.000Z',
#     'UCR_No': 7001,
#     'HPD_Beat': '15E40',
#     'HPD_District': '15',
#     'Offense': 'Auto Theft',
#     'Address_Range': '8500-8599 KNIGHT',
#     'Premise_Type': 'Road, Street, or Sidewalk',
#     'X_Coord': 3111412.98604,
#     'Y_Coord': 13813204.00358,
#     'Zip_Code': '77054',
#     'Time_Frame': 2,
#     'SNB_No': 34,
#     'SNB_Name': 'ASTRODOME AREA',
#     'Council_District': 'K',
#     'HPD_Division': 'Southwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.39995469564784, 29.682263753905293]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1059,
#     'Join_Count': 1,
#     'TARGET_FID': 1059,
#     'Join_Count_1': 1,
#     'Incident_No': 23512219,
#     'Time_Begun': '2019-02-23T00:06:00.000Z',
#     'UCR_No': 7071,
#     'HPD_Beat': '18F30',
#     'HPD_District': '18',
#     'Offense': 'Auto Theft',
#     'Address_Range': '3300-3399 FOUNTAIN VIEW',
#     'Premise_Type': 'Hotel, Motel, Inn, Etc.',
#     'X_Coord': 3084160.16811,
#     'Y_Coord': 13829645.54519,
#     'Zip_Code': '77057',
#     'Time_Frame': 3,
#     'SNB_No': 20,
#     'SNB_Name': 'MID WEST',
#     'Council_District': 'J',
#     'HPD_Division': 'Midwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.48418939927468, 29.72973757017836]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1060,
#     'Join_Count': 1,
#     'TARGET_FID': 1060,
#     'Join_Count_1': 1,
#     'Incident_No': 24974919,
#     'Time_Begun': '2019-02-25T13:00:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '1A20',
#     'HPD_District': '1',
#     'Offense': 'Theft',
#     'Address_Range': '2700-2799 W DALLAS',
#     'Premise_Type': 'Other Parking Lot',
#     'X_Coord': 3112213.78948,
#     'Y_Coord': 13840570.92448,
#     'Zip_Code': '77019',
#     'Time_Frame': 3,
#     'SNB_No': 24,
#     'SNB_Name': 'NEARTOWN - MONTROSE',
#     'Council_District': 'C',
#     'HPD_Division': 'Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.39477732947591, 29.757420292180615]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1061,
#     'Join_Count': 1,
#     'TARGET_FID': 1061,
#     'Join_Count_1': 1,
#     'Incident_No': 33176919,
#     'Time_Begun': '2019-03-15T22:30:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '18F30',
#     'HPD_District': '18',
#     'Offense': 'Theft',
#     'Address_Range': '6200-6299 RICHMOND',
#     'Premise_Type': 'Hotel or Motel Parking Lo',
#     'X_Coord': 3082118.06926,
#     'Y_Coord': 13830331.34425,
#     'Zip_Code': '77057',
#     'Time_Frame': 2,
#     'SNB_No': 20,
#     'SNB_Name': 'MID WEST',
#     'Council_District': 'J',
#     'HPD_Division': 'Midwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.4905560374756, 29.731791333481443]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1062,
#     'Join_Count': 1,
#     'TARGET_FID': 1062,
#     'Join_Count_1': 1,
#     'Incident_No': 33171219,
#     'Time_Begun': '2019-03-16T00:01:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '6B30',
#     'HPD_District': '6',
#     'Offense': 'Theft',
#     'Address_Range': '7100-7199 LOG VIEW',
#     'Premise_Type': 'Driveway',
#     'X_Coord': 3078272.14426,
#     'Y_Coord': 13887721.07123,
#     'Zip_Code': '77040',
#     'Time_Frame': 2,
#     'SNB_No': 5,
#     'SNB_Name': 'GREATER INWOOD',
#     'Council_District': 'A',
#     'HPD_Division': 'North Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.49725364821124, 29.889857277642466]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1063,
#     'Join_Count': 1,
#     'TARGET_FID': 1063,
#     'Join_Count_1': 1,
#     'Incident_No': 33171019,
#     'Time_Begun': '2019-03-16T07:50:00.000Z',
#     'UCR_No': 6073,
#     'HPD_Beat': '15E40',
#     'HPD_District': '15',
#     'Offense': 'Theft',
#     'Address_Range': '8600-8699 ALMEDA',
#     'Premise_Type': 'Service or Gas Station',
#     'X_Coord': 3113488.86403,
#     'Y_Coord': 13812301.41944,
#     'Zip_Code': '77054',
#     'Time_Frame': 2,
#     'SNB_No': 35,
#     'SNB_Name': 'SOUTH MAIN',
#     'Council_District': 'K',
#     'HPD_Division': 'Southwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.39350768852525, 29.679606904820524]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1064,
#     'Join_Count': 1,
#     'TARGET_FID': 1064,
#     'Join_Count_1': 1,
#     'Incident_No': 32178719,
#     'Time_Begun': '2019-03-14T07:43:00.000Z',
#     'UCR_No': 3031,
#     'HPD_Beat': '4F30',
#     'HPD_District': '4',
#     'Offense': 'Robbery',
#     'Address_Range': '1200-1299 N SH 6',
#     'Premise_Type': 'Convenience Store',
#     'X_Coord': 3032573.46279,
#     'Y_Coord': 13849556.14331,
#     'Zip_Code': '77084',
#     'Time_Frame': 2,
#     'SNB_No': 9,
#     'SNB_Name': 'ADDICKS PARK TEN',
#     'Council_District': 'A',
#     'HPD_Division': 'Northwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.6448655176992, 29.788634973236586]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1065,
#     'Join_Count': 1,
#     'TARGET_FID': 1065,
#     'Join_Count_1': 1,
#     'Incident_No': 34348619,
#     'Time_Begun': '2019-03-18T21:21:00.000Z',
#     'UCR_No': 5041,
#     'HPD_Beat': '3B10',
#     'HPD_District': '3',
#     'Offense': 'Burglary',
#     'Address_Range': '10600-10699 HEMPSTEAD',
#     'Premise_Type': 'Office Building',
#     'X_Coord': 3087571.4778,
#     'Y_Coord': 13858668.16802,
#     'Zip_Code': '77092',
#     'Time_Frame': 2,
#     'SNB_No': 86,
#     'SNB_Name': 'SPRING BRANCH EAST',
#     'Council_District': 'A',
#     'HPD_Division': 'North Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.47068651337061, 29.809231076242174]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1066,
#     'Join_Count': 1,
#     'TARGET_FID': 1066,
#     'Join_Count_1': 1,
#     'Incident_No': 29314119,
#     'Time_Begun': '2019-03-07T23:15:00.000Z',
#     'UCR_No': 4041,
#     'HPD_Beat': '6B20',
#     'HPD_District': '6',
#     'Offense': 'Aggravated Assault',
#     'Address_Range': '1000-1099 MARCELLA',
#     'Premise_Type': 'Residence or House',
#     'X_Coord': 3101996.16787,
#     'Y_Coord': 13872157.57014,
#     'Zip_Code': '77091',
#     'Time_Frame': 3,
#     'SNB_No': 6,
#     'SNB_Name': 'ACRES HOME',
#     'Council_District': 'B',
#     'HPD_Division': 'North Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.42392171572537, 29.845104387737983]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1067,
#     'Join_Count': 1,
#     'TARGET_FID': 1067,
#     'Join_Count_1': 1,
#     'Incident_No': 27316919,
#     'Time_Begun': '2019-02-26T02:00:00.000Z',
#     'UCR_No': 5031,
#     'HPD_Beat': '8C10',
#     'HPD_District': '8',
#     'Offense': 'Burglary',
#     'Address_Range': '9600-9699 HOMESTEAD',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3140891.05835,
#     'Y_Coord': 13875413.99537,
#     'Zip_Code': '77016',
#     'Time_Frame': 3,
#     'SNB_No': 47,
#     'SNB_Name': 'EAST LITTLE YORK / HOMESTEAD',
#     'Council_District': 'B',
#     'HPD_Division': 'Northeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.30096718849938, 29.850728799574103]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1068,
#     'Join_Count': 1,
#     'TARGET_FID': 1068,
#     'Join_Count_1': 1,
#     'Incident_No': 32966519,
#     'Time_Begun': '2019-03-15T20:24:00.000Z',
#     'UCR_No': 5001,
#     'HPD_Beat': '14D30',
#     'HPD_District': '14',
#     'Offense': 'Burglary',
#     'Address_Range': '7300-7399 EISENHOWER',
# ...
#     'Offense': 'Theft',
#     'Address_Range': '6600-6699 HILLCROFT',
#     'Premise_Type': 'Apartment Parking Lot',
#     'X_Coord': 3081551.31553,
#     'Y_Coord': 13822035.98955,
#     'Zip_Code': '77081',
#     'Time_Frame': 2,
#     'SNB_No': 26,
#     'SNB_Name': 'SHARPSTOWN',
#     'Council_District': 'J',
#     'HPD_Division': 'South Gessner Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.49312468642651, 29.709035803974828]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1979,
#     'Join_Count': 1,
#     'TARGET_FID': 1979,
#     'Join_Count_1': 1,
#     'Incident_No': 32415919,
#     'Time_Begun': '2019-03-14T16:59:00.000Z',
#     'UCR_No': 6143,
#     'HPD_Beat': '19G40',
#     'HPD_District': '19',
#     'Offense': 'Theft',
#     'Address_Range': '9700-9799 COURT GLEN',
#     'Premise_Type': 'Apartment Parking Lot',
#     'X_Coord': 3053424.58098,
#     'Y_Coord': 13807755.09934,
#     'Zip_Code': '77099',
#     'Time_Frame': 2,
#     'SNB_No': 25,
#     'SNB_Name': 'ALIEF',
#     'Council_District': 'F',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.58300655179436, 29.672069064703226]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1980,
#     'Join_Count': 1,
#     'TARGET_FID': 1980,
#     'Join_Count_1': 1,
#     'Incident_No': 24190319,
#     'Time_Begun': '2019-02-21T06:46:00.000Z',
#     'UCR_No': 6192,
#     'HPD_Beat': '1A20',
#     'HPD_District': '1',
#     'Offense': 'Theft',
#     'Address_Range': '900-999 GILLETTE',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3115917.34929,
#     'Y_Coord': 13841069.96942,
#     'Zip_Code': '77019',
#     'Time_Frame': 3,
#     'SNB_No': 60,
#     'SNB_Name': 'FOURTH WARD',
#     'Council_District': 'C',
#     'HPD_Division': 'Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.38306171141019, 29.758477590660807]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1981,
#     'Join_Count': 1,
#     'TARGET_FID': 1981,
#     'Join_Count_1': 1,
#     'Incident_No': 27215219,
#     'Time_Begun': '2019-03-03T08:07:00.000Z',
#     'UCR_No': 4044,
#     'HPD_Beat': '7C20',
#     'HPD_District': '7',
#     'Offense': 'Aggravated Assault',
#     'Address_Range': '4300-4399 CRANE',
#     'Premise_Type': 'Residence or House',
#     'X_Coord': 3133321.9547,
#     'Y_Coord': 13855587.23764,
#     'Zip_Code': '77026',
#     'Time_Frame': 3,
#     'SNB_No': 52,
#     'SNB_Name': 'KASHMERE GARDENS',
#     'Council_District': 'B',
#     'HPD_Division': 'Northeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.32679701124263, 29.79688908892787]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1982,
#     'Join_Count': 1,
#     'TARGET_FID': 1982,
#     'Join_Count_1': 1,
#     'Incident_No': 23437919,
#     'Time_Begun': '2019-02-22T20:51:00.000Z',
#     'UCR_No': 4043,
#     'HPD_Beat': '22B20',
#     'HPD_District': '22',
#     'Offense': 'Aggravated Assault',
#     'Address_Range': '1200-1299 GRAND PLAZA',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3097610.76087,
#     'Y_Coord': 13906809.31003,
#     'Zip_Code': '77038',
#     'Time_Frame': 3,
#     'SNB_No': 2,
#     'SNB_Name': 'GREATER GREENSPOINT',
#     'Council_District': 'B',
#     'HPD_Division': 'North Belt Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.4344167263758, 29.940716862000908]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1983,
#     'Join_Count': 1,
#     'TARGET_FID': 1983,
#     'Join_Count_1': 1,
#     'Incident_No': 23434919,
#     'Time_Begun': '2019-02-22T20:43:00.000Z',
#     'UCR_No': 4041,
#     'HPD_Beat': '6B10',
#     'HPD_District': '6',
#     'Offense': 'Aggravated Assault',
#     'Address_Range': '200-299 W LITTLE YORK',
#     'Premise_Type': 'Residence or House',
#     'X_Coord': 3108888.6535,
#     'Y_Coord': 13881380.15404,
#     'Zip_Code': '77037',
#     'Time_Frame': 3,
#     'SNB_No': 45,
#     'SNB_Name': 'NORTHSIDE/NORTHLINE',
#     'Council_District': 'H',
#     'HPD_Division': 'North Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.40129512815668, 29.86987260029559]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1984,
#     'Join_Count': 1,
#     'TARGET_FID': 1984,
#     'Join_Count_1': 1,
#     'Incident_No': 34681019,
#     'Time_Begun': '2019-03-19T16:30:00.000Z',
#     'UCR_No': 6061,
#     'HPD_Beat': '6B30',
#     'HPD_District': '6',
#     'Offense': 'Theft',
#     'Address_Range': '5300-5399 DE SOTO',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3088268.59224,
#     'Y_Coord': 13875164.71769,
#     'Zip_Code': '77091',
#     'Time_Frame': 2,
#     'SNB_No': 5,
#     'SNB_Name': 'GREATER INWOOD',
#     'Council_District': 'A',
#     'HPD_Division': 'North Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.46691804722175, 29.85451721616302]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1985,
#     'Join_Count': 1,
#     'TARGET_FID': 1985,
#     'Join_Count_1': 1,
#     'Incident_No': 32506019,
#     'Time_Begun': '2019-03-14T13:00:00.000Z',
#     'UCR_No': 6191,
#     'HPD_Beat': '9C40',
#     'HPD_District': '9',
#     'Offense': 'Theft',
#     'Address_Range': '1100-1199 UVALDE',
#     'Premise_Type': 'Restaurant or Cafeteria',
#     'X_Coord': 3178053.4972,
#     'Y_Coord': 13848612.30253,
#     'Zip_Code': '77015',
#     'Time_Frame': 2,
#     'SNB_No': 58,
#     'SNB_Name': 'NORTHSHORE',
#     'Council_District': 'E',
#     'HPD_Division': 'Northeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.18655329083867, 29.773781293858253]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1986,
#     'Join_Count': 1,
#     'TARGET_FID': 1986,
#     'Join_Count_1': 1,
#     'Incident_No': 22843119,
#     'Time_Begun': '2019-02-21T00:10:00.000Z',
#     'UCR_No': 6191,
#     'HPD_Beat': '2A60',
#     'HPD_District': '2',
#     'Offense': 'Theft',
#     'Address_Range': '800-899 W 24TH',
#     'Premise_Type': 'Residence or House',
#     'X_Coord': 3105769.33251,
#     'Y_Coord': 13858708.50491,
#     'Zip_Code': '77008',
#     'Time_Frame': 3,
#     'SNB_No': 15,
#     'SNB_Name': 'GREATER HEIGHTS',
#     'Council_District': 'C',
#     'HPD_Division': 'Central Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.41332601205272, 29.807819712031094]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1987,
#     'Join_Count': 1,
#     'TARGET_FID': 1987,
#     'Join_Count_1': 1,
#     'Incident_No': 34167819,
#     'Time_Begun': '2019-03-18T12:30:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '5F30',
#     'HPD_District': '5',
#     'Offense': 'Theft',
#     'Address_Range': '5600-5699 HOLLISTER',
#     'Premise_Type': 'Commercial Parking Lot or',
#     'X_Coord': 3076051.76121,
#     'Y_Coord': 13872617.05697,
#     'Zip_Code': '77040',
#     'Time_Frame': 2,
#     'SNB_No': 4,
#     'SNB_Name': 'FAIRBANKS / NORTHWEST CROSSING',
#     'Council_District': 'A',
#     'HPD_Division': 'Northwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.50568158782964, 29.848523678048853]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1988,
#     'Join_Count': 1,
#     'TARGET_FID': 1988,
#     'Join_Count_1': 1,
#     'Incident_No': 32500819,
#     'Time_Begun': '2019-03-14T08:06:00.000Z',
#     'UCR_No': 6071,
#     'HPD_Beat': '12D70',
#     'HPD_District': '12',
#     'Offense': 'Theft',
#     'Address_Range': '1000-1099 BAYBROOK MALL',
#     'Premise_Type': 'Specialty Store (Non-Spec',
#     'X_Coord': 3193829.14,
#     'Y_Coord': 13765354.16713,
#     'Zip_Code': '77546',
#     'Time_Frame': 2,
#     'SNB_No': 81,
#     'SNB_Name': 'CLEAR LAKE',
#     'Council_District': 'E',
#     'HPD_Division': 'Clear Lake Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.14550025938293, 29.5435157907867]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1989,
#     'Join_Count': 1,
#     'TARGET_FID': 1989,
#     'Join_Count_1': 1,
#     'Incident_No': 31922919,
#     'Time_Begun': '2019-03-13T15:40:00.000Z',
#     'UCR_No': 5021,
#     'HPD_Beat': '20G10',
#     'HPD_District': '20',
#     'Offense': 'Burglary',
#     'Address_Range': '9800-9899 MEADOWGLEN',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3064374.16856,
#     'Y_Coord': 13830266.20043,
#     'Zip_Code': '77042',
#     'Time_Frame': 3,
#     'SNB_No': 19,
#     'SNB_Name': 'WESTCHASE',
#     'Council_District': 'F',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.54644739603431, 29.733064661029182]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1990,
#     'Join_Count': 1,
#     'TARGET_FID': 1990,
#     'Join_Count_1': 1,
#     'Incident_No': 30084619,
#     'Time_Begun': '2019-03-09T15:46:00.000Z',
#     'UCR_No': 7033,
#     'HPD_Beat': '12D70',
#     'HPD_District': '12',
#     'Offense': 'Auto Theft',
#     'Address_Range': '500-599 BAYBROOK MALL',
#     'Premise_Type': 'Mall Parking Lot',
#     'X_Coord': 3193759.65036,
#     'Y_Coord': 13765293.59997,
#     'Zip_Code': '77546',
#     'Time_Frame': 3,
#     'SNB_No': 81,
#     'SNB_Name': 'CLEAR LAKE',
#     'Council_District': 'E',
#     'HPD_Division': 'Clear Lake Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.14572497102509, 29.543355609466264]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1991,
#     'Join_Count': 1,
#     'TARGET_FID': 1991,
#     'Join_Count_1': 1,
#     'Incident_No': 34180719,
#     'Time_Begun': '2019-03-18T15:04:00.000Z',
#     'UCR_No': 6191,
#     'HPD_Beat': '6B30',
#     'HPD_District': '6',
#     'Offense': 'Theft',
#     'Address_Range': '5500-5599 DE SOTO',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3087574.88408,
#     'Y_Coord': 13875134.71747,
#     'Zip_Code': '77091',
#     'Time_Frame': 2,
#     'SNB_No': 5,
#     'SNB_Name': 'GREATER INWOOD',
#     'Council_District': 'A',
#     'HPD_Division': 'North Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.46910835975322, 29.85449235849888]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1992,
#     'Join_Count': 1,
#     'TARGET_FID': 1992,
#     'Join_Count_1': 1,
#     'Incident_No': 34179319,
#     'Time_Begun': '2019-03-16T21:00:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '20G10',
#     'HPD_District': '20',
#     'Offense': 'Theft',
#     'Address_Range': '2900-2999 S GESSNER',
#     'Premise_Type': 'Apartment Parking Lot',
#     'X_Coord': 3066623.90179,
#     'Y_Coord': 13830943.98683,
#     'Zip_Code': '77063',
#     'Time_Frame': 2,
#     'SNB_No': 19,
#     'SNB_Name': 'WESTCHASE',
#     'Council_District': 'F',
#     'HPD_Division': 'Midwest Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.5392984867396, 29.734744919007827]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1993,
#     'Join_Count': 1,
#     'TARGET_FID': 1993,
#     'Join_Count_1': 1,
#     'Incident_No': 23286219,
#     'Time_Begun': '2019-02-22T14:53:00.000Z',
#     'UCR_No': 6081,
#     'HPD_Beat': '9C40',
#     'HPD_District': '9',
#     'Offense': 'Theft',
#     'Address_Range': '13500-13599 EAST ',
#     'Premise_Type': 'Bank',
#     'X_Coord': 3178806.6599,
#     'Y_Coord': 13847333.7262,
#     'Zip_Code': '77015',
#     'Time_Frame': 3,
#     'SNB_No': 58,
#     'SNB_Name': 'NORTHSHORE',
#     'Council_District': 'E',
#     'HPD_Division': 'Northeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.18431189180818, 29.770199536486732]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1994,
#     'Join_Count': 1,
#     'TARGET_FID': 1994,
#     'Join_Count_1': 1,
#     'Incident_No': 26558619,
#     'Time_Begun': '2019-03-01T08:00:00.000Z',
#     'UCR_No': 5031,
#     'HPD_Beat': '17E20',
#     'HPD_District': '17',
#     'Offense': 'Burglary',
#     'Address_Range': '9700-9799 S GESSNER',
#     'Premise_Type': 'Apartment',
#     'X_Coord': 3070767.70499,
#     'Y_Coord': 13809589.13389,
#     'Zip_Code': '77074',
#     'Time_Frame': 3,
#     'SNB_No': 30,
#     'SNB_Name': 'BRAEBURN',
#     'Council_District': 'J',
#     'HPD_Division': 'South Gessner Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.52824428741019, 29.675706124814074]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1995,
#     'Join_Count': 1,
#     'TARGET_FID': 1995,
#     'Join_Count_1': 1,
#     'Incident_No': 26328319,
#     'Time_Begun': '2019-02-28T12:00:00.000Z',
#     'UCR_No': 5071,
#     'HPD_Beat': '11H10',
#     'HPD_District': '11',
#     'Offense': 'Burglary',
#     'Address_Range': '6700-6799 HARRISBURG',
#     'Premise_Type': 'Amusement Park, Bowling A',
#     'X_Coord': 3140025.35723,
#     'Y_Coord': 13834156.56009,
#     'Zip_Code': '77011',
#     'Time_Frame': 3,
#     'SNB_No': 82,
#     'SNB_Name': 'MAGNOLIA PARK',
#     'Council_District': 'I',
#     'HPD_Division': 'Eastside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.30780500178473, 29.737403505168803]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1996,
#     'Join_Count': 1,
#     'TARGET_FID': 1996,
#     'Join_Count_1': 1,
#     'Incident_No': 26315019,
#     'Time_Begun': '2019-03-01T10:27:00.000Z',
#     'UCR_No': 6141,
#     'HPD_Beat': '24C10',
#     'HPD_District': '24',
#     'Offense': 'Theft',
#     'Address_Range': '1100-1199 KINGWOOD',
#     'Premise_Type': 'Service or Gas Station',
#     'X_Coord': 3157716.0542,
#     'Y_Coord': 13948293.17617,
#     'Zip_Code': '77339',
#     'Time_Frame': 3,
#     'SNB_No': 43,
#     'SNB_Name': 'KINGWOOD AREA',
#     'Council_District': 'E',
#     'HPD_Division': 'Kingwood Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.24052931246813, 30.049558297699175]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1997,
#     'Join_Count': 1,
#     'TARGET_FID': 1997,
#     'Join_Count_1': 1,
#     'Incident_No': 26531219,
#     'Time_Begun': '2019-03-01T18:55:00.000Z',
#     'UCR_No': 6071,
#     'HPD_Beat': '13D40',
#     'HPD_District': '13',
#     'Offense': 'Theft',
#     'Address_Range': '8000-8099 FUQUA',
#     'Premise_Type': 'Department or Discount St',
#     'X_Coord': 3151082.41096,
#     'Y_Coord': 13788778.20583,
#     'Zip_Code': '77075',
#     'Time_Frame': 3,
#     'SNB_No': 78,
#     'SNB_Name': 'GREATER HOBBY AREA',
#     'Council_District': 'D',
#     'HPD_Division': 'Southeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.27753136046245, 29.611708782708497]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1998,
#     'Join_Count': 1,
#     'TARGET_FID': 1998,
#     'Join_Count_1': 1,
#     'Incident_No': 26580319,
#     'Time_Begun': '2019-03-01T20:57:00.000Z',
#     'UCR_No': 6073,
#     'HPD_Beat': '22B10',
#     'HPD_District': '22',
#     'Offense': 'Theft',
#     'Address_Range': '7600-7699 W FM 1960',
#     'Premise_Type': 'Liquor Store',
#     'X_Coord': 3062587.0305,
#     'Y_Coord': 13913981.50505,
#     'Zip_Code': '77070',
#     'Time_Frame': 3,
#     'SNB_No': 1,
#     'SNB_Name': 'WILLOWBROOK',
#     'Council_District': 'A',
#     'HPD_Division': 'North Belt Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.54428287903525, 29.963321006752764]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1999,
#     'Join_Count': 1,
#     'TARGET_FID': 1999,
#     'Join_Count_1': 1,
#     'Incident_No': 26533319,
#     'Time_Begun': '2019-03-01T19:00:00.000Z',
#     'UCR_No': 6073,
#     'HPD_Beat': '20G30',
#     'HPD_District': '20',
#     'Offense': 'Theft',
#     'Address_Range': '2700-2799 S KIRKWOOD',
#     'Premise_Type': 'Department or Discount St',
#     'X_Coord': 3050962.19819,
#     'Y_Coord': 13830953.57798,
#     'Zip_Code': '77082',
#     'Time_Frame': 3,
#     'SNB_No': 19,
#     'SNB_Name': 'WESTCHASE',
#     'Council_District': 'F',
#     'HPD_Division': 'Westside Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.58862686970267, 29.736036508221787]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2000,
#     'Join_Count': 1,
#     'TARGET_FID': 2000,
#     'Join_Count_1': 1,
#     'Incident_No': 26536619,
#     'Time_Begun': '2019-03-01T18:30:00.000Z',
#     'UCR_No': 6071,
#     'HPD_Beat': '8C10',
#     'HPD_District': '8',
#     'Offense': 'Theft',
#     'Address_Range': '7700-7799 LOCKWOOD',
#     'Premise_Type': 'Convenience Store',
#     'X_Coord': 3135463.98962,
#     'Y_Coord': 13867744.55538,
#     'Zip_Code': '77016',
#     'Time_Frame': 3,
#     'SNB_No': 48,
#     'SNB_Name': 'TRINITY / HOUSTON GARDENS',
#     'Council_District': 'B',
#     'HPD_Division': 'Northeast Division'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-95.31884034248354, 29.830119588631444]}},
#   ...]}

# %%
# Grab "features" data from "crime_report"
crime_list = crime_report["features"]

# Check the length of "crime_list"
len(crime_list)
# Out:
# 7368

# %% [markdown]
# ### Data rearrangement in Pandas DataFrame

# %%
# Generate a new empty Pandas dataframe with "Offense", "Crime Type", "Lat", and "Lng" columns
crime_info_pd = pd.DataFrame(columns = ["Offense", "Crime Type", "Lat", "Lng"])

# Preview "crime_info_pd"
crime_info_pd
# Out:
# Empty DataFrame
# Columns: [Offense, Crime Type, Lat, Lng]
# Index: []

# %%
# list to store types of crimes
crime_type = []

# Loop through "crime_list"
for case in crime_list:
    
    # Append unique values of crime types to "crime_type" list
    if case["properties"]["Offense"] not in crime_type:
        crime_type.append(case["properties"]["Offense"])

# Get the list of crime type documented in HPD recent crime data
crime_type
# Out:
# ['Theft',
#  'Robbery',
#  'Burglary',
#  'Auto Theft',
#  'Aggravated Assault',
#  'Rape',
#  'Murder']

# %%
# List for violet crimes
violet_crime = ["Aggravated Assault", "Murder", "Robbery", "Rape"]

# List for non-violet crimes
non_violet_crime = ["Theft", "Burglary", "Auto Theft"]

# List to store date of crime
crime_date = []

# Loop through "crime_list"
for case in crime_list:

    # Note that the length of "crime_info_pd" immediately gets changed once a value is added in a column
    # Use "im" to store the length of "crime_info_pd" so that new values will be added in the same row for each column within the same iteration
    im = len(crime_info_pd)
    
    # Append data to "Offense" column
    crime_info_pd.loc[im, "Offense"] = case["properties"]["Offense"]
    
    # Determine crime type (violet/non-violet) through comparing with "violet_crime" and "non_violet_crime" lists
    if case["properties"]["Offense"] in violet_crime:
        crime_info_pd.loc[im, "Crime Type"] = "Violet"
    if case["properties"]["Offense"] in non_violet_crime:
        crime_info_pd.loc[im, "Crime Type"] = "Non-Violet"
    
    # Append longitude value to "Lng" column
    crime_info_pd.loc[im, "Lng"] = case["geometry"]["coordinates"][0]

    # Append Latitude value to "Lat" column
    crime_info_pd.loc[im, "Lat"] = case["geometry"]["coordinates"][1]
    
    # Convert date info. into datetime format and temporatorily assign it to "date_im"
    date_im = datetime.datetime.strptime(case["properties"]["Time_Begun"][:10], "%Y-%m-%d")
    # Append date info into "crime_date" list as "yyyy-mm-dd"
    crime_date.append(date_im.strftime("%Y-%m-%d"))
    
# Preview "crime_info_pd"
crime_info_pd.head()
# Out:
#    Offense  Crime Type      Lat      Lng
# 0    Theft  Non-Violet  29.6774 -95.4168
# 1    Theft  Non-Violet   29.614  -95.394
# 2  Robbery      Violet  29.7982   -95.37
# 3    Theft  Non-Violet  29.7242 -95.5011
# 4    Theft  Non-Violet  29.6197 -95.2821

# %%
# Remove cases of crime with missing data if any
crime_info_pd = crime_info_pd.dropna(how="any")

# Check the length of "crime_info_pd"
len(crime_info_pd)
# Out:
# 7368

# %%
# Print the date range of HPD recent crime data 
date_range = str("from " + min(crime_date) + " to " + max(crime_date))

print("Crime Report" + " " + date_range)
# Out:
# Crime Report from 2019-02-21 to 2019-03-20

# %% [markdown]
# ### Heatmap of Crime Types

# %%
# Configure gmaps with API key
gmaps.configure(api_key=gkey)

# %%
# Store "Lat" and "Lng" into "loc_non_violet" and "loc_violet"
loc_non_violet = crime_info_pd.loc[crime_info_pd["Crime Type"] == "Non-Violet", ["Lat","Lng"]].astype(float)

loc_violet = crime_info_pd.loc[crime_info_pd["Crime Type"] == "Violet", ["Lat","Lng"]].astype(float)

# Check the total number of non-violet crimes as well as violet crimes
print(f"Total number of non-violet crimes is: {len(loc_non_violet)}")
print(f"Total number of violet crimes is: {len(loc_violet)}")
# Out:
# Total number of non-violet crimes is: 6028
# Total number of violet crimes is: 1340

# %%
# Create heatmap for crime types
fig = gmaps.figure()

# Set parameters for non-violet heatmap
# Note that "weights" is not included as "Non_Violet" in every row is of equal importance
non_violet_layer = gmaps.heatmap_layer(loc_non_violet, point_radius = 30)
# Set the color range of crime heatmap from fuchsia to red
non_violet_layer.gradient = [
    (255, 255, 255, 0),
    (255, 0, 255, 0.6),
    (255, 0, 0, 1.0)
  ]
# Apply non-violet heatmap layer on google map
fig.add_layer(non_violet_layer)

# Set parameters for violet heatmap
# Note that total violet crime is roughly 4.5 folds of that for non-violet crime in quantity, adjust its opacity in order not to mask the heatdot on non-violet heatmap layer
violet_layer = gmaps.heatmap_layer(loc_violet, point_radius = 30, opacity=0.35)
# Set the color range of crime heatmap within the range of yellow (light color)
violet_layer.gradient = [
    (255, 255, 255, 0),
    (128, 128, 0, 0.6),
    (255, 255, 0, 1.0)
  ]
# Apply violet heatmap layer on google map
fig.add_layer(violet_layer)

# Preview "fig"
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
