# %%
import pandas as pd
import json
import http.client
from api_keys import attom_data_key

# %%
a = pd.read_csv(f"../data/rawdata/Harris_County.csv",header=None)
zips =  list(a[0])

# %%
# Out:
# [77002,
#  77004,
#  77003,
#  77006,
#  77005,
#  77008,
#  77007,
#  77010,
#  77009,
#  77012,
#  77011,
#  77014,
#  77013,
#  77016,
#  77015,
#  77018,
#  77017,
#  77020,
#  77019,
#  77022,
#  77021,
#  77024,
#  77023,
#  77026,
#  77025,
#  77028,
#  77027,
#  77030,
#  77029,
#  77032,
#  77031,
#  77034,
#  77033,
#  77036,
#  77035,
#  77038,
#  77037,
#  77040,
#  77039,
#  77042,
#  77041,
#  77044,
#  77043,
#  77046,
#  77045,
#  77048,
#  77047,
#  77050,
#  77049,
#  77051,
#  77054,
#  77053,
#  77056,
#  77055,
#  77058,
#  77057,
#  77060,
#  77059,
#  77062,
#  77061,
#  77064,
#  77063,
#  77066,
#  77065,
#  77068,
#  77067,
#  77070,
#  77069,
#  77072,
#  77071,
#  77074,
#  77073,
#  77076,
#  77075,
#  77078,
#  77077,
#  77080,
#  77079,
#  77082,
#  77081,
#  77084,
#  77083,
#  77086,
#  77085,
#  77088,
#  77087,
#  77090,
#  77089,
#  77092,
#  77091,
#  77094,
#  77093,
#  77096,
#  77095,
#  77098,
#  77099,
#  77204,
#  77217,
#  77249,
#  77251,
# ...
